# %%
from mpi4py import MPI
import gmsh
import numpy as np
from scipy.spatial import cKDTree
import pyvista as pv
from dolfinx import plot

Lx, Ly = 1.0, 1.0

# %%
from dolfinx import mesh, fem
import ufl
import numpy as np
from dolfinx.io import gmsh as gmshio
from mpi4py import MPI

# ---------------------------------------------------------------------
# 1. Mesh and tags (same mesh as reference)
# ---------------------------------------------------------------------
ref = 6
filename = f"regular_mesh_{ref}.msh"
msh, cell_markers, facet_markers = gmshio.read_from_msh(filename, MPI.COMM_WORLD, 0, gdim=2)[0:3]

tdim = msh.topology.dim  # 2
fdim = tdim - 1          # 1

lc = 1.0 / (2**ref)      # mesh size
h = lc

omega = msh

# ---------------------------------------------------------------------
# 2. Function space (standard CG on the bulk only)
# ---------------------------------------------------------------------
order = 1
V = fem.functionspace(omega, ("Lagrange", order))

# ---------------------------------------------------------------------
# 3. Trial / Test / Solution function
# ---------------------------------------------------------------------
phi = ufl.TestFunction(V)
p = fem.Function(V, name="p")
dp = ufl.TrialFunction(V)

# ---------------------------------------------------------------------
# 4. Coordinates and data
# ---------------------------------------------------------------------
x = ufl.SpatialCoordinate(omega)
# f_m = fem.Constant(omega, 0.0)
# f_m = 2*(x[1] - x[1]**2 + x[0] - x[0]**2)
f_m = x[1]
def f_callable(x):
    return x[1]

f = fem.Function(V)
f_func = fem.Function(V)
f_func.interpolate(f_callable)
f.interpolate(f_callable)
# create function
k_m = fem.Function(V, name="kappa")

def k_callable(x):
    # x is array with shape (gdim, N). compute scalar per point, return shape (1,N)
    vals = 2*(x[0])
    return vals[np.newaxis, :]

k_m.interpolate(k_callable)

kappa = 1.0
# k_m = fem.Constant(omega, kappa)  # bulk permeability

dx = ufl.Measure("dx", domain=omega)

# compute domain bbox to locate sides
coords = omega.geometry.x
xx = coords[:, 0]
yy = coords[:, 1]
xmin, xmax = xx.min(), xx.max()
ymin, ymax = yy.min(), yy.max()

tol = 1e-10 * max(xmax - xmin, ymax - ymin)

# locate boundary facets for bottom (y = ymin) and top (y = ymax)
bottom_facets = mesh.locate_entities_boundary(
    omega, fdim, lambda x: np.isclose(x[1], ymin, atol=tol)
)
top_facets = mesh.locate_entities_boundary(
    omega, fdim, lambda x: np.isclose(x[1], ymax, atol=tol)
)

# create meshtags for those Neumann parts (optional — kept for clarity)
indices = np.concatenate([bottom_facets, top_facets]).astype(np.int32)
values = np.concatenate([
    np.full(bottom_facets.shape, 10, dtype=np.int32),  # bottom tag = 10
    np.full(top_facets.shape,    20, dtype=np.int32),  # top tag    = 20
])
neumann_tags = mesh.meshtags(omega, fdim, indices, values)

# boundary measure (we'll use ds over the whole boundary with conditional g_N)
dsN = ufl.Measure("ds", domain=omega)  # we integrate g_N over the boundary

# Neumann data as conditional on the y coordinate (same as reference)
# g_N = ufl.conditional(
#     ufl.lt(abs(x[1] - ymax), tol),
#     -1.0,                                # top
#     ufl.conditional(
#         ufl.lt(abs(x[1] - ymin), tol),
#         2.0,                             # bottom
#         0.0                              # elsewhere
#     ),
# )

# ---------------------------------------------------------------------
# 5. Weak form (standard Darcy / Poisson form)
# ---------------------------------------------------------------------
a = ufl.inner(k_m * ufl.grad(dp), ufl.grad(phi)) * dx
L = f_m * phi * dx
# L -= g_N * phi * dsN

# Form for assembling (bilinear/trilinear functions expect TrialFunction in a)
A_form = ufl.inner(k_m * ufl.grad(dp), ufl.grad(phi)) * dx
b_form = L

# ---------------------------------------------------------------------
# 6. Dirichlet BCs (left/right like reference)
# ---------------------------------------------------------------------
# locate dofs on each side
left_dofs   = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[0], xmin, atol=tol))
right_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[0], xmax, atol=tol))
top_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[1], ymax, atol=tol))
bottom_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[1], ymin, atol=tol))

all_dofs = np.unique(np.concatenate([left_dofs, right_dofs]))
dof_coords = V.tabulate_dof_coordinates()

p_bc_fun = fem.Function(V)
p_bc_fun.x.array[left_dofs] = 0.0
p_bc_fun.x.array[right_dofs] = dof_coords[right_dofs, 1] / 2.0
# p_bc_fun.x.array[top_dofs] = 0.0
# p_bc_fun.x.array[bottom_dofs] = 0.0

bc = fem.dirichletbc(p_bc_fun, all_dofs)
bcs = [bc]

# ---------------------------------------------------------------------
# 7. Solve linear problem using dolfinx.fem.petsc.LinearProblem
# ---------------------------------------------------------------------
from dolfinx.fem import petsc

linear_problem = petsc.LinearProblem(
    a=A_form,
    L=b_form,
    bcs=bcs,
    petsc_options={
        "ksp_type": "preonly",
        "pc_type": "lu",
        "pc_factor_mat_solver_type": "mumps",
        "ksp_error_if_not_converged": True,
    },
    petsc_options_prefix="pmix_"
)

p_sol = linear_problem.solve()
p_sol.name = "pressure"

# optionally copy into p Function if you prefer
p.x.array[:] = p_sol.x.array[:]

# ---------------------------------------------------------------------
# 8. Diagnostics
# ---------------------------------------------------------------------
print("DOFs in V:", V.dofmap.index_map.size_global)
# Out:
# Info    : Reading 'regular_mesh_6.msh'...
# Info    : 36993 entities
# Info    : 4225 nodes
# Info    : 36993 elements
# Info    : Done reading 'regular_mesh_6.msh'
# DOFs in V: 4225

# %%
# Access mesh geometry
tdim = omega.topology.dim

# Gather coordinates and connectivity
omega_geometry = omega.geometry.x[:,0:2]  # global array of vertex coords
# Build cell->vertex mapping (fast access)
# Using dolfinx.Cell to get connectivity is more robust, but below uses mesh.topology
cells = omega.topology.connectivity(0, tdim)  # vertices -> cells
# Instead get cell->vertex mapping via mesh.topology.index_map?
# Simpler: use mesh.geometry.x with mesh.topology.connectivity(tdim, 0)
ctv = omega.topology.connectivity(tdim, 0)
if ctv is None:
    omega.topology.create_connectivity(tdim, 0)
    ctv = omega.topology.connectivity(tdim, 0)
# ctv.array() gives flattened vertex indices -> need per-cell view
# There's a helper to get cell entity indices
num_cells = omega.topology.index_map(tdim).size_local  # per-rank local count
# We'll iterate over local cells only
local_cells = np.arange(num_cells, dtype=np.int32)

# For evaluating u_h and kappa, we can use u_h.x.array if needed.
# But easier: create a point evaluation lambda to get value at a point
from dolfinx.fem import Function
u_func = p_sol
local_fluxes = {}
V_dofmap = V.dofmap.index_map.local_range  # not directly used; we'll query dofs per cell

# Get dof indices per cell
# Using dolfinx.fem.locate_dofs_topological is one option, but below we get cell_dofs
dofmap = V.dofmap
# But to avoid uncertain reshape semantics, use mesh.topology.connectivity(tdim, 0).entities
# Simpler robust approach: use dolfinx.mesh.cells() to get local cells vertex indices
try:
    from dolfinx.mesh import cells as dolfinx_cells
    local_cell_vertices = dolfinx_cells(mesh)
except Exception:
    # fallback: create by slicing connectivity
    # arr = ctv.array
    # local_cell_vertices = arr.reshape((-1, 3))
    local_cell_vertices = np.array([ctv.links(c) for c in range(ctv.num_nodes)])

# %%
tdim = omega.topology.dim
omega.topology.create_connectivity(tdim, tdim - 1)
omega.topology.create_connectivity(tdim - 1, tdim)

c2f = omega.topology.connectivity(tdim, tdim - 1)
f2c = omega.topology.connectivity(tdim - 1, tdim)

num_cells = omega.topology.index_map(tdim).size_local

local_cell_adjacent = [[] for _ in range(num_cells)]

for c in range(num_cells):
    neighbors = set()
    for ff in c2f.links(c):
        for cc in f2c.links(ff):
            if cc != c:
                neighbors.add(int(cc))
    local_cell_adjacent[c] = list(neighbors)

# %%
#facet vertices
tdim = omega.topology.dim
fdim = tdim - 1

# Make sure facet -> vertex connectivity exists
if omega.topology.connectivity(fdim, 0) is None:
    omega.topology.create_connectivity(fdim, 0)

f2v = omega.topology.connectivity(fdim, 0)

num_facets = omega.topology.index_map(fdim).size_local
local_facets = np.arange(num_facets, dtype=np.int32)

facet_vertices = []
facet_coords = []

x = omega.geometry.x  # global vertex coordinates

for ff in local_facets:
    verts = f2v.links(ff)          # vertex indices of facet f
    coords = x[verts]             # coordinates of those vertices

    facet_vertices.append(verts)
    facet_coords.append(coords)

# %%
import numpy as np
from collections import defaultdict

def compute_cell_subdomains_from_connectivity(
    local_cell_vertices,
    omega_geometry,
    n_per_dim,
    x0=0.0, x1=1.0,
    y0=0.0, y1=1.0,
):
    """
    Connectivity-based subdomain adjacency detection.
    Works for structured triangular meshes.

    Returns:
        cell_subdomain : list of lists
            [own_subdomain, adj1, adj2, ...]
    """

    m = n_per_dim
    dx = (x1 - x0) / m
    dy = (y1 - y0) / m

    n_cells = len(local_cell_vertices)

    # -------------------------------------------------
    # 1. Compute centroid-based OWNERSHIP only
    # -------------------------------------------------
    centroids = np.array([
        omega_geometry[verts].mean(axis=0)
        for verts in local_cell_vertices
    ])

    own_sub = []

    for x_c, y_c in centroids:
        ix = int((x_c - x0) / dx)
        iy = int((y_c - y0) / dy)

        ix = max(0, min(m - 1, ix))
        iy = max(0, min(m - 1, iy))

        own_sub.append(iy * m + ix)

    # -------------------------------------------------
    # 2. Build edge-to-cell map
    # -------------------------------------------------
    edge_map = defaultdict(list)

    for cell_id, verts in enumerate(local_cell_vertices):
        nv = len(verts)
        for k in range(nv):
            v0 = verts[k]
            v1 = verts[(k + 1) % nv]

            edge = tuple(sorted((v0, v1)))
            edge_map[edge].append(cell_id)

    # -------------------------------------------------
    # 3. Detect adjacency via shared edges
    # -------------------------------------------------
    cell_subdomain = []

    for cell_id in range(n_cells):

        subs = [own_sub[cell_id]]

        verts = local_cell_vertices[cell_id]
        nv = len(verts)

        for k in range(nv):
            v0 = verts[k]
            v1 = verts[(k + 1) % nv]
            edge = tuple(sorted((v0, v1)))

            neighbors = edge_map[edge]

            for nb in neighbors:
                if nb == cell_id:
                    continue

                nb_sub = own_sub[nb]
                if nb_sub != own_sub[cell_id] and nb_sub not in subs:
                    subs.append(nb_sub)

        cell_subdomain.append(subs)

    return cell_subdomain


num_subdomains = 4
cell_subdomain = compute_cell_subdomains_from_connectivity(local_cell_vertices, omega_geometry, int(np.sqrt(num_subdomains)))

# %%
import matplotlib.pyplot as plt
import numpy as np

centroids = np.array([omega_geometry[i].mean(axis=0) 
                      for i in local_cell_vertices])

fig, ax = plt.subplots()

for idx, (x, y) in enumerate(centroids):
    ax.plot(x, y, marker='o')          # plot point (not scatter)
    ax.text(x, y, str(idx),            # label with enumerate index
            fontsize=10,
            ha='center', va='center')

ax.set_aspect('equal')
plt.show()

# %%
fig, ax = plt.subplots()

for idx, (x, y) in enumerate(centroids):
    ax.plot(x, y, marker='o')          # plot point (not scatter)
    ax.text(x, y, str(cell_subdomain[idx][0]),            # label with enumerate index
            fontsize=10,
            ha='center', va='center')

ax.set_aspect('equal')
plt.show()

# %%
import numpy as np
import torch
import torch.nn as nn
import cma
from tqdm import tqdm
import basix
from dolfinx import default_scalar_type, mesh as dmesh
import math

# ---------------------------------------------------------
# 1. Define a small NN for flux (or flux correction)
# ---------------------------------------------------------
class AdaptiveTanh(nn.Module):
    def __init__(self, n=5.0):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(1.0 / n))  # scalar a^k

    def forward(self, x):
        return torch.tanh(self.a * x)
    
class AdaptiveSin(nn.Module):
    def __init__(self, n=5.0):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(1.0 / n))  # scalar a^k

    def forward(self, x):
        return torch.sin(self.a * x) #+ torch.cos(self.a * x)
    
class FluxNet(nn.Module):
    def __init__(self, in_dim=1, out_dim=1, hidden_dim=32, n = 5.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        # x: tensor of shape (N, in_dim)
        return self.net(x)
    
    def slope_recovery_term(self):
        # collect all a^k from hidden layers
        slopes = []
        for m in self.net:
            if isinstance(m, AdaptiveTanh) or isinstance(m, AdaptiveSin):
                slopes.append(m.a)

        a = torch.stack(slopes)                 # shape: (L-1,)
        return 1.0 / torch.mean(torch.exp(a))   # S(a)
    
    def zero_last_layer(self):
        last = self.net[-1]
        nn.init.constant_(last.weight, 0.0)
        if last.bias is not None:
            nn.init.constant_(last.bias, 0.0)

    def siren_init(self):
        """
        Apply SIREN initialization to all Linear layers.
        Assumes AdaptiveSin(n=n) uses frequency multiplier n.
        """
        for i, m in enumerate(self.net):
            if isinstance(m, nn.Linear):
                fan_in = m.in_features

                if i == 0:
                    # First layer
                    bound = 1.0 / fan_in
                else:
                    # Hidden layers
                    # Find preceding AdaptiveSin to get its frequency n
                    prev = self.net[i - 1]
                    if isinstance(prev, AdaptiveSin):
                        omega = float(prev.a)
                    else:
                        omega = 1.0

                    bound = (math.sqrt(6 / fan_in)) / omega

                nn.init.uniform_(m.weight, -bound, bound)

                if m.bias is not None:
                    nn.init.uniform_(m.bias, -bound, bound)


nets = [FluxNet(in_dim=2, out_dim=2, hidden_dim=8) for _ in range(num_subdomains)]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for net in nets:
    net.to(device)
    # net.siren_init()
    net.zero_last_layer()

# ---------------------------------------------------------
# 2. Utilities to flatten / unflatten parameters
# ---------------------------------------------------------

def get_flat_params_from(net: nn.Module) -> np.ndarray:
    """
    Returns a 1D numpy array containing all parameters of the network.
    """
    with torch.no_grad():
        vec = torch.nn.utils.parameters_to_vector(net.parameters())
    return vec.cpu().numpy()


def set_flat_params_to(net: nn.Module, theta: np.ndarray):
    """
    Loads a 1D numpy array `theta` back into the network parameters.
    """
    theta_torch = torch.tensor(theta, dtype=torch.float32)
    with torch.no_grad():
        torch.nn.utils.vector_to_parameters(theta_torch, net.parameters())


# ---------------------------------------------------------
# 3. Define a loss function for CMA-ES (gradient-free)
# ---------------------------------------------------------

# Precompute sample points (these play the role of quadrature points)
# x_np = np.linspace(0.0, 1.0, 128, endpoint=True)
x_np = V.tabulate_dof_coordinates()
x_torch = torch.tensor(x_np, dtype=torch.float32).view(-1, 1)
gdim = omega_geometry.shape[1]

xi = torch.tensor(
        [
            0.5 * (1.0 - 1.0 / math.sqrt(3.0)),
            0.5 * (1.0 + 1.0 / math.sqrt(3.0)),
        ],
        dtype=torch.float32,
        device=device,
    )
wi = torch.tensor([0.5, 0.5], dtype=torch.float32, device=device)

def integrate_edge_flux(net, x0, x1, n_edge, L, xi, wi, num_sub):
    """
    Compute ∫_edge (net(x)·n_edge) ds via composite quadrature.
    """
    t = x1 - x0
    h = 1.0 / num_sub

    int_edge = 0.0
    for j in range(num_sub):
        s_left = j * h
        for k in range(len(xi)):
            s = s_left + h * xi[k]
            w = h * wi[k]

            x_q = x0 + s * t
            r_q = net(x_q.unsqueeze(0))[0]  # (dim,)

            int_edge = int_edge + torch.dot(r_q, n_edge) * L * w

    return int_edge

def compute_element_continuity(nets):
    device = next(nets[0].parameters()).device
    num_vertices = omega_geometry.shape[0]
    
    # 1) Build vertex → {subdomains} map
    vertex_subdomains = [set() for _ in range(num_vertices)]

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx]  # 0,1,2,3
        for v in cell_verts:
            vertex_subdomains[v].add(sd)

    # Sort so we can index [0], [1] deterministically
    vertex_subdomains = [sorted(vv) for vv in vertex_subdomains]

    # 2) Loop over cells and edges, accumulate per-subdomain penalty
    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]

    tdim = omega.topology.dim
    cells_vtx = omega.topology.connectivity(0, tdim)

    pairs = list(enumerate(local_cell_vertices))
    random.shuffle(pairs)

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    # for local_cell_idx, cell_verts in pairs:
        sd = cell_subdomain[local_cell_idx]
        coords = omega_geometry[cell_verts]
        centroid = np.mean(coords, axis=0).reshape(1, -1)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()
        loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

        # edges in terms of *global vertex indices*
        # edge_indices = [
        #     (cell_verts[0], cell_verts[1]),
        #     (cell_verts[1], cell_verts[2]),
        #     (cell_verts[2], cell_verts[0])
        # ]
        edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

        coord_el = basix.ufl.element(
            "Lagrange", "triangle", 1, shape=(gdim,)
        )

        local_mesh = dmesh.create_mesh(
            MPI.COMM_SELF, loc_cells, coord_el, coords
        )
        tdim = local_mesh.topology.dim
        fdim = tdim - 1
        # Make sure facet entities / connectivity exist
        local_mesh.topology.create_connectivity(tdim, fdim)
        local_mesh.topology.create_connectivity(fdim, tdim)

        # Total number of facets
        num_facets = local_mesh.topology.index_map(fdim).size_local

        V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
        P_loc = fem.functionspace(local_mesh, ("CG", order))

        p_K = fem.Function(P_loc)
        k_m_loc = fem.Function(P_loc)
        f_m_loc = fem.Function(P_loc)

        x_loc = V_loc.tabulate_dof_coordinates()[:, :2]
        x_loc_torch = torch.tensor(x_loc, dtype=torch.float32, device=device)

        # ---------------- r_theta integral ----------------
        coords_t = torch.tensor(coords, dtype=torch.float32, device=device)

        # ---------------- CG flux + source ----------------
        global_dofs = V.dofmap.cell_dofs(local_cell_idx)
        local_dofs = P_loc.dofmap.cell_dofs(0)

        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
        f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()
        f_m_loc.x.scatter_forward()

        q_CG = -k_m_loc * ufl.grad(p_K)
        n_K = ufl.FacetNormal(local_mesh)

        cell_adj = local_cell_adjacent[local_cell_idx]

        for (v0, v1) in edge_indices_loc:
            i0 = cell_verts[v0]
            i1 = cell_verts[v1]
            # Only interface edges between exactly 2 subdomains, and the same pair at both endpoints
            if (len(vertex_subdomains[i0]) >= 2 and len(vertex_subdomains[i1]) >= 2):
                edge_sds = set(vertex_subdomains[i0]) & set(vertex_subdomains[i1])

                # Remove the current cell's subdomain
                sd_adj_set = edge_sds - {sd}

                if len(sd_adj_set) != 1:
                    # edge not between exactly two subdomains, skip or handle
                    continue
                sd_adj = next(iter(sd_adj_set))
                
                #find the CG flux in the edge
                local_mesh.topology.create_connectivity(0, fdim)
                local_mesh.topology.create_connectivity(fdim, 0)

                v_to_f = local_mesh.topology.connectivity(0, fdim)
                f_to_v = local_mesh.topology.connectivity(fdim, 0)

                edge_id = None
                for ff in v_to_f.links(v0):
                    verts = f_to_v.links(ff)
                    if v1 in verts:
                        edge_id = ff
                        break

                # All facet indices
                facets = np.arange(num_facets, dtype=np.int32)

                # Tag values: 0 = unmarked
                values = np.zeros(num_facets, dtype=np.int32)

                # Pick ANY positive integer as the tag
                EDGE_TAG = 1
                values[edge_id] = EDGE_TAG

                facet_tags = mesh.meshtags(local_mesh, fdim, facets, values)

                ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

                int_qcg_edge = fem.assemble_scalar(
                    fem.form(ufl.dot(q_CG, n_K) * ds(EDGE_TAG))
                )

                # LOCAL MESH ADJ
                # find neighbor cell along this edge (same as code 2)
                cells0 = cells_vtx.links(i0)
                cells1 = cells_vtx.links(i1)
                common_cells = np.intersect1d(cells0, cells1)
                neighbor_cells = [int(c) for c in common_cells if int(c) != local_cell_idx]
                if len(neighbor_cells) == 0:
                    continue  # boundary / inconsistent mesh
                local_cell_idx_adj = neighbor_cells[0]

                cell_verts_adj = local_cell_vertices[local_cell_idx_adj]
                # find local indices in the neighbor that match i0, i1
                try:
                    loc0_adj = int(np.where(cell_verts_adj == i0)[0][0])
                    loc1_adj = int(np.where(cell_verts_adj == i1)[0][0])
                except IndexError:
                    # neighbor doesn't actually share both these vertices -> skip
                    continue
                coords_adj = omega_geometry[cell_verts_adj]
                centroid_adj = np.mean(coords_adj, axis=0).reshape(1, -1)
                centroid_t_adj = torch.tensor(centroid_adj, dtype=torch.float32, device=device).squeeze()
                local_mesh_adj = dmesh.create_mesh(
                    MPI.COMM_SELF, loc_cells, coord_el, coords_adj
                )
                V_loc_adj = fem.functionspace(local_mesh_adj, ("CG", order + 1, (gdim,)))
                P_loc_adj = fem.functionspace(local_mesh_adj, ("CG", order))

                p_K_adj = fem.Function(P_loc_adj)
                k_m_loc_adj = fem.Function(P_loc_adj)

                x_loc_adj = V_loc_adj.tabulate_dof_coordinates()[:, :2]

                global_dofs_adj = V.dofmap.cell_dofs(local_cell_idx_adj)
                local_dofs_adj = P_loc_adj.dofmap.cell_dofs(0)

                p_K_adj.x.array[local_dofs_adj] = p_sol.x.array[global_dofs_adj]
                k_m_loc_adj.x.array[local_dofs_adj] = k_m.x.array[global_dofs_adj]

                p_K_adj.x.scatter_forward()
                k_m_loc_adj.x.scatter_forward()

                q_CG_adj = -k_m_loc_adj * ufl.grad(p_K_adj)
                n_K_adj = ufl.FacetNormal(local_mesh_adj)

                #find the CG flux adj in the edge
                local_mesh_adj.topology.create_connectivity(0, fdim)
                local_mesh_adj.topology.create_connectivity(fdim, 0)

                v_to_f_adj = local_mesh_adj.topology.connectivity(0, fdim)
                f_to_v_adj = local_mesh_adj.topology.connectivity(fdim, 0)

                edge_id_adj = None
                for ff in v_to_f_adj.links(loc0_adj):
                    verts = f_to_v_adj.links(ff)
                    if loc1_adj in verts:
                        edge_id_adj = ff
                        break

                # All facet indices
                facets_adj = np.arange(num_facets, dtype=np.int32)

                # Tag values: 0 = unmarked
                values_adj = np.zeros(num_facets, dtype=np.int32)

                # Pick ANY positive integer as the tag
                EDGE_TAG = 1
                values_adj[edge_id_adj] = EDGE_TAG

                facet_tags_adj = mesh.meshtags(local_mesh_adj, fdim, facets_adj, values_adj)

                ds_adj = ufl.Measure("ds", domain=local_mesh_adj, subdomain_data=facet_tags_adj)

                int_qcg_edge_adj = fem.assemble_scalar(
                    fem.form(ufl.dot(q_CG_adj, n_K_adj) * ds_adj(EDGE_TAG))
                )

                # ---- geometric data (on the right device) ----
                x0 = torch.tensor(omega_geometry[i0], dtype=torch.float32, device=device)
                x1 = torch.tensor(omega_geometry[i1], dtype=torch.float32, device=device)

                t = x1 - x0
                L = torch.linalg.norm(t)
                if L <= 0:
                    continue

                n_edge = torch.stack([t[1], -t[0]]) / L
                midpoint = 0.5 * (x0 + x1)
                if torch.dot(n_edge, centroid_t - midpoint) > 0:
                    n_edge = -n_edge

                # subdomain pair sharing this edge
                # if vertex_subdomains[i0][0] == sd:
                #     sd_adj = vertex_subdomains[i0][1]
                # elif vertex_subdomains[i0][1] == sd:
                #     sd_adj = vertex_subdomains[i0][0]
                net_sd = nets[sd]
                net_sd_adj  = nets[sd_adj]

                int_net_edge = integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
                int_net_edge_adj = integrate_edge_flux(net_sd_adj, x0, x1, -n_edge, L, xi, wi, num_sub=3)

                # add the same penalty to both subdomains
                res = int_net_edge + int_qcg_edge + int_net_edge_adj + int_qcg_edge_adj
                loss_sd[sd] += res**2
                # loss_sd[sd_adj]  += res_con
                count_sd[sd] += 1
                # count_sd[sd_adj]  += 1

    # 3) normalize by number of contributions per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd
 
def grad_norm(model):
    total_norm = 0.0
    for p in model.parameters():
        if p.grad is not None:
            param_norm = p.grad.detach().norm(2)
            total_norm += param_norm**2
    return total_norm.sqrt()

num_cells = len(local_cell_vertices)
cells_per_sd = num_cells // num_subdomains

def l2_norm_network(net, omega_geometry, dx=None, weights=None, device=None):
    """
    Approximate L2 norm of `net` over the set of points omega_geometry.

    Parameters
    ----------
    net : nn.Module
        Network with output shape (N, out_dim).
    omega_geometry : array-like, shape (N, in_dim)
        Coordinates where the network is evaluated.
    dx : float, optional
        Uniform measure per point, e.g. cell size. If given and `weights` is None:
            integral ≈ dx * sum_i ||u(x_i)||^2
    weights : array-like, optional
        Non-uniform weights w_i (e.g. quadrature weights * cell volumes).
        If given:
            integral ≈ sum_i w_i ||u(x_i)||^2
    device : torch.device, optional
        Device where computation runs. If None, inferred from `net`.

    Returns
    -------
    torch.Tensor
        Scalar tensor: approximate L2 norm.
    """
    if device is None:
        device = next(net.parameters()).device

    x = torch.as_tensor(omega_geometry, dtype=torch.float32, device=device)
    u = net(x)                           # (N, out_dim)
    norms_sq = torch.sum(u**2, dim=1)    # ||u(x_i)||^2, shape (N,)

    if weights is not None:
        w = torch.as_tensor(weights, dtype=torch.float32, device=device)
        assert w.shape == norms_sq.shape, "weights must have same shape as points"
        integral_approx = torch.sum(w * norms_sq)
    elif dx is not None:
        integral_approx = dx * torch.sum(norms_sq)
    else:
        # No geometric info: treat as average over points.
        # If |Ω| = 1 (e.g. domain [0,1]^d), this coincides with L2 norm.
        integral_approx = torch.mean(norms_sq)

    return integral_approx

def grad_norm_from_loss(loss, net):
    """
    Compute L2 norm of gradients of `loss` w.r.t. all parameters of `net`.
    Uses autograd.grad (does NOT write into param.grad).
    """
    grads = torch.autograd.grad(
        loss,
        [p for p in net.parameters() if p.requires_grad],
        retain_graph=True,
        create_graph=False,
        allow_unused=True,
    )
    sq_sum = 0.0
    for g in grads:
        if g is not None:
            sq_sum = sq_sum + g.pow(2).sum()
    return sq_sum.sqrt()

# ---------------------------------------------------------
# 4. Train the network with Adam (gradient-based)
# ---------------------------------------------------------
# import torch

# Put network on desired device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# net.to(device)

# Adam optimizer
learning_rate = 1e-3
# all_params = []
# for net in nets:
#     all_params += list(net.parameters())

# optimizer = torch.optim.Adam(all_params, lr=1e-3)
optimizers = [
    torch.optim.Adam(nets[k].parameters(), lr=1e-3)
    for k in range(num_subdomains)
]

max_epochs = 800    # or whatever you like
mse_it = []

best_loss = float("inf")
best_state = None
W_f = 1.0e3   # flux term
W_c = 1.0e2     # continuity
W_a = 1.0    # slope regularizer (between 0.007 and 0.07 is reasonable)
# W_r = 1.0e1
# ckpt = torch.load("checkpoint.pt")
# net.load_state_dict(ckpt["model_state_dict"])
# optimizer.load_state_dict(ckpt["optimizer_state_dict"])
# start_epoch = ckpt["epoch"] + 1

loss_sd_arr = [[] for _ in range(num_subdomains)]
loss_cont_arr = [[] for _ in range(num_subdomains)]
loss_total_arr = [[] for _ in range(num_subdomains)]

loss_lc_avg_arr = []
loss_cont_avg_arr = []

subdomain_cell = [[] for _ in range(num_subdomains)]

for cell_idx, subs in enumerate(cell_subdomain):
    own_sub = subs[0]        # index 0 = own subdomain
    subdomain_cell[own_sub].append(cell_idx)

# use sets to avoid duplicates
subdomain_vertices = [set() for _ in range(num_subdomains)]

for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    own_sub = cell_subdomain[local_cell_idx][0]
    subdomain_vertices[own_sub].update(cell_verts)

# convert sets to lists (optional: sorted for consistency)
subdomain_vertices = [sorted(list(vset)) for vset in subdomain_vertices]

# %%
subdomain_vertices_coord = [[omega_geometry[j] for j in subdomain_vertices[i]] for i in range(num_subdomains)]

# %%
def precompute_cell_flux_and_source():
    """
    Precompute, for each cell K:
        int_qcg[K] = ∫_{∂K} q_CG · n ds
        int_f[K]   = ∫_K f dx
    where q_CG = -k_m * grad(p_sol).

    Returns:
        cell_flux: dict mapping cell_idx -> (int_qcg, int_f)
    """
    cell_flux = {}

    gdim = omega_geometry.shape[1]

    # 1-cell template mesh
    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
    dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

    local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)

    tdim = local_mesh.topology.dim

    V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
    P_loc = fem.functionspace(local_mesh, ("CG", order))

    p_K = fem.Function(P_loc)
    k_m_loc = fem.Function(P_loc)
    f_m_loc = fem.Function(P_loc)

    # Local DOFs for the single template cell
    local_dofs = P_loc.dofmap.cell_dofs(0)

    n_K = ufl.FacetNormal(local_mesh)
    q_CG = -k_m_loc * ufl.grad(p_K)

    ds = ufl.ds(domain=local_mesh)
    dx = ufl.dx(domain=local_mesh)

    for cell_idx, cell_verts in enumerate(local_cell_vertices):
        coords = omega_geometry[cell_verts]
        # update geometry
        local_mesh.geometry.x[:, :gdim] = coords

        # copy global DOFs into local functions
        global_dofs = V.dofmap.cell_dofs(cell_idx)
        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
        f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()
        f_m_loc.x.scatter_forward()

        # assemble cell-level quantities
        int_qcg = fem.assemble_scalar(fem.form(ufl.dot(q_CG, n_K) * ds))
        int_f   = fem.assemble_scalar(fem.form(f_m_loc * dx))

        cell_flux[cell_idx] = (float(int_qcg), float(int_f))

    return cell_flux

cell_flux = precompute_cell_flux_and_source()

# %%
def precompute_interface_cg_fluxes():
    """
    Precompute ∫_e q_CG · n_K ds for every cell edge.
    Returns:
        cg_flux[(cell_idx, local_edge_id)] = float
    """

    cg_flux = {}

    gdim = omega_geometry.shape[1]

    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
    dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

    local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)

    tdim = local_mesh.topology.dim
    fdim = tdim - 1

    local_mesh.topology.create_connectivity(tdim, fdim)
    local_mesh.topology.create_connectivity(fdim, tdim)
    local_mesh.topology.create_connectivity(0, fdim)
    local_mesh.topology.create_connectivity(fdim, 0)

    num_facets = local_mesh.topology.index_map(fdim).size_local

    facets = np.arange(num_facets, dtype=np.int32)
    facet_values = np.arange(num_facets, dtype=np.int32)
    facet_tags = mesh.meshtags(local_mesh, fdim, facets, facet_values)

    ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

    V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
    P_loc = fem.functionspace(local_mesh, ("CG", order))

    p_K = fem.Function(P_loc)
    k_m_loc = fem.Function(P_loc)

    local_dofs = P_loc.dofmap.cell_dofs(0)

    n_K = ufl.FacetNormal(local_mesh)
    q_CG = -k_m_loc * ufl.grad(p_K)

    # Build edge mapping
    v_to_f = local_mesh.topology.connectivity(0, fdim)
    f_to_v = local_mesh.topology.connectivity(fdim, 0)

    edge_to_facet = {}
    for v0 in range(3):
        for fct in v_to_f.links(v0):
            verts = f_to_v.links(fct)
            for v1 in verts:
                if v1 != v0:
                    edge_to_facet[(v0, v1)] = fct

    edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

    for cell_idx, cell_verts in enumerate(local_cell_vertices):

        coords = omega_geometry[cell_verts]
        local_mesh.geometry.x[:, :gdim] = coords

        global_dofs = V.dofmap.cell_dofs(cell_idx)

        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()

        for edge_loc, (v0, v1) in enumerate(edge_indices_loc):
            facet_id = edge_to_facet[(v0, v1)]

            value = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ds(facet_id))
            )

            cg_flux[(cell_idx, edge_loc)] = value

    return cg_flux

cg_flux = precompute_interface_cg_fluxes()

# %%
num_vertices = omega_geometry.shape[0]

# 1) Build vertex → {subdomains} map  (unchanged)
vertex_subdomains = [set() for _ in range(num_vertices)]
for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    sd = cell_subdomain[local_cell_idx][0]  # 0,1,2,3
    for v in cell_verts:
        vertex_subdomains[v].add(sd)
vertex_subdomains = [sorted(vv) for vv in vertex_subdomains]


# --- connectivity on the global mesh (used for neighbor search) ---
tdim = omega.topology.dim
omega.topology.create_connectivity(0, tdim)
cells_vtx = omega.topology.connectivity(0, tdim)

# randomize cell order (unchanged logic)
# pairs = list(enumerate(local_cell_vertices))
# random.shuffle(pairs)

# ------------------------------------------------------------
# NEW: Precompute a single 1-cell local mesh + spaces + facet tags
# ------------------------------------------------------------
gdim = omega_geometry.shape[1]

coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)
tdim_loc = local_mesh.topology.dim
fdim = tdim_loc - 1

local_mesh.topology.create_connectivity(tdim_loc, fdim)
local_mesh.topology.create_connectivity(fdim, tdim_loc)
local_mesh.topology.create_connectivity(0, fdim)
local_mesh.topology.create_connectivity(fdim, 0)

num_facets = local_mesh.topology.index_map(fdim).size_local

# Tag each facet with its own index: 0,1,2
facets = np.arange(num_facets, dtype=np.int32)
facet_values = np.arange(num_facets, dtype=np.int32)
facet_tags = mesh.meshtags(local_mesh, fdim, facets, facet_values)

ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
P_loc = fem.functionspace(local_mesh, ("CG", order))

p_K = fem.Function(P_loc)
k_m_loc = fem.Function(P_loc)
f_m_loc = fem.Function(P_loc)

# Local DOFs for the single cell of the template mesh
local_dofs = P_loc.dofmap.cell_dofs(0)

n_K = ufl.FacetNormal(local_mesh)
q_CG = -k_m_loc * ufl.grad(p_K)

# Build a robust edge (v0,v1) -> facet_id map once
v_to_f = local_mesh.topology.connectivity(0, fdim)
f_to_v = local_mesh.topology.connectivity(fdim, 0)
edge_to_facet = {}
for v0 in range(3):
    for fct in v_to_f.links(v0):
        verts = f_to_v.links(fct)
        for v1 in verts:
            if v1 != v0:
                edge_to_facet[(v0, v1)] = fct

# Local edge list (same as before)
edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

# Precompute geometry tensor (no grad; acts as constant input to nets)
omega_geometry_t = torch.tensor(omega_geometry, dtype=torch.float32, device=device)
edge_pair_to_id = {
    (0, 1): 0,
    (1, 2): 1,
    (2, 0): 2,
    (1, 0): 0,
    (2, 1): 1,
    (0, 2): 2,
}
def compute_subdomain_continuity(nets):
    device = next(nets[0].parameters()).device
    # 2) Per-subdomain loss accumulators  (unchanged)
    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]
    # ------------------------------------------------------------
    # 3) Loop over cells and edges
    # ------------------------------------------------------------
    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx][0]

        cell_verts_np = np.asarray(cell_verts, dtype=np.int64)
        coords = omega_geometry[cell_verts_np]
        centroid = coords.mean(axis=0)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device)

        for edge_loc, (v0_loc, v1_loc) in enumerate(edge_indices_loc):
            i0 = int(cell_verts_np[v0_loc])
            i1 = int(cell_verts_np[v1_loc])

            # Only interface edges between exactly 2 subdomains
            if (len(vertex_subdomains[i0]) < 2 or len(vertex_subdomains[i1]) < 2):
                continue

            edge_sds = set(vertex_subdomains[i0]) & set(vertex_subdomains[i1])
            sd_adj_set = edge_sds - {sd}
            if len(sd_adj_set) != 1:
                continue
            sd_adj = next(iter(sd_adj_set))

            # ---- CG flux integral on this edge for current cell (precomputed) ----
            # If missing (e.g. boundary), treat as zero
            int_qcg_edge = cg_flux.get((local_cell_idx, edge_loc), 0.0)

            # ---- find neighbor cell sharing (i0, i1) ----
            cells0 = cells_vtx.links(i0)
            cells1 = cells_vtx.links(i1)
            common_cells = np.intersect1d(cells0, cells1)
            neighbor_cells = [int(c) for c in common_cells if int(c) != local_cell_idx]
            if not neighbor_cells:
                continue
            local_cell_idx_adj = neighbor_cells[0]

            # local indices of i0, i1 in neighbor cell
            cell_verts_adj = local_cell_vertices[local_cell_idx_adj]
            try:
                loc0_adj = int(np.where(cell_verts_adj == i0)[0][0])
                loc1_adj = int(np.where(cell_verts_adj == i1)[0][0])
            except IndexError:
                # neighbor doesn't actually share both these vertices
                continue

            # local edge id for neighbor cell
            edge_loc_adj = edge_pair_to_id[(loc0_adj, loc1_adj)]

            # CG flux integral for neighbor cell on same geometric edge
            int_qcg_edge_adj = cg_flux.get((local_cell_idx_adj, edge_loc_adj), 0.0)

            # ---- geometric data for NN fluxes ----
            x0 = omega_geometry_t[i0]
            x1 = omega_geometry_t[i1]

            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            # outward normal (in plane) w.r.t. current cell
            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t - midpoint) > 0:
                n_edge = -n_edge

            net_sd = nets[sd]
            net_sd_adj = nets[sd_adj]

            # Keep gradients: these calls must NOT be in no_grad
            int_net_edge = integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
            int_net_edge_adj = integrate_edge_flux(net_sd_adj, x0, x1, -n_edge, L, xi, wi, num_sub=3)

            # q_CG integrals are plain floats (constants); nets carry grad
            res = int_net_edge + int_qcg_edge + int_net_edge_adj + int_qcg_edge_adj

            loss_sd[sd] += res**2
            count_sd[sd] += 1

    # 3) normalize by number of contributions per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd

# %%
def compute_flux_loss(nets, it=None):
    """
    nets      : list of PyTorch models, one per subdomain
    cell_flux : dict mapping cell_idx -> (int_qcg, int_f)
                where
                  int_qcg = ∫_{∂K} q_CG · n ds  (float)
                  int_f   = ∫_K f dx           (float)
    """
    device = next(nets[0].parameters()).device

    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]

    # geometry as torch constant (no grad wrt nets)
    omega_geometry_t = torch.tensor(omega_geometry, dtype=torch.float32, device=device)

    edge_indices = [(0, 1), (1, 2), (2, 0)]
    num_sub = 3  # sub-intervals per edge

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx][0]
        net = nets[sd]
        count_sd[sd] += 1

        # --- geometry (torch) ---
        cell_verts_np = np.asarray(cell_verts, dtype=np.int64)
        coords_t = omega_geometry_t[cell_verts_np]  # shape (3, gdim)
        centroid_t = coords_t.mean(dim=0)

        # ---------------- r_theta integral (NN flux over boundary) ----------------
        int_r_local = torch.zeros((), device=device)

        for (i0, i1) in edge_indices:
            x0 = coords_t[i0]
            x1 = coords_t[i1]
            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t - midpoint) > 0:
                n_edge = -n_edge

            h = 1.0 / num_sub

            for j in range(num_sub):
                s_left = j * h
                for k in range(len(xi)):
                    s = s_left + h * xi[k]
                    w = h * wi[k]

                    x_q = x0 + s * t  # point on edge, torch
                    r_q = net(x_q.unsqueeze(0))[0]  # NN flux at quadrature point

                    int_r_local = int_r_local + torch.dot(r_q, n_edge) * L * w

        # ---------------- CG flux + source (precomputed) ----------------
        int_qcg, int_f = cell_flux.get(local_cell_idx, (0.0, 0.0))

        int_qcg_t = torch.tensor(int_qcg, dtype=torch.float32, device=device)
        int_f_t   = torch.tensor(int_f, dtype=torch.float32, device=device)

        residual = int_r_local + int_qcg_t - int_f_t

        loss_sd[sd] += residual**2

    # normalize by number of cells per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd

# %%
from dolfinx import geometry
local_cell_centroid = []
for local_cell_idx, cell_verts in enumerate(tqdm(local_cell_vertices)):
    # cell_verts are global vertex indices
    coords = omega_geometry[cell_verts]  # shape (3,2)
    centroid = np.mean(coords, axis=0).reshape(1,-1)
    local_cell_centroid.append(centroid)

# Reference-cell centroid (barycenter) for common cell types
if tdim == 1:
    # interval [0, 1]
    X_ref = np.array([[0.5]], dtype=np.float64)
elif tdim == 2:
    # triangle: vertices (0,0), (1,0), (0,1)
    X_ref = np.array([[1/3, 1/3]], dtype=np.float64)
elif tdim == 3:
    # tetrahedron: vertices (0,0,0), (1,0,0), (0,1,0), (0,0,1)
    X_ref = np.array([[1/3, 1/3, 1/3]], dtype=np.float64)
else:
    raise RuntimeError("Unsupported topological dimension for centroid eval")

# UFL expression for the flux
q_ufl = -k_m * ufl.grad(p)

# Expression: evaluate q at the reference centroid in each cell
expr_q = fem.Expression(ufl.div(q_ufl), X_ref)
expr_f = fem.Expression(f_func, X_ref)

# --- your existing point / cell-location code, with centroids as X3 ---
cells = np.arange(len(local_cell_centroid), dtype=np.int32)
q_vals_local = expr_q.eval(omega, cells)
f_local = expr_f.eval(omega, cells)
# q_vals_local = expr_q.eval(omega, cells_on_proc)
div_q_local = q_vals_local[:, 0]  # drop the "num_points" axis

def compute_strong_form(nets):
    """
    Strong-form loss:
        L(theta) ≈ mean_i ( div(q + r_theta)(x_i) )^2
    evaluated at cell centroids, grouped per subdomain.
    """

    # ---- 1️⃣ Pre-assemble centroid arrays per subdomain ----
    # Convert centroids to clean (num_cells, gdim) numpy array
    X_all = np.vstack(local_cell_centroid)   # shape (num_cells, gdim)
    sd_all = np.array([cell_subdomain[i][0] for i in range(len(X_all))])

    loss_sd = []

    for sd in range(num_subdomains):

        # Mask cells belonging to this subdomain
        mask = (sd_all == sd)
        if not np.any(mask):
            loss_sd.append(torch.zeros((), device=device))
            continue

        # ---- 2️⃣ Batch points ----
        X_sd = torch.tensor(
            X_all[mask],
            dtype=torch.float32,
            device=device,
            requires_grad=True
        )  # shape (Ns, gdim)

        div_q_sd = torch.tensor(
            div_q_local[mask],
            dtype=torch.float32,
            device=device
        )  # shape (Ns,)

        f_sd = torch.tensor(
            f_local[mask],
            dtype=torch.float32,
            device=device
        )

        net = nets[sd]

        # ---- 3️⃣ Forward pass ----
        r = net(X_sd)  # shape (Ns, gdim)

        # ---- 4️⃣ Compute divergence in batch ----
        gdim = r.shape[1]
        div_r = 0.0

        for j in range(gdim):
            grad_rj = torch.autograd.grad(
                r[:, j].sum(),     # sum to get scalar
                X_sd,
                create_graph=True
            )[0]                  # shape (Ns, gdim)

            div_r = div_r + grad_rj[:, j]

        # ---- 5️⃣ Residual and loss ----
        residual = div_q_sd + div_r - f_sd  # shape (Ns,)
        loss = torch.mean(residual**2)

        loss_sd.append(loss)

    return loss_sd
# Out:
#   0%|          | 0/8192 [00:00<?, ?it/s]
# 100%|██████████| 8192/8192 [00:00<00:00, 96409.69it/s]

# %%
eps = 1e-6
W_f = 1.0e3   # flux term
W_c = 1.0e2     # continuity
W_r = 1.0e3
W_a = 1.0
# initialize once
lambdas = [torch.zeros(1, device=device) for _ in range(num_subdomains)]
rho = 10.0   # penalty parameter (tunable)
is_update_rho = False


max_epochs = 2500
import time

for epoch in range(max_epochs):

    # zero all grads
    for opt in optimizers:
        opt.zero_grad()

    # ----- forward: loss_sd -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    # loss_lce = compute_flux_loss(nets)
    loss_strong = compute_strong_form(nets)                       # 10s
    time_loss_sd = time.perf_counter() - t0

    # ----- forward: loss_continuity_sd -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    loss_continuity_sd = compute_subdomain_continuity(nets) # 30s
    time_loss_cont = time.perf_counter() - t0

    S_a = [net_i.slope_recovery_term() for net_i in nets]   # list of num_subdomains scalars
    net_norm = [l2_norm_network(nets[i], subdomain_vertices_coord[i], dx=lc) for i in range(num_subdomains)]

    # ----- gradient-based weight update every 10 epochs -----
    if epoch % 10 == 0:
        grad_f_list, grad_c_list, grad_a_list, grad_r_list = [], [], [], []

        for k in range(num_subdomains):
            net_k = nets[k]

            g_f = grad_norm_from_loss(loss_strong[k], net_k)
            g_c = grad_norm_from_loss(loss_continuity_sd[k], net_k)
            g_a = grad_norm_from_loss(S_a[k], net_k)
            g_r = grad_norm_from_loss(net_norm[k], net_k)

            grad_f_list.append(g_f)
            grad_c_list.append(g_c)
            grad_a_list.append(g_a)
            grad_r_list.append(g_r)

        # average gradient norms over subdomains
        g_f = torch.stack(grad_f_list).mean()
        g_c = torch.stack(grad_c_list).mean()
        g_a = torch.stack(grad_a_list).mean()
        g_r = torch.stack(grad_r_list).mean()

        # choose W_f as the anchor (scale is arbitrary)
        with torch.no_grad():
            W_f = (1.0 / (g_f + eps)).item()
            W_c = (1.0 / (g_c + eps)).item()
            W_a = (1.0 / (g_a + eps)).item()
            W_r = 0.01*(1.0 / (g_r + eps)).item()

    # ----- combined loss with current weights -----
    loss = [
        W_f * loss_strong[k] +
        W_c * loss_continuity_sd[k]
        # + lambdas[k] * loss_continuity_sd[k]
        + W_a * S_a[k]
        + W_r * net_norm[k]
        for k in range(num_subdomains)
    ]
    total_loss = torch.sum(torch.stack(loss))

    # ----- backward: total_loss.backward() -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    total_loss.backward()
    time_backward = time.perf_counter() - t0

    # ----- optimizer.step() loop (per subdomain) -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    for k in range(num_subdomains):
        optimizers[k].step()
    time_opt_step = time.perf_counter() - t0

    avg_F = sum(loss_strong) / len(loss_strong)
    avg_C = sum(loss_continuity_sd) / len(loss_continuity_sd)

    loss_lc_avg_arr.append(float(avg_F))
    loss_cont_avg_arr.append(float(avg_C))
    if epoch == 1:
        Lc0 = avg_C.item()

    if epoch % 10 == 0:
        print(
            f"[Epoch {epoch:4d}] "
            f"W_f={W_f:.3e}, W_c={W_c:.3e}, W_a={W_a:.3e}, W_r={W_r:.3e} | "
            f"F_avg={avg_F.item():.4e} | "
            f"C_avg={avg_C.item():.4e}"
        )

    # timings printed every epoch
    print(
        f"[Epoch {epoch:4d} timings] "
        f"loss_sd={time_loss_sd:.3f}s, "
        f"loss_cont={time_loss_cont:.3f}s, "
        f"backward={time_backward:.3f}s, "
        f"opt_step_loop={time_opt_step:.3f}s"
    )
# Out:
# [Epoch    0] W_f=6.866e-01, W_c=3.145e+05, W_a=1.221e+00, W_r=1.000e+04 | F_avg=9.0545e+00 | C_avg=1.1245e-08
# [Epoch    0 timings] loss_sd=0.192s, loss_cont=0.671s, backward=0.613s, opt_step_loop=0.007s
# [Epoch    1 timings] loss_sd=0.117s, loss_cont=0.866s, backward=0.720s, opt_step_loop=0.004s
# [Epoch    2 timings] loss_sd=0.058s, loss_cont=0.741s, backward=0.848s, opt_step_loop=0.007s
# [Epoch    3 timings] loss_sd=0.117s, loss_cont=0.767s, backward=0.754s, opt_step_loop=0.002s
# [Epoch    4 timings] loss_sd=0.068s, loss_cont=0.761s, backward=0.669s, opt_step_loop=0.003s
# [Epoch    5 timings] loss_sd=0.084s, loss_cont=0.857s, backward=0.819s, opt_step_loop=0.004s
# [Epoch    6 timings] loss_sd=0.065s, loss_cont=0.791s, backward=0.705s, opt_step_loop=0.006s
# [Epoch    7 timings] loss_sd=0.083s, loss_cont=0.751s, backward=0.705s, opt_step_loop=0.002s
# [Epoch    8 timings] loss_sd=0.084s, loss_cont=0.748s, backward=0.673s, opt_step_loop=0.003s
# [Epoch    9 timings] loss_sd=0.076s, loss_cont=0.791s, backward=0.703s, opt_step_loop=0.003s
# [Epoch   10] W_f=7.086e-01, W_c=4.268e+05, W_a=1.215e+00, W_r=1.470e-01 | F_avg=9.0505e+00 | C_avg=5.3464e-09
# [Epoch   10 timings] loss_sd=0.078s, loss_cont=0.800s, backward=0.717s, opt_step_loop=0.004s
# [Epoch   11 timings] loss_sd=0.091s, loss_cont=0.762s, backward=0.711s, opt_step_loop=0.004s
# [Epoch   12 timings] loss_sd=0.083s, loss_cont=0.788s, backward=0.725s, opt_step_loop=0.003s
# [Epoch   13 timings] loss_sd=0.083s, loss_cont=0.771s, backward=0.670s, opt_step_loop=0.002s
# [Epoch   14 timings] loss_sd=0.062s, loss_cont=0.741s, backward=0.874s, opt_step_loop=0.004s
# [Epoch   15 timings] loss_sd=0.091s, loss_cont=0.780s, backward=0.671s, opt_step_loop=0.002s
# [Epoch   16 timings] loss_sd=0.069s, loss_cont=0.750s, backward=0.671s, opt_step_loop=0.004s
# [Epoch   17 timings] loss_sd=0.067s, loss_cont=0.792s, backward=0.673s, opt_step_loop=0.003s
# [Epoch   18 timings] loss_sd=0.055s, loss_cont=0.770s, backward=0.682s, opt_step_loop=0.002s
# [Epoch   19 timings] loss_sd=0.061s, loss_cont=0.777s, backward=0.675s, opt_step_loop=0.003s
# [Epoch   20] W_f=7.176e-01, W_c=2.994e+05, W_a=1.213e+00, W_r=7.887e-02 | F_avg=9.0542e+00 | C_avg=1.0642e-08
# [Epoch   20 timings] loss_sd=0.076s, loss_cont=0.776s, backward=0.667s, opt_step_loop=0.003s
# [Epoch   21 timings] loss_sd=0.080s, loss_cont=0.801s, backward=0.722s, opt_step_loop=0.003s
# [Epoch   22 timings] loss_sd=0.075s, loss_cont=0.814s, backward=0.666s, opt_step_loop=0.002s
# [Epoch   23 timings] loss_sd=0.069s, loss_cont=0.717s, backward=0.660s, opt_step_loop=0.004s
# [Epoch   24 timings] loss_sd=0.075s, loss_cont=0.746s, backward=0.707s, opt_step_loop=0.006s
# [Epoch   25 timings] loss_sd=0.076s, loss_cont=0.787s, backward=0.796s, opt_step_loop=0.003s
# [Epoch   26 timings] loss_sd=0.071s, loss_cont=0.735s, backward=0.655s, opt_step_loop=0.003s
# [Epoch   27 timings] loss_sd=0.087s, loss_cont=1.583s, backward=0.671s, opt_step_loop=0.004s
# [Epoch   28 timings] loss_sd=0.063s, loss_cont=0.795s, backward=0.718s, opt_step_loop=0.002s
# [Epoch   29 timings] loss_sd=0.087s, loss_cont=0.821s, backward=0.762s, opt_step_loop=0.002s
# [Epoch   30] W_f=7.132e-01, W_c=2.674e+05, W_a=1.214e+00, W_r=5.937e-02 | F_avg=9.0542e+00 | C_avg=1.3952e-08
# [Epoch   30 timings] loss_sd=0.072s, loss_cont=0.770s, backward=0.673s, opt_step_loop=0.002s
# [Epoch   31 timings] loss_sd=0.088s, loss_cont=0.720s, backward=0.711s, opt_step_loop=0.003s
# [Epoch   32 timings] loss_sd=0.056s, loss_cont=0.714s, backward=0.695s, opt_step_loop=0.003s
# [Epoch   33 timings] loss_sd=0.070s, loss_cont=0.742s, backward=0.671s, opt_step_loop=0.003s
# [Epoch   34 timings] loss_sd=0.079s, loss_cont=0.750s, backward=0.674s, opt_step_loop=0.005s
# [Epoch   35 timings] loss_sd=0.083s, loss_cont=0.785s, backward=0.734s, opt_step_loop=0.004s
# [Epoch   36 timings] loss_sd=0.064s, loss_cont=0.735s, backward=0.640s, opt_step_loop=0.002s
# [Epoch   37 timings] loss_sd=0.057s, loss_cont=0.842s, backward=0.669s, opt_step_loop=0.002s
# [Epoch   38 timings] loss_sd=0.072s, loss_cont=0.754s, backward=0.670s, opt_step_loop=0.003s
# [Epoch   39 timings] loss_sd=0.067s, loss_cont=0.778s, backward=0.669s, opt_step_loop=0.002s
# [Epoch   40] W_f=7.035e-01, W_c=2.589e+05, W_a=1.217e+00, W_r=5.434e-02 | F_avg=9.0526e+00 | C_avg=1.5102e-08
# [Epoch   40 timings] loss_sd=0.076s, loss_cont=0.729s, backward=0.642s, opt_step_loop=0.002s
# [Epoch   41 timings] loss_sd=0.075s, loss_cont=0.683s, backward=0.692s, opt_step_loop=0.003s
# [Epoch   42 timings] loss_sd=0.066s, loss_cont=0.753s, backward=0.639s, opt_step_loop=0.004s
# [Epoch   43 timings] loss_sd=0.075s, loss_cont=0.763s, backward=0.694s, opt_step_loop=0.005s
# [Epoch   44 timings] loss_sd=0.076s, loss_cont=0.741s, backward=0.693s, opt_step_loop=0.003s
# [Epoch   45 timings] loss_sd=0.083s, loss_cont=0.735s, backward=0.669s, opt_step_loop=0.003s
# [Epoch   46 timings] loss_sd=0.069s, loss_cont=0.753s, backward=0.653s, opt_step_loop=0.002s
# [Epoch   47 timings] loss_sd=0.078s, loss_cont=0.741s, backward=0.691s, opt_step_loop=0.006s
# [Epoch   48 timings] loss_sd=0.067s, loss_cont=0.800s, backward=0.776s, opt_step_loop=0.004s
# [Epoch   49 timings] loss_sd=0.094s, loss_cont=0.747s, backward=0.695s, opt_step_loop=0.003s
# [Epoch   50] W_f=6.913e-01, W_c=2.585e+05, W_a=1.221e+00, W_r=5.289e-02 | F_avg=9.0501e+00 | C_avg=1.5168e-08
# [Epoch   50 timings] loss_sd=0.074s, loss_cont=0.692s, backward=0.686s, opt_step_loop=0.006s
# [Epoch   51 timings] loss_sd=0.082s, loss_cont=0.784s, backward=0.672s, opt_step_loop=0.002s
# [Epoch   52 timings] loss_sd=0.058s, loss_cont=0.766s, backward=0.637s, opt_step_loop=0.002s
# [Epoch   53 timings] loss_sd=0.091s, loss_cont=0.722s, backward=0.711s, opt_step_loop=0.003s
# [Epoch   54 timings] loss_sd=0.075s, loss_cont=0.816s, backward=0.652s, opt_step_loop=0.004s
# [Epoch   55 timings] loss_sd=0.081s, loss_cont=0.770s, backward=0.683s, opt_step_loop=0.007s
# [Epoch   56 timings] loss_sd=0.078s, loss_cont=0.717s, backward=0.705s, opt_step_loop=0.003s
# [Epoch   57 timings] loss_sd=0.086s, loss_cont=0.798s, backward=0.708s, opt_step_loop=0.004s
# [Epoch   58 timings] loss_sd=0.073s, loss_cont=0.733s, backward=0.617s, opt_step_loop=0.002s
# [Epoch   59 timings] loss_sd=0.074s, loss_cont=0.686s, backward=0.699s, opt_step_loop=0.004s
# [Epoch   60] W_f=6.778e-01, W_c=2.615e+05, W_a=1.225e+00, W_r=5.274e-02 | F_avg=9.0471e+00 | C_avg=1.4754e-08
# [Epoch   60 timings] loss_sd=0.074s, loss_cont=0.707s, backward=0.616s, opt_step_loop=0.003s
# [Epoch   61 timings] loss_sd=0.080s, loss_cont=0.667s, backward=0.680s, opt_step_loop=0.006s
# [Epoch   62 timings] loss_sd=0.077s, loss_cont=0.687s, backward=0.637s, opt_step_loop=0.002s
# [Epoch   63 timings] loss_sd=0.075s, loss_cont=0.698s, backward=0.733s, opt_step_loop=0.004s
# [Epoch   64 timings] loss_sd=0.064s, loss_cont=0.645s, backward=0.607s, opt_step_loop=0.004s
# [Epoch   65 timings] loss_sd=0.066s, loss_cont=0.669s, backward=0.624s, opt_step_loop=0.002s
# [Epoch   66 timings] loss_sd=0.080s, loss_cont=0.644s, backward=0.623s, opt_step_loop=0.002s
# [Epoch   67 timings] loss_sd=0.092s, loss_cont=0.788s, backward=0.708s, opt_step_loop=0.003s
# [Epoch   68 timings] loss_sd=0.063s, loss_cont=0.670s, backward=0.637s, opt_step_loop=0.002s
# [Epoch   69 timings] loss_sd=0.087s, loss_cont=0.710s, backward=0.664s, opt_step_loop=0.002s
# [Epoch   70] W_f=6.636e-01, W_c=2.662e+05, W_a=1.230e+00, W_r=5.315e-02 | F_avg=9.0435e+00 | C_avg=1.4137e-08
# [Epoch   70 timings] loss_sd=0.075s, loss_cont=0.647s, backward=0.664s, opt_step_loop=0.002s
# [Epoch   71 timings] loss_sd=0.083s, loss_cont=0.710s, backward=0.623s, opt_step_loop=0.003s
# [Epoch   72 timings] loss_sd=0.073s, loss_cont=0.692s, backward=0.630s, opt_step_loop=0.003s
# [Epoch   73 timings] loss_sd=0.083s, loss_cont=0.661s, backward=0.606s, opt_step_loop=0.002s
# [Epoch   74 timings] loss_sd=0.076s, loss_cont=0.685s, backward=0.616s, opt_step_loop=0.003s
# [Epoch   75 timings] loss_sd=0.096s, loss_cont=0.658s, backward=0.649s, opt_step_loop=0.003s
# [Epoch   76 timings] loss_sd=0.083s, loss_cont=0.655s, backward=0.612s, opt_step_loop=0.004s
# [Epoch   77 timings] loss_sd=0.092s, loss_cont=0.706s, backward=0.630s, opt_step_loop=0.003s
# [Epoch   78 timings] loss_sd=0.078s, loss_cont=0.692s, backward=0.636s, opt_step_loop=0.002s
# [Epoch   79 timings] loss_sd=0.088s, loss_cont=0.682s, backward=0.649s, opt_step_loop=0.003s
# [Epoch   80] W_f=6.488e-01, W_c=2.720e+05, W_a=1.236e+00, W_r=5.387e-02 | F_avg=9.0394e+00 | C_avg=1.3441e-08
# [Epoch   80 timings] loss_sd=0.079s, loss_cont=0.678s, backward=0.619s, opt_step_loop=0.002s
# [Epoch   81 timings] loss_sd=0.071s, loss_cont=0.688s, backward=0.587s, opt_step_loop=0.002s
# [Epoch   82 timings] loss_sd=0.070s, loss_cont=0.692s, backward=0.578s, opt_step_loop=0.002s
# [Epoch   83 timings] loss_sd=0.080s, loss_cont=0.683s, backward=0.655s, opt_step_loop=0.006s
# [Epoch   84 timings] loss_sd=0.067s, loss_cont=0.708s, backward=0.657s, opt_step_loop=0.003s
# [Epoch   85 timings] loss_sd=0.086s, loss_cont=0.654s, backward=0.684s, opt_step_loop=0.002s
# [Epoch   86 timings] loss_sd=0.082s, loss_cont=0.669s, backward=0.589s, opt_step_loop=0.003s
# [Epoch   87 timings] loss_sd=0.085s, loss_cont=0.692s, backward=0.588s, opt_step_loop=0.002s
# [Epoch   88 timings] loss_sd=0.069s, loss_cont=0.679s, backward=0.612s, opt_step_loop=0.002s
# [Epoch   89 timings] loss_sd=0.095s, loss_cont=0.718s, backward=0.618s, opt_step_loop=0.002s
# [Epoch   90] W_f=6.337e-01, W_c=2.785e+05, W_a=1.241e+00, W_r=5.478e-02 | F_avg=9.0348e+00 | C_avg=1.2729e-08
# [Epoch   90 timings] loss_sd=0.078s, loss_cont=1.527s, backward=0.634s, opt_step_loop=0.002s
# [Epoch   91 timings] loss_sd=0.069s, loss_cont=0.729s, backward=0.716s, opt_step_loop=0.004s
# [Epoch   92 timings] loss_sd=0.069s, loss_cont=0.726s, backward=0.656s, opt_step_loop=0.003s
# [Epoch   93 timings] loss_sd=0.080s, loss_cont=0.802s, backward=0.672s, opt_step_loop=0.002s
# [Epoch   94 timings] loss_sd=0.074s, loss_cont=0.771s, backward=0.698s, opt_step_loop=0.002s
# [Epoch   95 timings] loss_sd=0.086s, loss_cont=0.767s, backward=0.710s, opt_step_loop=0.005s
# [Epoch   96 timings] loss_sd=0.083s, loss_cont=0.761s, backward=0.657s, opt_step_loop=0.003s
# [Epoch   97 timings] loss_sd=0.084s, loss_cont=0.772s, backward=0.699s, opt_step_loop=0.003s
# [Epoch   98 timings] loss_sd=0.076s, loss_cont=0.814s, backward=0.717s, opt_step_loop=0.002s
# [Epoch   99 timings] loss_sd=0.089s, loss_cont=0.711s, backward=0.653s, opt_step_loop=0.002s
# [Epoch  100] W_f=6.184e-01, W_c=2.854e+05, W_a=1.247e+00, W_r=5.585e-02 | F_avg=9.0297e+00 | C_avg=1.2038e-08
# [Epoch  100 timings] loss_sd=0.073s, loss_cont=0.725s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  101 timings] loss_sd=0.081s, loss_cont=0.786s, backward=0.732s, opt_step_loop=0.004s
# [Epoch  102 timings] loss_sd=0.061s, loss_cont=0.710s, backward=0.681s, opt_step_loop=0.002s
# [Epoch  103 timings] loss_sd=0.077s, loss_cont=0.751s, backward=0.700s, opt_step_loop=0.002s
# [Epoch  104 timings] loss_sd=0.053s, loss_cont=0.725s, backward=0.597s, opt_step_loop=0.003s
# [Epoch  105 timings] loss_sd=0.072s, loss_cont=0.720s, backward=0.655s, opt_step_loop=0.003s
# [Epoch  106 timings] loss_sd=0.055s, loss_cont=0.780s, backward=0.640s, opt_step_loop=0.002s
# [Epoch  107 timings] loss_sd=0.090s, loss_cont=0.776s, backward=1.052s, opt_step_loop=0.002s
# [Epoch  108 timings] loss_sd=0.070s, loss_cont=0.751s, backward=0.673s, opt_step_loop=0.004s
# [Epoch  109 timings] loss_sd=0.074s, loss_cont=0.903s, backward=0.698s, opt_step_loop=0.002s
# [Epoch  110] W_f=6.030e-01, W_c=2.922e+05, W_a=1.254e+00, W_r=5.700e-02 | F_avg=9.0240e+00 | C_avg=1.1400e-08
# [Epoch  110 timings] loss_sd=0.085s, loss_cont=0.673s, backward=0.658s, opt_step_loop=0.003s
# [Epoch  111 timings] loss_sd=0.094s, loss_cont=0.690s, backward=0.627s, opt_step_loop=0.002s
# [Epoch  112 timings] loss_sd=0.064s, loss_cont=0.678s, backward=0.679s, opt_step_loop=0.003s
# [Epoch  113 timings] loss_sd=0.088s, loss_cont=0.686s, backward=0.714s, opt_step_loop=0.002s
# [Epoch  114 timings] loss_sd=0.062s, loss_cont=0.683s, backward=0.634s, opt_step_loop=0.004s
# [Epoch  115 timings] loss_sd=0.092s, loss_cont=0.714s, backward=0.617s, opt_step_loop=0.004s
# [Epoch  116 timings] loss_sd=0.063s, loss_cont=0.770s, backward=0.662s, opt_step_loop=0.003s
# [Epoch  117 timings] loss_sd=0.080s, loss_cont=0.739s, backward=0.732s, opt_step_loop=0.003s
# [Epoch  118 timings] loss_sd=0.080s, loss_cont=0.663s, backward=0.673s, opt_step_loop=0.002s
# [Epoch  119 timings] loss_sd=0.075s, loss_cont=0.772s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  120] W_f=5.876e-01, W_c=2.984e+05, W_a=1.260e+00, W_r=5.817e-02 | F_avg=9.0178e+00 | C_avg=1.0844e-08
# [Epoch  120 timings] loss_sd=0.078s, loss_cont=0.728s, backward=0.746s, opt_step_loop=0.003s
# [Epoch  121 timings] loss_sd=0.063s, loss_cont=0.746s, backward=0.720s, opt_step_loop=0.002s
# [Epoch  122 timings] loss_sd=0.050s, loss_cont=0.765s, backward=0.636s, opt_step_loop=0.003s
# [Epoch  123 timings] loss_sd=0.073s, loss_cont=0.662s, backward=0.638s, opt_step_loop=0.008s
# [Epoch  124 timings] loss_sd=0.085s, loss_cont=0.752s, backward=0.673s, opt_step_loop=0.003s
# [Epoch  125 timings] loss_sd=0.089s, loss_cont=0.763s, backward=0.676s, opt_step_loop=0.002s
# [Epoch  126 timings] loss_sd=0.075s, loss_cont=0.784s, backward=0.668s, opt_step_loop=0.002s
# [Epoch  127 timings] loss_sd=0.066s, loss_cont=0.758s, backward=0.670s, opt_step_loop=0.002s
# [Epoch  128 timings] loss_sd=0.057s, loss_cont=0.734s, backward=0.647s, opt_step_loop=0.003s
# [Epoch  129 timings] loss_sd=0.088s, loss_cont=0.678s, backward=0.728s, opt_step_loop=0.005s
# [Epoch  130] W_f=5.723e-01, W_c=3.033e+05, W_a=1.267e+00, W_r=5.925e-02 | F_avg=9.0109e+00 | C_avg=1.0394e-08
# [Epoch  130 timings] loss_sd=0.077s, loss_cont=0.788s, backward=0.635s, opt_step_loop=0.002s
# [Epoch  131 timings] loss_sd=0.087s, loss_cont=0.689s, backward=0.682s, opt_step_loop=0.002s
# [Epoch  132 timings] loss_sd=0.083s, loss_cont=0.735s, backward=0.674s, opt_step_loop=0.002s
# [Epoch  133 timings] loss_sd=0.074s, loss_cont=0.745s, backward=0.662s, opt_step_loop=0.003s
# [Epoch  134 timings] loss_sd=0.088s, loss_cont=0.743s, backward=0.642s, opt_step_loop=0.002s
# [Epoch  135 timings] loss_sd=0.070s, loss_cont=0.701s, backward=0.721s, opt_step_loop=0.003s
# [Epoch  136 timings] loss_sd=0.049s, loss_cont=0.644s, backward=0.588s, opt_step_loop=0.003s
# [Epoch  137 timings] loss_sd=0.102s, loss_cont=0.664s, backward=0.727s, opt_step_loop=0.002s
# [Epoch  138 timings] loss_sd=0.088s, loss_cont=0.764s, backward=0.648s, opt_step_loop=0.003s
# [Epoch  139 timings] loss_sd=0.061s, loss_cont=0.763s, backward=0.708s, opt_step_loop=0.002s
# [Epoch  140] W_f=5.571e-01, W_c=3.062e+05, W_a=1.274e+00, W_r=6.005e-02 | F_avg=9.0034e+00 | C_avg=1.0068e-08
# [Epoch  140 timings] loss_sd=0.055s, loss_cont=0.754s, backward=0.706s, opt_step_loop=0.002s
# [Epoch  141 timings] loss_sd=0.067s, loss_cont=0.738s, backward=0.681s, opt_step_loop=0.002s
# [Epoch  142 timings] loss_sd=0.055s, loss_cont=1.636s, backward=0.622s, opt_step_loop=0.002s
# [Epoch  143 timings] loss_sd=0.089s, loss_cont=0.712s, backward=0.663s, opt_step_loop=0.003s
# [Epoch  144 timings] loss_sd=0.065s, loss_cont=0.822s, backward=0.641s, opt_step_loop=0.005s
# [Epoch  145 timings] loss_sd=0.071s, loss_cont=0.777s, backward=0.637s, opt_step_loop=0.002s
# [Epoch  146 timings] loss_sd=0.063s, loss_cont=0.756s, backward=0.629s, opt_step_loop=0.002s
# [Epoch  147 timings] loss_sd=0.059s, loss_cont=0.753s, backward=0.695s, opt_step_loop=0.003s
# [Epoch  148 timings] loss_sd=0.071s, loss_cont=0.880s, backward=0.687s, opt_step_loop=0.002s
# [Epoch  149 timings] loss_sd=0.090s, loss_cont=0.745s, backward=0.662s, opt_step_loop=0.002s
# [Epoch  150] W_f=5.421e-01, W_c=3.066e+05, W_a=1.281e+00, W_r=6.031e-02 | F_avg=8.9951e+00 | C_avg=9.8717e-09
# [Epoch  150 timings] loss_sd=0.070s, loss_cont=0.770s, backward=0.650s, opt_step_loop=0.002s
# [Epoch  151 timings] loss_sd=0.067s, loss_cont=0.823s, backward=0.675s, opt_step_loop=0.002s
# [Epoch  152 timings] loss_sd=0.054s, loss_cont=0.697s, backward=0.683s, opt_step_loop=0.002s
# [Epoch  153 timings] loss_sd=0.076s, loss_cont=0.731s, backward=0.710s, opt_step_loop=0.002s
# [Epoch  154 timings] loss_sd=0.068s, loss_cont=0.782s, backward=0.738s, opt_step_loop=0.002s
# [Epoch  155 timings] loss_sd=0.055s, loss_cont=0.776s, backward=0.670s, opt_step_loop=0.003s
# [Epoch  156 timings] loss_sd=0.058s, loss_cont=0.733s, backward=0.644s, opt_step_loop=0.003s
# [Epoch  157 timings] loss_sd=0.063s, loss_cont=0.758s, backward=0.741s, opt_step_loop=0.002s
# [Epoch  158 timings] loss_sd=0.061s, loss_cont=0.746s, backward=0.721s, opt_step_loop=0.002s
# [Epoch  159 timings] loss_sd=0.072s, loss_cont=0.756s, backward=0.664s, opt_step_loop=0.005s
# [Epoch  160] W_f=5.275e-01, W_c=3.048e+05, W_a=1.289e+00, W_r=5.902e-02 | F_avg=8.9861e+00 | C_avg=9.7995e-09
# [Epoch  160 timings] loss_sd=0.068s, loss_cont=0.805s, backward=0.655s, opt_step_loop=0.004s
# [Epoch  161 timings] loss_sd=0.070s, loss_cont=0.755s, backward=0.652s, opt_step_loop=0.003s
# [Epoch  162 timings] loss_sd=0.068s, loss_cont=0.725s, backward=0.678s, opt_step_loop=0.003s
# [Epoch  163 timings] loss_sd=0.074s, loss_cont=0.727s, backward=0.682s, opt_step_loop=0.003s
# [Epoch  164 timings] loss_sd=0.089s, loss_cont=0.732s, backward=0.684s, opt_step_loop=0.006s
# [Epoch  165 timings] loss_sd=0.076s, loss_cont=0.694s, backward=0.680s, opt_step_loop=0.002s
# [Epoch  166 timings] loss_sd=0.068s, loss_cont=0.726s, backward=0.630s, opt_step_loop=0.003s
# [Epoch  167 timings] loss_sd=0.093s, loss_cont=0.738s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  168 timings] loss_sd=0.072s, loss_cont=0.720s, backward=0.623s, opt_step_loop=0.003s
# [Epoch  169 timings] loss_sd=0.068s, loss_cont=0.684s, backward=0.722s, opt_step_loop=0.003s
# [Epoch  170] W_f=5.131e-01, W_c=3.013e+05, W_a=1.296e+00, W_r=5.475e-02 | F_avg=8.9764e+00 | C_avg=9.8311e-09
# [Epoch  170 timings] loss_sd=0.074s, loss_cont=0.739s, backward=0.804s, opt_step_loop=0.003s
# [Epoch  171 timings] loss_sd=0.076s, loss_cont=0.842s, backward=0.655s, opt_step_loop=0.006s
# [Epoch  172 timings] loss_sd=0.077s, loss_cont=0.717s, backward=0.616s, opt_step_loop=0.002s
# [Epoch  173 timings] loss_sd=0.085s, loss_cont=0.691s, backward=0.654s, opt_step_loop=0.002s
# [Epoch  174 timings] loss_sd=0.063s, loss_cont=0.670s, backward=0.646s, opt_step_loop=0.002s
# [Epoch  175 timings] loss_sd=0.074s, loss_cont=0.720s, backward=0.689s, opt_step_loop=0.002s
# [Epoch  176 timings] loss_sd=0.063s, loss_cont=0.865s, backward=0.795s, opt_step_loop=0.003s
# [Epoch  177 timings] loss_sd=0.070s, loss_cont=0.669s, backward=0.658s, opt_step_loop=0.008s
# [Epoch  178 timings] loss_sd=0.066s, loss_cont=0.675s, backward=0.617s, opt_step_loop=0.005s
# [Epoch  179 timings] loss_sd=0.057s, loss_cont=0.697s, backward=0.671s, opt_step_loop=0.002s
# [Epoch  180] W_f=4.991e-01, W_c=2.971e+05, W_a=1.304e+00, W_r=4.942e-02 | F_avg=8.9659e+00 | C_avg=9.9333e-09
# [Epoch  180 timings] loss_sd=0.064s, loss_cont=0.672s, backward=0.663s, opt_step_loop=0.002s
# [Epoch  181 timings] loss_sd=0.080s, loss_cont=0.680s, backward=0.680s, opt_step_loop=0.004s
# [Epoch  182 timings] loss_sd=0.063s, loss_cont=0.692s, backward=0.608s, opt_step_loop=0.003s
# [Epoch  183 timings] loss_sd=0.073s, loss_cont=0.696s, backward=0.644s, opt_step_loop=0.003s
# [Epoch  184 timings] loss_sd=0.070s, loss_cont=0.682s, backward=0.672s, opt_step_loop=0.003s
# [Epoch  185 timings] loss_sd=0.064s, loss_cont=0.664s, backward=0.643s, opt_step_loop=0.002s
# [Epoch  186 timings] loss_sd=0.076s, loss_cont=0.670s, backward=0.584s, opt_step_loop=0.003s
# [Epoch  187 timings] loss_sd=0.055s, loss_cont=0.674s, backward=0.637s, opt_step_loop=0.003s
# [Epoch  188 timings] loss_sd=0.079s, loss_cont=0.674s, backward=0.620s, opt_step_loop=0.004s
# [Epoch  189 timings] loss_sd=0.073s, loss_cont=0.667s, backward=0.627s, opt_step_loop=0.003s
# [Epoch  190] W_f=4.855e-01, W_c=2.930e+05, W_a=1.312e+00, W_r=4.421e-02 | F_avg=8.9544e+00 | C_avg=1.0063e-08
# [Epoch  190 timings] loss_sd=0.082s, loss_cont=0.683s, backward=0.603s, opt_step_loop=0.002s
# [Epoch  191 timings] loss_sd=0.068s, loss_cont=0.673s, backward=0.624s, opt_step_loop=0.003s
# [Epoch  192 timings] loss_sd=0.076s, loss_cont=0.642s, backward=0.634s, opt_step_loop=0.002s
# [Epoch  193 timings] loss_sd=0.076s, loss_cont=0.663s, backward=0.642s, opt_step_loop=0.003s
# [Epoch  194 timings] loss_sd=0.069s, loss_cont=0.660s, backward=0.590s, opt_step_loop=0.002s
# [Epoch  195 timings] loss_sd=0.069s, loss_cont=0.672s, backward=0.623s, opt_step_loop=0.007s
# [Epoch  196 timings] loss_sd=0.065s, loss_cont=0.667s, backward=0.995s, opt_step_loop=0.002s
# [Epoch  197 timings] loss_sd=0.057s, loss_cont=0.716s, backward=0.717s, opt_step_loop=0.002s
# [Epoch  198 timings] loss_sd=0.047s, loss_cont=0.700s, backward=0.956s, opt_step_loop=0.004s
# [Epoch  199 timings] loss_sd=0.540s, loss_cont=0.691s, backward=0.659s, opt_step_loop=0.002s
# [Epoch  200] W_f=4.723e-01, W_c=2.897e+05, W_a=1.321e+00, W_r=3.935e-02 | F_avg=8.9421e+00 | C_avg=1.0172e-08
# [Epoch  200 timings] loss_sd=0.067s, loss_cont=0.718s, backward=0.615s, opt_step_loop=0.002s
# [Epoch  201 timings] loss_sd=0.075s, loss_cont=0.763s, backward=0.660s, opt_step_loop=0.002s
# [Epoch  202 timings] loss_sd=0.055s, loss_cont=0.746s, backward=0.596s, opt_step_loop=0.002s
# [Epoch  203 timings] loss_sd=0.117s, loss_cont=0.827s, backward=0.679s, opt_step_loop=0.003s
# [Epoch  204 timings] loss_sd=0.055s, loss_cont=0.689s, backward=0.716s, opt_step_loop=0.003s
# [Epoch  205 timings] loss_sd=0.086s, loss_cont=0.696s, backward=0.660s, opt_step_loop=0.003s
# [Epoch  206 timings] loss_sd=0.063s, loss_cont=0.684s, backward=0.782s, opt_step_loop=0.003s
# [Epoch  207 timings] loss_sd=0.075s, loss_cont=0.679s, backward=0.680s, opt_step_loop=0.003s
# [Epoch  208 timings] loss_sd=0.063s, loss_cont=0.739s, backward=0.685s, opt_step_loop=0.002s
# [Epoch  209 timings] loss_sd=0.086s, loss_cont=0.696s, backward=0.695s, opt_step_loop=0.002s
# [Epoch  210] W_f=4.596e-01, W_c=2.874e+05, W_a=1.329e+00, W_r=3.492e-02 | F_avg=8.9288e+00 | C_avg=1.0214e-08
# [Epoch  210 timings] loss_sd=0.075s, loss_cont=0.820s, backward=0.676s, opt_step_loop=0.002s
# [Epoch  211 timings] loss_sd=0.074s, loss_cont=0.670s, backward=0.736s, opt_step_loop=0.003s
# [Epoch  212 timings] loss_sd=0.053s, loss_cont=0.667s, backward=0.611s, opt_step_loop=0.003s
# [Epoch  213 timings] loss_sd=0.097s, loss_cont=0.764s, backward=0.704s, opt_step_loop=0.002s
# [Epoch  214 timings] loss_sd=0.063s, loss_cont=0.683s, backward=0.640s, opt_step_loop=0.003s
# [Epoch  215 timings] loss_sd=0.071s, loss_cont=0.735s, backward=0.789s, opt_step_loop=0.002s
# [Epoch  216 timings] loss_sd=0.071s, loss_cont=0.692s, backward=0.642s, opt_step_loop=0.002s
# [Epoch  217 timings] loss_sd=0.068s, loss_cont=0.677s, backward=1.012s, opt_step_loop=0.002s
# [Epoch  218 timings] loss_sd=0.064s, loss_cont=0.669s, backward=0.657s, opt_step_loop=0.002s
# [Epoch  219 timings] loss_sd=0.070s, loss_cont=0.774s, backward=0.676s, opt_step_loop=0.003s
# [Epoch  220] W_f=4.473e-01, W_c=2.866e+05, W_a=1.338e+00, W_r=3.093e-02 | F_avg=8.9144e+00 | C_avg=1.0152e-08
# [Epoch  220 timings] loss_sd=0.061s, loss_cont=0.681s, backward=0.631s, opt_step_loop=0.002s
# [Epoch  221 timings] loss_sd=0.284s, loss_cont=0.790s, backward=0.886s, opt_step_loop=0.003s
# [Epoch  222 timings] loss_sd=0.066s, loss_cont=0.675s, backward=0.718s, opt_step_loop=0.003s
# [Epoch  223 timings] loss_sd=0.051s, loss_cont=0.705s, backward=0.644s, opt_step_loop=0.004s
# [Epoch  224 timings] loss_sd=0.068s, loss_cont=0.732s, backward=0.640s, opt_step_loop=0.004s
# [Epoch  225 timings] loss_sd=0.071s, loss_cont=0.707s, backward=0.609s, opt_step_loop=0.002s
# [Epoch  226 timings] loss_sd=0.081s, loss_cont=0.759s, backward=0.620s, opt_step_loop=0.002s
# [Epoch  227 timings] loss_sd=0.053s, loss_cont=0.708s, backward=0.650s, opt_step_loop=0.002s
# [Epoch  228 timings] loss_sd=0.071s, loss_cont=0.740s, backward=0.672s, opt_step_loop=0.002s
# [Epoch  229 timings] loss_sd=0.058s, loss_cont=0.702s, backward=0.576s, opt_step_loop=0.002s
# [Epoch  230] W_f=4.354e-01, W_c=2.874e+05, W_a=1.347e+00, W_r=2.736e-02 | F_avg=8.8990e+00 | C_avg=9.9568e-09
# [Epoch  230 timings] loss_sd=0.058s, loss_cont=0.740s, backward=0.605s, opt_step_loop=0.002s
# [Epoch  231 timings] loss_sd=0.081s, loss_cont=0.701s, backward=0.880s, opt_step_loop=0.002s
# [Epoch  232 timings] loss_sd=0.063s, loss_cont=0.704s, backward=0.613s, opt_step_loop=0.004s
# [Epoch  233 timings] loss_sd=0.058s, loss_cont=0.770s, backward=0.620s, opt_step_loop=0.002s
# [Epoch  234 timings] loss_sd=0.074s, loss_cont=0.730s, backward=0.679s, opt_step_loop=0.002s
# [Epoch  235 timings] loss_sd=0.071s, loss_cont=0.683s, backward=0.756s, opt_step_loop=0.004s
# [Epoch  236 timings] loss_sd=0.068s, loss_cont=0.700s, backward=0.612s, opt_step_loop=0.003s
# [Epoch  237 timings] loss_sd=0.062s, loss_cont=0.766s, backward=0.689s, opt_step_loop=0.002s
# [Epoch  238 timings] loss_sd=0.066s, loss_cont=0.680s, backward=0.608s, opt_step_loop=0.002s
# [Epoch  239 timings] loss_sd=0.067s, loss_cont=0.787s, backward=0.632s, opt_step_loop=0.002s
# [Epoch  240] W_f=4.240e-01, W_c=2.901e+05, W_a=1.356e+00, W_r=2.419e-02 | F_avg=8.8824e+00 | C_avg=9.6180e-09
# [Epoch  240 timings] loss_sd=0.068s, loss_cont=0.696s, backward=0.680s, opt_step_loop=0.002s
# [Epoch  241 timings] loss_sd=0.084s, loss_cont=0.716s, backward=0.678s, opt_step_loop=0.002s
# [Epoch  242 timings] loss_sd=0.064s, loss_cont=1.555s, backward=0.612s, opt_step_loop=0.007s
# [Epoch  243 timings] loss_sd=0.090s, loss_cont=0.697s, backward=0.691s, opt_step_loop=0.003s
# [Epoch  244 timings] loss_sd=0.072s, loss_cont=0.698s, backward=0.623s, opt_step_loop=0.002s
# [Epoch  245 timings] loss_sd=0.072s, loss_cont=0.708s, backward=0.878s, opt_step_loop=0.002s
# [Epoch  246 timings] loss_sd=0.080s, loss_cont=0.689s, backward=0.630s, opt_step_loop=0.003s
# [Epoch  247 timings] loss_sd=0.088s, loss_cont=0.810s, backward=0.647s, opt_step_loop=0.002s
# [Epoch  248 timings] loss_sd=0.072s, loss_cont=0.713s, backward=0.588s, opt_step_loop=0.002s
# [Epoch  249 timings] loss_sd=0.152s, loss_cont=0.746s, backward=0.803s, opt_step_loop=0.002s
# [Epoch  250] W_f=4.131e-01, W_c=2.948e+05, W_a=1.366e+00, W_r=2.137e-02 | F_avg=8.8645e+00 | C_avg=9.1376e-09
# [Epoch  250 timings] loss_sd=0.080s, loss_cont=0.714s, backward=0.639s, opt_step_loop=0.003s
# [Epoch  251 timings] loss_sd=0.086s, loss_cont=0.758s, backward=0.607s, opt_step_loop=0.002s
# [Epoch  252 timings] loss_sd=0.061s, loss_cont=0.662s, backward=0.720s, opt_step_loop=0.003s
# [Epoch  253 timings] loss_sd=0.073s, loss_cont=0.703s, backward=0.838s, opt_step_loop=0.003s
# [Epoch  254 timings] loss_sd=0.074s, loss_cont=0.745s, backward=0.661s, opt_step_loop=0.003s
# [Epoch  255 timings] loss_sd=0.074s, loss_cont=0.737s, backward=0.640s, opt_step_loop=0.002s
# [Epoch  256 timings] loss_sd=0.056s, loss_cont=0.773s, backward=0.645s, opt_step_loop=0.004s
# [Epoch  257 timings] loss_sd=0.073s, loss_cont=0.686s, backward=0.628s, opt_step_loop=0.003s
# [Epoch  258 timings] loss_sd=0.071s, loss_cont=0.790s, backward=0.618s, opt_step_loop=0.004s
# [Epoch  259 timings] loss_sd=0.199s, loss_cont=0.665s, backward=0.966s, opt_step_loop=0.002s
# [Epoch  260] W_f=4.027e-01, W_c=3.018e+05, W_a=1.375e+00, W_r=1.889e-02 | F_avg=8.8454e+00 | C_avg=8.5320e-09
# [Epoch  260 timings] loss_sd=0.092s, loss_cont=0.737s, backward=0.605s, opt_step_loop=0.003s
# [Epoch  261 timings] loss_sd=0.062s, loss_cont=0.790s, backward=0.636s, opt_step_loop=0.003s
# [Epoch  262 timings] loss_sd=0.077s, loss_cont=0.697s, backward=0.734s, opt_step_loop=0.006s
# [Epoch  263 timings] loss_sd=0.076s, loss_cont=0.726s, backward=0.619s, opt_step_loop=0.004s
# [Epoch  264 timings] loss_sd=0.059s, loss_cont=0.699s, backward=0.966s, opt_step_loop=0.005s
# [Epoch  265 timings] loss_sd=0.084s, loss_cont=0.691s, backward=0.629s, opt_step_loop=0.002s
# [Epoch  266 timings] loss_sd=0.054s, loss_cont=0.765s, backward=0.674s, opt_step_loop=0.003s
# [Epoch  267 timings] loss_sd=0.063s, loss_cont=0.722s, backward=0.673s, opt_step_loop=0.002s
# [Epoch  268 timings] loss_sd=0.059s, loss_cont=0.791s, backward=0.670s, opt_step_loop=0.003s
# [Epoch  269 timings] loss_sd=0.066s, loss_cont=0.744s, backward=0.662s, opt_step_loop=0.003s
# [Epoch  270] W_f=3.927e-01, W_c=3.114e+05, W_a=1.385e+00, W_r=1.671e-02 | F_avg=8.8248e+00 | C_avg=7.8295e-09
# [Epoch  270 timings] loss_sd=0.062s, loss_cont=0.696s, backward=0.816s, opt_step_loop=0.003s
# [Epoch  271 timings] loss_sd=0.060s, loss_cont=0.691s, backward=0.601s, opt_step_loop=0.002s
# [Epoch  272 timings] loss_sd=0.081s, loss_cont=0.763s, backward=0.610s, opt_step_loop=0.002s
# [Epoch  273 timings] loss_sd=0.066s, loss_cont=0.693s, backward=0.719s, opt_step_loop=0.004s
# [Epoch  274 timings] loss_sd=0.125s, loss_cont=0.680s, backward=0.632s, opt_step_loop=0.002s
# [Epoch  275 timings] loss_sd=0.076s, loss_cont=0.740s, backward=0.792s, opt_step_loop=0.003s
# [Epoch  276 timings] loss_sd=0.064s, loss_cont=0.664s, backward=0.630s, opt_step_loop=0.002s
# [Epoch  277 timings] loss_sd=0.073s, loss_cont=0.792s, backward=0.630s, opt_step_loop=0.004s
# [Epoch  278 timings] loss_sd=0.070s, loss_cont=0.724s, backward=0.617s, opt_step_loop=0.004s
# [Epoch  279 timings] loss_sd=0.091s, loss_cont=0.711s, backward=0.645s, opt_step_loop=0.003s
# [Epoch  280] W_f=3.832e-01, W_c=3.239e+05, W_a=1.395e+00, W_r=1.479e-02 | F_avg=8.8029e+00 | C_avg=7.0664e-09
# [Epoch  280 timings] loss_sd=0.064s, loss_cont=0.671s, backward=0.722s, opt_step_loop=0.002s
# [Epoch  281 timings] loss_sd=0.069s, loss_cont=0.680s, backward=0.615s, opt_step_loop=0.002s
# [Epoch  282 timings] loss_sd=0.061s, loss_cont=0.783s, backward=0.608s, opt_step_loop=0.002s
# [Epoch  283 timings] loss_sd=0.080s, loss_cont=0.707s, backward=0.647s, opt_step_loop=0.003s
# [Epoch  284 timings] loss_sd=0.155s, loss_cont=0.734s, backward=0.910s, opt_step_loop=0.002s
# [Epoch  285 timings] loss_sd=0.073s, loss_cont=0.653s, backward=0.990s, opt_step_loop=0.003s
# [Epoch  286 timings] loss_sd=0.080s, loss_cont=0.666s, backward=0.790s, opt_step_loop=0.003s
# [Epoch  287 timings] loss_sd=0.045s, loss_cont=0.685s, backward=0.613s, opt_step_loop=0.002s
# [Epoch  288 timings] loss_sd=0.301s, loss_cont=0.765s, backward=0.708s, opt_step_loop=0.003s
# [Epoch  289 timings] loss_sd=0.078s, loss_cont=0.673s, backward=0.926s, opt_step_loop=0.002s
# [Epoch  290] W_f=3.742e-01, W_c=3.397e+05, W_a=1.405e+00, W_r=1.312e-02 | F_avg=8.7795e+00 | C_avg=6.2832e-09
# [Epoch  290 timings] loss_sd=0.054s, loss_cont=0.669s, backward=0.628s, opt_step_loop=0.002s
# [Epoch  291 timings] loss_sd=0.072s, loss_cont=0.768s, backward=0.674s, opt_step_loop=0.003s
# [Epoch  292 timings] loss_sd=0.069s, loss_cont=0.692s, backward=0.843s, opt_step_loop=0.002s
# [Epoch  293 timings] loss_sd=0.073s, loss_cont=0.729s, backward=0.750s, opt_step_loop=0.003s
# [Epoch  294 timings] loss_sd=0.064s, loss_cont=0.676s, backward=0.763s, opt_step_loop=0.002s
# [Epoch  295 timings] loss_sd=0.075s, loss_cont=0.678s, backward=0.650s, opt_step_loop=0.003s
# [Epoch  296 timings] loss_sd=0.060s, loss_cont=0.812s, backward=0.650s, opt_step_loop=0.004s
# [Epoch  297 timings] loss_sd=0.081s, loss_cont=0.717s, backward=0.614s, opt_step_loop=0.003s
# [Epoch  298 timings] loss_sd=0.072s, loss_cont=0.758s, backward=0.648s, opt_step_loop=0.003s
# [Epoch  299 timings] loss_sd=0.069s, loss_cont=0.689s, backward=0.742s, opt_step_loop=0.002s
# [Epoch  300] W_f=3.658e-01, W_c=3.589e+05, W_a=1.416e+00, W_r=1.166e-02 | F_avg=8.7546e+00 | C_avg=5.5199e-09
# [Epoch  300 timings] loss_sd=0.068s, loss_cont=0.703s, backward=0.615s, opt_step_loop=0.002s
# [Epoch  301 timings] loss_sd=0.063s, loss_cont=0.736s, backward=0.674s, opt_step_loop=0.002s
# [Epoch  302 timings] loss_sd=0.060s, loss_cont=0.707s, backward=0.626s, opt_step_loop=0.002s
# [Epoch  303 timings] loss_sd=0.075s, loss_cont=0.795s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  304 timings] loss_sd=0.079s, loss_cont=0.761s, backward=0.582s, opt_step_loop=0.003s
# [Epoch  305 timings] loss_sd=0.070s, loss_cont=0.756s, backward=0.689s, opt_step_loop=0.004s
# [Epoch  306 timings] loss_sd=0.059s, loss_cont=0.712s, backward=0.614s, opt_step_loop=0.002s
# [Epoch  307 timings] loss_sd=0.075s, loss_cont=0.830s, backward=0.652s, opt_step_loop=0.002s
# [Epoch  308 timings] loss_sd=0.060s, loss_cont=0.721s, backward=0.857s, opt_step_loop=0.003s
# [Epoch  309 timings] loss_sd=0.063s, loss_cont=0.715s, backward=0.660s, opt_step_loop=0.005s
# [Epoch  310] W_f=3.578e-01, W_c=3.818e+05, W_a=1.426e+00, W_r=1.039e-02 | F_avg=8.7282e+00 | C_avg=4.8108e-09
# [Epoch  310 timings] loss_sd=0.065s, loss_cont=0.707s, backward=0.688s, opt_step_loop=0.006s
# [Epoch  311 timings] loss_sd=0.072s, loss_cont=0.743s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  312 timings] loss_sd=0.080s, loss_cont=0.833s, backward=0.647s, opt_step_loop=0.005s
# [Epoch  313 timings] loss_sd=0.083s, loss_cont=0.722s, backward=0.931s, opt_step_loop=0.002s
# [Epoch  314 timings] loss_sd=0.087s, loss_cont=0.728s, backward=0.644s, opt_step_loop=0.002s
# [Epoch  315 timings] loss_sd=0.068s, loss_cont=0.708s, backward=0.764s, opt_step_loop=0.005s
# [Epoch  316 timings] loss_sd=0.065s, loss_cont=0.773s, backward=0.891s, opt_step_loop=0.002s
# [Epoch  317 timings] loss_sd=0.102s, loss_cont=0.791s, backward=0.841s, opt_step_loop=0.002s
# [Epoch  318 timings] loss_sd=0.091s, loss_cont=0.791s, backward=0.697s, opt_step_loop=0.003s
# [Epoch  319 timings] loss_sd=0.065s, loss_cont=0.896s, backward=0.760s, opt_step_loop=0.002s
# [Epoch  320] W_f=3.504e-01, W_c=4.078e+05, W_a=1.437e+00, W_r=9.278e-03 | F_avg=8.7001e+00 | C_avg=4.1809e-09
# [Epoch  320 timings] loss_sd=0.071s, loss_cont=1.746s, backward=0.710s, opt_step_loop=0.003s
# [Epoch  321 timings] loss_sd=0.087s, loss_cont=0.813s, backward=0.736s, opt_step_loop=0.003s
# [Epoch  322 timings] loss_sd=0.063s, loss_cont=0.923s, backward=0.682s, opt_step_loop=0.003s
# [Epoch  323 timings] loss_sd=0.078s, loss_cont=0.720s, backward=0.768s, opt_step_loop=0.002s
# [Epoch  324 timings] loss_sd=0.082s, loss_cont=0.846s, backward=0.725s, opt_step_loop=0.002s
# [Epoch  325 timings] loss_sd=0.102s, loss_cont=0.761s, backward=0.705s, opt_step_loop=0.002s
# [Epoch  326 timings] loss_sd=0.335s, loss_cont=0.811s, backward=0.765s, opt_step_loop=0.003s
# [Epoch  327 timings] loss_sd=0.076s, loss_cont=0.724s, backward=1.150s, opt_step_loop=0.002s
# [Epoch  328 timings] loss_sd=0.054s, loss_cont=0.747s, backward=0.673s, opt_step_loop=0.003s
# [Epoch  329 timings] loss_sd=0.084s, loss_cont=0.827s, backward=0.714s, opt_step_loop=0.002s
# [Epoch  330] W_f=3.435e-01, W_c=4.363e+05, W_a=1.448e+00, W_r=8.313e-03 | F_avg=8.6705e+00 | C_avg=3.6429e-09
# [Epoch  330 timings] loss_sd=0.058s, loss_cont=0.738s, backward=1.106s, opt_step_loop=0.004s
# [Epoch  331 timings] loss_sd=0.075s, loss_cont=0.793s, backward=0.714s, opt_step_loop=0.002s
# [Epoch  332 timings] loss_sd=0.085s, loss_cont=0.762s, backward=0.726s, opt_step_loop=0.003s
# [Epoch  333 timings] loss_sd=0.063s, loss_cont=0.731s, backward=0.709s, opt_step_loop=0.002s
# [Epoch  334 timings] loss_sd=0.079s, loss_cont=0.782s, backward=0.690s, opt_step_loop=0.003s
# [Epoch  335 timings] loss_sd=0.069s, loss_cont=0.766s, backward=0.672s, opt_step_loop=0.002s
# [Epoch  336 timings] loss_sd=0.074s, loss_cont=0.799s, backward=0.651s, opt_step_loop=0.003s
# [Epoch  337 timings] loss_sd=0.051s, loss_cont=0.790s, backward=1.075s, opt_step_loop=0.002s
# [Epoch  338 timings] loss_sd=0.125s, loss_cont=0.836s, backward=0.696s, opt_step_loop=0.003s
# [Epoch  339 timings] loss_sd=0.065s, loss_cont=0.833s, backward=0.692s, opt_step_loop=0.004s
# [Epoch  340] W_f=3.371e-01, W_c=4.657e+05, W_a=1.459e+00, W_r=7.472e-03 | F_avg=8.6393e+00 | C_avg=3.1961e-09
# [Epoch  340 timings] loss_sd=0.058s, loss_cont=0.807s, backward=0.641s, opt_step_loop=0.002s
# [Epoch  341 timings] loss_sd=0.090s, loss_cont=0.778s, backward=1.066s, opt_step_loop=0.002s
# [Epoch  342 timings] loss_sd=0.061s, loss_cont=0.703s, backward=0.648s, opt_step_loop=0.002s
# [Epoch  343 timings] loss_sd=0.082s, loss_cont=0.710s, backward=0.988s, opt_step_loop=0.002s
# [Epoch  344 timings] loss_sd=0.066s, loss_cont=0.760s, backward=0.617s, opt_step_loop=0.006s
# [Epoch  345 timings] loss_sd=0.090s, loss_cont=0.780s, backward=0.711s, opt_step_loop=0.002s
# [Epoch  346 timings] loss_sd=0.063s, loss_cont=0.765s, backward=0.647s, opt_step_loop=0.003s
# [Epoch  347 timings] loss_sd=0.072s, loss_cont=0.842s, backward=0.678s, opt_step_loop=0.002s
# [Epoch  348 timings] loss_sd=0.073s, loss_cont=0.742s, backward=0.657s, opt_step_loop=0.003s
# [Epoch  349 timings] loss_sd=0.068s, loss_cont=0.831s, backward=0.712s, opt_step_loop=0.010s
# [Epoch  350] W_f=3.314e-01, W_c=4.937e+05, W_a=1.471e+00, W_r=6.737e-03 | F_avg=8.6066e+00 | C_avg=2.8283e-09
# [Epoch  350 timings] loss_sd=0.059s, loss_cont=0.790s, backward=0.696s, opt_step_loop=0.002s
# [Epoch  351 timings] loss_sd=0.062s, loss_cont=0.712s, backward=0.723s, opt_step_loop=0.002s
# [Epoch  352 timings] loss_sd=0.057s, loss_cont=0.763s, backward=0.700s, opt_step_loop=0.003s
# [Epoch  353 timings] loss_sd=0.057s, loss_cont=0.832s, backward=1.279s, opt_step_loop=0.002s
# [Epoch  354 timings] loss_sd=0.529s, loss_cont=0.750s, backward=0.870s, opt_step_loop=0.002s
# [Epoch  355 timings] loss_sd=0.088s, loss_cont=0.796s, backward=1.205s, opt_step_loop=0.002s
# [Epoch  356 timings] loss_sd=0.067s, loss_cont=0.744s, backward=0.780s, opt_step_loop=0.003s
# [Epoch  357 timings] loss_sd=0.109s, loss_cont=0.784s, backward=0.756s, opt_step_loop=0.005s
# [Epoch  358 timings] loss_sd=0.056s, loss_cont=0.809s, backward=0.657s, opt_step_loop=0.003s
# [Epoch  359 timings] loss_sd=0.111s, loss_cont=0.718s, backward=1.092s, opt_step_loop=0.003s
# [Epoch  360] W_f=3.261e-01, W_c=5.186e+05, W_a=1.482e+00, W_r=6.094e-03 | F_avg=8.5724e+00 | C_avg=2.5212e-09
# [Epoch  360 timings] loss_sd=0.069s, loss_cont=0.778s, backward=0.765s, opt_step_loop=0.007s
# [Epoch  361 timings] loss_sd=0.078s, loss_cont=0.840s, backward=0.717s, opt_step_loop=0.003s
# [Epoch  362 timings] loss_sd=0.059s, loss_cont=0.769s, backward=0.642s, opt_step_loop=0.002s
# [Epoch  363 timings] loss_sd=0.068s, loss_cont=0.875s, backward=0.638s, opt_step_loop=0.002s
# [Epoch  364 timings] loss_sd=0.062s, loss_cont=0.748s, backward=1.125s, opt_step_loop=0.004s
# [Epoch  365 timings] loss_sd=0.085s, loss_cont=0.799s, backward=0.662s, opt_step_loop=0.002s
# [Epoch  366 timings] loss_sd=0.153s, loss_cont=0.718s, backward=1.059s, opt_step_loop=0.002s
# [Epoch  367 timings] loss_sd=0.070s, loss_cont=0.763s, backward=0.664s, opt_step_loop=0.002s
# [Epoch  368 timings] loss_sd=0.071s, loss_cont=0.737s, backward=0.767s, opt_step_loop=0.002s
# [Epoch  369 timings] loss_sd=0.064s, loss_cont=0.721s, backward=0.680s, opt_step_loop=0.002s
# [Epoch  370] W_f=3.215e-01, W_c=5.395e+05, W_a=1.494e+00, W_r=5.528e-03 | F_avg=8.5369e+00 | C_avg=2.2566e-09
# [Epoch  370 timings] loss_sd=0.073s, loss_cont=0.811s, backward=0.671s, opt_step_loop=0.003s
# [Epoch  371 timings] loss_sd=0.071s, loss_cont=0.743s, backward=0.699s, opt_step_loop=0.002s
# [Epoch  372 timings] loss_sd=0.246s, loss_cont=0.775s, backward=0.673s, opt_step_loop=0.003s
# [Epoch  373 timings] loss_sd=0.065s, loss_cont=0.730s, backward=0.786s, opt_step_loop=0.002s
# [Epoch  374 timings] loss_sd=0.067s, loss_cont=0.782s, backward=0.744s, opt_step_loop=0.002s
# [Epoch  375 timings] loss_sd=0.065s, loss_cont=0.739s, backward=0.936s, opt_step_loop=0.003s
# [Epoch  376 timings] loss_sd=0.064s, loss_cont=0.755s, backward=0.702s, opt_step_loop=0.003s
# [Epoch  377 timings] loss_sd=0.054s, loss_cont=0.747s, backward=0.760s, opt_step_loop=0.002s
# [Epoch  378 timings] loss_sd=0.063s, loss_cont=0.764s, backward=0.782s, opt_step_loop=0.002s
# [Epoch  379 timings] loss_sd=0.061s, loss_cont=0.839s, backward=0.825s, opt_step_loop=0.003s
# [Epoch  380] W_f=3.175e-01, W_c=5.573e+05, W_a=1.506e+00, W_r=5.027e-03 | F_avg=8.5001e+00 | C_avg=2.0214e-09
# [Epoch  380 timings] loss_sd=0.072s, loss_cont=0.805s, backward=0.637s, opt_step_loop=0.003s
# [Epoch  381 timings] loss_sd=0.204s, loss_cont=0.846s, backward=0.898s, opt_step_loop=0.002s
# [Epoch  382 timings] loss_sd=0.065s, loss_cont=0.747s, backward=1.217s, opt_step_loop=0.002s
# [Epoch  383 timings] loss_sd=0.070s, loss_cont=1.525s, backward=1.123s, opt_step_loop=0.003s
# [Epoch  384 timings] loss_sd=0.077s, loss_cont=0.753s, backward=0.685s, opt_step_loop=0.004s
# [Epoch  385 timings] loss_sd=0.067s, loss_cont=0.734s, backward=0.795s, opt_step_loop=0.002s
# [Epoch  386 timings] loss_sd=0.055s, loss_cont=0.751s, backward=0.651s, opt_step_loop=0.002s
# [Epoch  387 timings] loss_sd=0.080s, loss_cont=0.811s, backward=0.675s, opt_step_loop=0.004s
# [Epoch  388 timings] loss_sd=0.061s, loss_cont=0.786s, backward=0.672s, opt_step_loop=0.002s
# [Epoch  389 timings] loss_sd=0.622s, loss_cont=0.815s, backward=0.716s, opt_step_loop=0.003s
# [Epoch  390] W_f=3.140e-01, W_c=5.732e+05, W_a=1.518e+00, W_r=4.582e-03 | F_avg=8.4621e+00 | C_avg=1.8101e-09
# [Epoch  390 timings] loss_sd=0.064s, loss_cont=0.727s, backward=0.645s, opt_step_loop=0.003s
# [Epoch  391 timings] loss_sd=0.068s, loss_cont=0.730s, backward=0.766s, opt_step_loop=0.004s
# [Epoch  392 timings] loss_sd=0.059s, loss_cont=0.705s, backward=0.748s, opt_step_loop=0.002s
# [Epoch  393 timings] loss_sd=0.073s, loss_cont=0.763s, backward=0.689s, opt_step_loop=0.003s
# [Epoch  394 timings] loss_sd=0.062s, loss_cont=0.762s, backward=0.780s, opt_step_loop=0.005s
# [Epoch  395 timings] loss_sd=0.067s, loss_cont=0.780s, backward=0.687s, opt_step_loop=0.002s
# [Epoch  396 timings] loss_sd=0.063s, loss_cont=0.871s, backward=0.705s, opt_step_loop=0.004s
# [Epoch  397 timings] loss_sd=0.065s, loss_cont=0.772s, backward=0.658s, opt_step_loop=0.002s
# [Epoch  398 timings] loss_sd=0.063s, loss_cont=0.793s, backward=0.698s, opt_step_loop=0.003s
# [Epoch  399 timings] loss_sd=0.068s, loss_cont=0.787s, backward=0.711s, opt_step_loop=0.004s
# [Epoch  400] W_f=3.112e-01, W_c=5.882e+05, W_a=1.530e+00, W_r=4.186e-03 | F_avg=8.4230e+00 | C_avg=1.6240e-09
# [Epoch  400 timings] loss_sd=0.358s, loss_cont=0.750s, backward=0.650s, opt_step_loop=0.003s
# [Epoch  401 timings] loss_sd=0.061s, loss_cont=0.830s, backward=0.700s, opt_step_loop=0.002s
# [Epoch  402 timings] loss_sd=0.060s, loss_cont=0.740s, backward=0.605s, opt_step_loop=0.002s
# [Epoch  403 timings] loss_sd=0.063s, loss_cont=0.843s, backward=0.679s, opt_step_loop=0.002s
# [Epoch  404 timings] loss_sd=0.054s, loss_cont=0.751s, backward=0.729s, opt_step_loop=0.004s
# [Epoch  405 timings] loss_sd=0.070s, loss_cont=0.724s, backward=0.674s, opt_step_loop=0.003s
# [Epoch  406 timings] loss_sd=0.053s, loss_cont=0.820s, backward=0.713s, opt_step_loop=0.002s
# [Epoch  407 timings] loss_sd=0.074s, loss_cont=0.754s, backward=0.686s, opt_step_loop=0.004s
# [Epoch  408 timings] loss_sd=0.074s, loss_cont=0.753s, backward=0.656s, opt_step_loop=0.002s
# [Epoch  409 timings] loss_sd=0.056s, loss_cont=0.725s, backward=0.770s, opt_step_loop=0.002s
# [Epoch  410] W_f=3.091e-01, W_c=6.021e+05, W_a=1.542e+00, W_r=3.832e-03 | F_avg=8.3830e+00 | C_avg=1.4666e-09
# [Epoch  410 timings] loss_sd=0.060s, loss_cont=0.729s, backward=0.700s, opt_step_loop=0.003s
# [Epoch  411 timings] loss_sd=0.080s, loss_cont=0.767s, backward=0.697s, opt_step_loop=0.003s
# [Epoch  412 timings] loss_sd=0.043s, loss_cont=0.833s, backward=0.710s, opt_step_loop=0.005s
# [Epoch  413 timings] loss_sd=0.068s, loss_cont=0.786s, backward=0.756s, opt_step_loop=0.005s
# [Epoch  414 timings] loss_sd=0.047s, loss_cont=0.799s, backward=0.671s, opt_step_loop=0.002s
# [Epoch  415 timings] loss_sd=0.071s, loss_cont=0.739s, backward=0.922s, opt_step_loop=0.003s
# [Epoch  416 timings] loss_sd=0.067s, loss_cont=0.761s, backward=0.704s, opt_step_loop=0.007s
# [Epoch  417 timings] loss_sd=0.066s, loss_cont=0.815s, backward=0.998s, opt_step_loop=0.002s
# [Epoch  418 timings] loss_sd=0.070s, loss_cont=0.765s, backward=0.679s, opt_step_loop=0.003s
# [Epoch  419 timings] loss_sd=0.066s, loss_cont=0.833s, backward=0.683s, opt_step_loop=0.003s
# [Epoch  420] W_f=3.075e-01, W_c=6.145e+05, W_a=1.555e+00, W_r=3.516e-03 | F_avg=8.3422e+00 | C_avg=1.3399e-09
# [Epoch  420 timings] loss_sd=0.122s, loss_cont=0.726s, backward=0.729s, opt_step_loop=0.002s
# [Epoch  421 timings] loss_sd=0.082s, loss_cont=0.746s, backward=0.645s, opt_step_loop=0.002s
# [Epoch  422 timings] loss_sd=0.112s, loss_cont=0.756s, backward=0.801s, opt_step_loop=0.002s
# [Epoch  423 timings] loss_sd=0.059s, loss_cont=0.727s, backward=0.672s, opt_step_loop=0.002s
# [Epoch  424 timings] loss_sd=0.075s, loss_cont=0.790s, backward=0.673s, opt_step_loop=0.002s
# [Epoch  425 timings] loss_sd=0.060s, loss_cont=0.746s, backward=0.599s, opt_step_loop=0.002s
# [Epoch  426 timings] loss_sd=0.062s, loss_cont=0.774s, backward=0.634s, opt_step_loop=0.004s
# [Epoch  427 timings] loss_sd=0.080s, loss_cont=0.812s, backward=0.677s, opt_step_loop=0.004s
# [Epoch  428 timings] loss_sd=0.066s, loss_cont=0.806s, backward=0.676s, opt_step_loop=0.002s
# [Epoch  429 timings] loss_sd=0.077s, loss_cont=0.754s, backward=0.715s, opt_step_loop=0.005s
# [Epoch  430] W_f=3.067e-01, W_c=6.251e+05, W_a=1.568e+00, W_r=3.233e-03 | F_avg=8.3007e+00 | C_avg=1.2426e-09
# [Epoch  430 timings] loss_sd=0.059s, loss_cont=0.857s, backward=0.935s, opt_step_loop=0.003s
# [Epoch  431 timings] loss_sd=0.086s, loss_cont=0.772s, backward=1.195s, opt_step_loop=0.004s
# [Epoch  432 timings] loss_sd=0.061s, loss_cont=0.726s, backward=0.656s, opt_step_loop=0.002s
# [Epoch  433 timings] loss_sd=0.083s, loss_cont=0.769s, backward=1.028s, opt_step_loop=0.002s
# [Epoch  434 timings] loss_sd=0.076s, loss_cont=0.794s, backward=0.689s, opt_step_loop=0.002s
# [Epoch  435 timings] loss_sd=0.074s, loss_cont=1.531s, backward=0.818s, opt_step_loop=0.003s
# [Epoch  436 timings] loss_sd=0.076s, loss_cont=0.737s, backward=1.124s, opt_step_loop=0.002s
# [Epoch  437 timings] loss_sd=0.078s, loss_cont=0.737s, backward=0.657s, opt_step_loop=0.003s
# [Epoch  438 timings] loss_sd=0.074s, loss_cont=0.816s, backward=0.694s, opt_step_loop=0.003s
# [Epoch  439 timings] loss_sd=0.063s, loss_cont=0.768s, backward=0.679s, opt_step_loop=0.003s
# [Epoch  440] W_f=3.065e-01, W_c=6.341e+05, W_a=1.581e+00, W_r=2.979e-03 | F_avg=8.2585e+00 | C_avg=1.1721e-09
# [Epoch  440 timings] loss_sd=0.072s, loss_cont=0.850s, backward=0.711s, opt_step_loop=0.003s
# [Epoch  441 timings] loss_sd=0.061s, loss_cont=0.725s, backward=0.897s, opt_step_loop=0.004s
# [Epoch  442 timings] loss_sd=0.063s, loss_cont=0.712s, backward=0.638s, opt_step_loop=0.002s
# [Epoch  443 timings] loss_sd=0.074s, loss_cont=0.812s, backward=0.693s, opt_step_loop=0.003s
# [Epoch  444 timings] loss_sd=0.065s, loss_cont=0.772s, backward=0.735s, opt_step_loop=0.002s
# [Epoch  445 timings] loss_sd=0.070s, loss_cont=0.721s, backward=1.228s, opt_step_loop=0.003s
# [Epoch  446 timings] loss_sd=0.066s, loss_cont=0.749s, backward=0.669s, opt_step_loop=0.004s
# [Epoch  447 timings] loss_sd=0.066s, loss_cont=0.771s, backward=0.832s, opt_step_loop=0.002s
# [Epoch  448 timings] loss_sd=0.066s, loss_cont=0.741s, backward=0.654s, opt_step_loop=0.002s
# [Epoch  449 timings] loss_sd=0.064s, loss_cont=0.798s, backward=0.721s, opt_step_loop=0.002s
# [Epoch  450] W_f=3.069e-01, W_c=6.415e+05, W_a=1.594e+00, W_r=2.752e-03 | F_avg=8.2159e+00 | C_avg=1.1257e-09
# [Epoch  450 timings] loss_sd=0.074s, loss_cont=0.812s, backward=0.775s, opt_step_loop=0.003s
# [Epoch  451 timings] loss_sd=0.498s, loss_cont=0.904s, backward=1.300s, opt_step_loop=0.004s
# [Epoch  452 timings] loss_sd=0.072s, loss_cont=0.806s, backward=0.926s, opt_step_loop=0.003s
# [Epoch  453 timings] loss_sd=0.093s, loss_cont=0.804s, backward=0.830s, opt_step_loop=0.004s
# [Epoch  454 timings] loss_sd=0.064s, loss_cont=0.851s, backward=0.768s, opt_step_loop=0.002s
# [Epoch  455 timings] loss_sd=0.110s, loss_cont=0.772s, backward=1.214s, opt_step_loop=0.002s
# [Epoch  456 timings] loss_sd=0.127s, loss_cont=0.818s, backward=0.855s, opt_step_loop=0.006s
# [Epoch  457 timings] loss_sd=0.061s, loss_cont=0.752s, backward=1.377s, opt_step_loop=0.002s
# [Epoch  458 timings] loss_sd=0.113s, loss_cont=0.746s, backward=0.795s, opt_step_loop=0.003s
# [Epoch  459 timings] loss_sd=0.092s, loss_cont=0.817s, backward=0.792s, opt_step_loop=0.003s
# [Epoch  460] W_f=3.081e-01, W_c=6.474e+05, W_a=1.607e+00, W_r=2.547e-03 | F_avg=8.1728e+00 | C_avg=1.1007e-09
# ...
# [Epoch 2346 timings] loss_sd=0.056s, loss_cont=0.733s, backward=1.006s, opt_step_loop=0.002s
# [Epoch 2347 timings] loss_sd=0.071s, loss_cont=0.775s, backward=0.677s, opt_step_loop=0.005s
# [Epoch 2348 timings] loss_sd=0.059s, loss_cont=0.751s, backward=0.762s, opt_step_loop=0.005s
# [Epoch 2349 timings] loss_sd=0.079s, loss_cont=0.717s, backward=0.674s, opt_step_loop=0.003s
# [Epoch 2350] W_f=1.131e+00, W_c=7.082e+05, W_a=1.026e+01, W_r=2.276e-05 | F_avg=1.1580e+00 | C_avg=7.1169e-09
# [Epoch 2350 timings] loss_sd=0.056s, loss_cont=0.816s, backward=0.630s, opt_step_loop=0.002s
# [Epoch 2351 timings] loss_sd=0.069s, loss_cont=0.712s, backward=1.020s, opt_step_loop=0.006s
# [Epoch 2352 timings] loss_sd=0.168s, loss_cont=0.758s, backward=0.667s, opt_step_loop=0.004s
# [Epoch 2353 timings] loss_sd=0.062s, loss_cont=0.709s, backward=0.743s, opt_step_loop=0.002s
# [Epoch 2354 timings] loss_sd=0.091s, loss_cont=0.732s, backward=0.605s, opt_step_loop=0.003s
# [Epoch 2355 timings] loss_sd=0.072s, loss_cont=0.797s, backward=0.717s, opt_step_loop=0.003s
# [Epoch 2356 timings] loss_sd=0.058s, loss_cont=0.774s, backward=0.632s, opt_step_loop=0.002s
# [Epoch 2357 timings] loss_sd=0.059s, loss_cont=0.802s, backward=0.662s, opt_step_loop=0.002s
# [Epoch 2358 timings] loss_sd=0.068s, loss_cont=0.755s, backward=0.625s, opt_step_loop=0.003s
# [Epoch 2359 timings] loss_sd=0.108s, loss_cont=0.803s, backward=0.641s, opt_step_loop=0.002s
# [Epoch 2360] W_f=1.149e+00, W_c=7.879e+05, W_a=1.036e+01, W_r=2.268e-05 | F_avg=1.1379e+00 | C_avg=6.9190e-09
# [Epoch 2360 timings] loss_sd=0.056s, loss_cont=0.774s, backward=0.809s, opt_step_loop=0.002s
# [Epoch 2361 timings] loss_sd=0.065s, loss_cont=0.752s, backward=0.671s, opt_step_loop=0.002s
# [Epoch 2362 timings] loss_sd=0.064s, loss_cont=0.739s, backward=0.721s, opt_step_loop=0.003s
# [Epoch 2363 timings] loss_sd=0.068s, loss_cont=0.759s, backward=0.680s, opt_step_loop=0.003s
# [Epoch 2364 timings] loss_sd=0.061s, loss_cont=0.767s, backward=0.752s, opt_step_loop=0.004s
# [Epoch 2365 timings] loss_sd=0.059s, loss_cont=0.760s, backward=0.658s, opt_step_loop=0.003s
# [Epoch 2366 timings] loss_sd=0.060s, loss_cont=0.826s, backward=1.434s, opt_step_loop=0.003s
# [Epoch 2367 timings] loss_sd=0.331s, loss_cont=0.830s, backward=0.705s, opt_step_loop=0.002s
# [Epoch 2368 timings] loss_sd=0.055s, loss_cont=0.711s, backward=0.613s, opt_step_loop=0.003s
# [Epoch 2369 timings] loss_sd=0.073s, loss_cont=0.827s, backward=0.660s, opt_step_loop=0.004s
# [Epoch 2370] W_f=1.168e+00, W_c=3.061e+05, W_a=1.047e+01, W_r=2.259e-05 | F_avg=1.1182e+00 | C_avg=7.0702e-09
# [Epoch 2370 timings] loss_sd=0.064s, loss_cont=0.759s, backward=1.154s, opt_step_loop=0.002s
# [Epoch 2371 timings] loss_sd=0.398s, loss_cont=1.447s, backward=0.689s, opt_step_loop=0.002s
# [Epoch 2372 timings] loss_sd=0.233s, loss_cont=0.759s, backward=0.916s, opt_step_loop=0.002s
# [Epoch 2373 timings] loss_sd=0.082s, loss_cont=0.707s, backward=0.806s, opt_step_loop=0.003s
# [Epoch 2374 timings] loss_sd=0.249s, loss_cont=0.732s, backward=0.736s, opt_step_loop=0.002s
# [Epoch 2375 timings] loss_sd=0.087s, loss_cont=0.834s, backward=0.684s, opt_step_loop=0.002s
# [Epoch 2376 timings] loss_sd=0.069s, loss_cont=0.742s, backward=0.686s, opt_step_loop=0.002s
# [Epoch 2377 timings] loss_sd=0.133s, loss_cont=0.826s, backward=0.674s, opt_step_loop=0.003s
# [Epoch 2378 timings] loss_sd=0.061s, loss_cont=0.848s, backward=0.635s, opt_step_loop=0.002s
# [Epoch 2379 timings] loss_sd=0.060s, loss_cont=0.801s, backward=0.699s, opt_step_loop=0.002s
# [Epoch 2380] W_f=1.168e+00, W_c=3.778e+05, W_a=1.057e+01, W_r=2.249e-05 | F_avg=1.0985e+00 | C_avg=7.1980e-09
# [Epoch 2380 timings] loss_sd=0.075s, loss_cont=0.741s, backward=0.966s, opt_step_loop=0.003s
# [Epoch 2381 timings] loss_sd=0.078s, loss_cont=0.762s, backward=0.668s, opt_step_loop=0.003s
# [Epoch 2382 timings] loss_sd=0.092s, loss_cont=0.762s, backward=0.790s, opt_step_loop=0.003s
# [Epoch 2383 timings] loss_sd=0.073s, loss_cont=0.770s, backward=0.675s, opt_step_loop=0.002s
# [Epoch 2384 timings] loss_sd=0.067s, loss_cont=0.760s, backward=0.723s, opt_step_loop=0.002s
# [Epoch 2385 timings] loss_sd=0.064s, loss_cont=0.720s, backward=0.609s, opt_step_loop=0.002s
# [Epoch 2386 timings] loss_sd=0.056s, loss_cont=0.810s, backward=0.675s, opt_step_loop=0.002s
# [Epoch 2387 timings] loss_sd=0.096s, loss_cont=0.800s, backward=0.777s, opt_step_loop=0.002s
# [Epoch 2388 timings] loss_sd=0.072s, loss_cont=0.767s, backward=0.939s, opt_step_loop=0.002s
# [Epoch 2389 timings] loss_sd=0.131s, loss_cont=0.751s, backward=0.829s, opt_step_loop=0.003s
# [Epoch 2390] W_f=1.214e+00, W_c=4.716e+05, W_a=1.068e+01, W_r=2.240e-05 | F_avg=1.0792e+00 | C_avg=7.5234e-09
# [Epoch 2390 timings] loss_sd=0.067s, loss_cont=0.761s, backward=0.677s, opt_step_loop=0.003s
# [Epoch 2391 timings] loss_sd=0.455s, loss_cont=0.755s, backward=0.904s, opt_step_loop=0.002s
# [Epoch 2392 timings] loss_sd=0.070s, loss_cont=0.786s, backward=0.782s, opt_step_loop=0.009s
# [Epoch 2393 timings] loss_sd=0.082s, loss_cont=0.720s, backward=0.717s, opt_step_loop=0.002s
# [Epoch 2394 timings] loss_sd=0.073s, loss_cont=0.902s, backward=0.720s, opt_step_loop=0.002s
# [Epoch 2395 timings] loss_sd=0.085s, loss_cont=0.802s, backward=0.704s, opt_step_loop=0.002s
# [Epoch 2396 timings] loss_sd=0.069s, loss_cont=0.742s, backward=0.727s, opt_step_loop=0.005s
# [Epoch 2397 timings] loss_sd=0.059s, loss_cont=0.766s, backward=0.761s, opt_step_loop=0.002s
# [Epoch 2398 timings] loss_sd=0.067s, loss_cont=0.802s, backward=0.708s, opt_step_loop=0.003s
# [Epoch 2399 timings] loss_sd=0.068s, loss_cont=0.749s, backward=0.682s, opt_step_loop=0.002s
# [Epoch 2400] W_f=1.208e+00, W_c=6.492e+05, W_a=1.079e+01, W_r=2.231e-05 | F_avg=1.0604e+00 | C_avg=7.3502e-09
# [Epoch 2400 timings] loss_sd=0.092s, loss_cont=0.823s, backward=0.720s, opt_step_loop=0.003s
# [Epoch 2401 timings] loss_sd=0.092s, loss_cont=0.746s, backward=0.771s, opt_step_loop=0.004s
# [Epoch 2402 timings] loss_sd=0.052s, loss_cont=0.690s, backward=0.666s, opt_step_loop=0.004s
# [Epoch 2403 timings] loss_sd=0.074s, loss_cont=0.811s, backward=0.693s, opt_step_loop=0.002s
# [Epoch 2404 timings] loss_sd=0.075s, loss_cont=0.756s, backward=0.640s, opt_step_loop=0.002s
# [Epoch 2405 timings] loss_sd=0.073s, loss_cont=0.848s, backward=0.658s, opt_step_loop=0.002s
# [Epoch 2406 timings] loss_sd=0.060s, loss_cont=0.732s, backward=1.033s, opt_step_loop=0.004s
# [Epoch 2407 timings] loss_sd=0.084s, loss_cont=0.751s, backward=0.730s, opt_step_loop=0.002s
# [Epoch 2408 timings] loss_sd=0.066s, loss_cont=0.736s, backward=0.717s, opt_step_loop=0.002s
# [Epoch 2409 timings] loss_sd=0.076s, loss_cont=0.748s, backward=0.882s, opt_step_loop=0.002s
# [Epoch 2410] W_f=1.247e+00, W_c=8.601e+05, W_a=1.090e+01, W_r=2.221e-05 | F_avg=1.0420e+00 | C_avg=6.7766e-09
# [Epoch 2410 timings] loss_sd=0.064s, loss_cont=0.810s, backward=0.667s, opt_step_loop=0.002s
# [Epoch 2411 timings] loss_sd=0.070s, loss_cont=0.713s, backward=0.667s, opt_step_loop=0.003s
# [Epoch 2412 timings] loss_sd=0.180s, loss_cont=0.862s, backward=0.685s, opt_step_loop=0.003s
# [Epoch 2413 timings] loss_sd=0.063s, loss_cont=0.772s, backward=0.683s, opt_step_loop=0.002s
# [Epoch 2414 timings] loss_sd=0.058s, loss_cont=0.885s, backward=0.632s, opt_step_loop=0.002s
# [Epoch 2415 timings] loss_sd=0.081s, loss_cont=0.714s, backward=0.663s, opt_step_loop=0.002s
# [Epoch 2416 timings] loss_sd=0.053s, loss_cont=0.897s, backward=0.655s, opt_step_loop=0.002s
# [Epoch 2417 timings] loss_sd=0.257s, loss_cont=0.744s, backward=0.885s, opt_step_loop=0.002s
# [Epoch 2418 timings] loss_sd=0.072s, loss_cont=0.765s, backward=0.650s, opt_step_loop=0.009s
# [Epoch 2419 timings] loss_sd=0.071s, loss_cont=0.742s, backward=1.048s, opt_step_loop=0.006s
# [Epoch 2420] W_f=1.276e+00, W_c=5.575e+04, W_a=1.101e+01, W_r=2.213e-05 | F_avg=1.0242e+00 | C_avg=3.0322e-08
# [Epoch 2420 timings] loss_sd=0.070s, loss_cont=0.732s, backward=0.638s, opt_step_loop=0.002s
# [Epoch 2421 timings] loss_sd=0.057s, loss_cont=0.842s, backward=1.000s, opt_step_loop=0.003s
# [Epoch 2422 timings] loss_sd=0.053s, loss_cont=0.747s, backward=0.931s, opt_step_loop=0.002s
# [Epoch 2423 timings] loss_sd=0.093s, loss_cont=0.753s, backward=0.817s, opt_step_loop=0.002s
# [Epoch 2424 timings] loss_sd=0.085s, loss_cont=0.732s, backward=0.756s, opt_step_loop=0.004s
# [Epoch 2425 timings] loss_sd=0.095s, loss_cont=0.769s, backward=0.669s, opt_step_loop=0.002s
# [Epoch 2426 timings] loss_sd=0.067s, loss_cont=0.771s, backward=1.010s, opt_step_loop=0.002s
# [Epoch 2427 timings] loss_sd=0.055s, loss_cont=0.707s, backward=0.693s, opt_step_loop=0.003s
# [Epoch 2428 timings] loss_sd=0.054s, loss_cont=0.810s, backward=0.728s, opt_step_loop=0.002s
# [Epoch 2429 timings] loss_sd=0.209s, loss_cont=0.788s, backward=0.770s, opt_step_loop=0.003s
# [Epoch 2430] W_f=1.264e+00, W_c=2.563e+04, W_a=1.112e+01, W_r=2.206e-05 | F_avg=1.0060e+00 | C_avg=1.2508e-07
# [Epoch 2430 timings] loss_sd=0.075s, loss_cont=0.839s, backward=0.768s, opt_step_loop=0.002s
# [Epoch 2431 timings] loss_sd=0.063s, loss_cont=0.767s, backward=0.659s, opt_step_loop=0.002s
# [Epoch 2432 timings] loss_sd=0.095s, loss_cont=0.853s, backward=0.905s, opt_step_loop=0.005s
# [Epoch 2433 timings] loss_sd=0.093s, loss_cont=0.731s, backward=1.127s, opt_step_loop=0.004s
# [Epoch 2434 timings] loss_sd=0.057s, loss_cont=1.511s, backward=1.630s, opt_step_loop=0.003s
# [Epoch 2435 timings] loss_sd=0.161s, loss_cont=0.799s, backward=0.672s, opt_step_loop=0.003s
# [Epoch 2436 timings] loss_sd=0.064s, loss_cont=0.745s, backward=0.824s, opt_step_loop=0.003s
# [Epoch 2437 timings] loss_sd=0.069s, loss_cont=0.776s, backward=0.763s, opt_step_loop=0.002s
# [Epoch 2438 timings] loss_sd=0.088s, loss_cont=0.839s, backward=1.009s, opt_step_loop=0.002s
# [Epoch 2439 timings] loss_sd=0.073s, loss_cont=0.763s, backward=0.673s, opt_step_loop=0.003s
# [Epoch 2440] W_f=1.294e+00, W_c=5.202e+04, W_a=1.123e+01, W_r=2.197e-05 | F_avg=9.8867e-01 | C_avg=3.3012e-08
# [Epoch 2440 timings] loss_sd=0.079s, loss_cont=0.818s, backward=0.837s, opt_step_loop=0.008s
# [Epoch 2441 timings] loss_sd=0.070s, loss_cont=0.711s, backward=1.112s, opt_step_loop=0.002s
# [Epoch 2442 timings] loss_sd=0.066s, loss_cont=0.725s, backward=1.237s, opt_step_loop=0.002s
# [Epoch 2443 timings] loss_sd=0.069s, loss_cont=0.819s, backward=0.645s, opt_step_loop=0.002s
# [Epoch 2444 timings] loss_sd=0.066s, loss_cont=0.723s, backward=1.199s, opt_step_loop=0.002s
# [Epoch 2445 timings] loss_sd=0.743s, loss_cont=0.800s, backward=0.679s, opt_step_loop=0.003s
# [Epoch 2446 timings] loss_sd=0.053s, loss_cont=0.834s, backward=0.916s, opt_step_loop=0.002s
# [Epoch 2447 timings] loss_sd=0.065s, loss_cont=0.885s, backward=0.705s, opt_step_loop=0.003s
# [Epoch 2448 timings] loss_sd=0.075s, loss_cont=0.735s, backward=0.993s, opt_step_loop=0.002s
# [Epoch 2449 timings] loss_sd=0.069s, loss_cont=0.738s, backward=0.677s, opt_step_loop=0.002s
# [Epoch 2450] W_f=1.321e+00, W_c=1.305e+05, W_a=1.135e+01, W_r=2.189e-05 | F_avg=9.7115e-01 | C_avg=1.2388e-08
# [Epoch 2450 timings] loss_sd=0.375s, loss_cont=0.832s, backward=0.672s, opt_step_loop=0.002s
# [Epoch 2451 timings] loss_sd=0.214s, loss_cont=0.762s, backward=1.461s, opt_step_loop=0.003s
# [Epoch 2452 timings] loss_sd=0.183s, loss_cont=0.743s, backward=0.659s, opt_step_loop=0.002s
# [Epoch 2453 timings] loss_sd=0.084s, loss_cont=0.787s, backward=0.731s, opt_step_loop=0.002s
# [Epoch 2454 timings] loss_sd=0.059s, loss_cont=0.752s, backward=0.615s, opt_step_loop=0.002s
# [Epoch 2455 timings] loss_sd=0.070s, loss_cont=0.833s, backward=0.663s, opt_step_loop=0.002s
# [Epoch 2456 timings] loss_sd=0.057s, loss_cont=0.723s, backward=0.640s, opt_step_loop=0.006s
# [Epoch 2457 timings] loss_sd=0.082s, loss_cont=0.825s, backward=1.154s, opt_step_loop=0.002s
# [Epoch 2458 timings] loss_sd=0.099s, loss_cont=0.723s, backward=0.674s, opt_step_loop=0.002s
# [Epoch 2459 timings] loss_sd=0.131s, loss_cont=0.722s, backward=0.692s, opt_step_loop=0.002s
# [Epoch 2460] W_f=1.334e+00, W_c=2.586e+05, W_a=1.146e+01, W_r=2.181e-05 | F_avg=9.5389e-01 | C_avg=8.7604e-09
# [Epoch 2460 timings] loss_sd=0.499s, loss_cont=0.849s, backward=0.663s, opt_step_loop=0.004s
# [Epoch 2461 timings] loss_sd=0.069s, loss_cont=0.783s, backward=1.154s, opt_step_loop=0.006s
# [Epoch 2462 timings] loss_sd=0.077s, loss_cont=0.769s, backward=0.798s, opt_step_loop=0.002s
# [Epoch 2463 timings] loss_sd=0.077s, loss_cont=0.809s, backward=0.711s, opt_step_loop=0.002s
# [Epoch 2464 timings] loss_sd=0.083s, loss_cont=0.728s, backward=0.779s, opt_step_loop=0.002s
# [Epoch 2465 timings] loss_sd=0.082s, loss_cont=0.704s, backward=0.623s, opt_step_loop=0.002s
# [Epoch 2466 timings] loss_sd=0.522s, loss_cont=0.807s, backward=0.674s, opt_step_loop=0.002s
# [Epoch 2467 timings] loss_sd=0.071s, loss_cont=0.761s, backward=1.097s, opt_step_loop=0.002s
# [Epoch 2468 timings] loss_sd=0.057s, loss_cont=0.735s, backward=0.780s, opt_step_loop=0.003s
# [Epoch 2469 timings] loss_sd=0.055s, loss_cont=0.753s, backward=0.743s, opt_step_loop=0.004s
# [Epoch 2470] W_f=1.354e+00, W_c=2.936e+05, W_a=1.158e+01, W_r=2.174e-05 | F_avg=9.3662e-01 | C_avg=8.5059e-09
# [Epoch 2470 timings] loss_sd=0.084s, loss_cont=0.738s, backward=1.122s, opt_step_loop=0.003s
# [Epoch 2471 timings] loss_sd=0.220s, loss_cont=0.777s, backward=0.883s, opt_step_loop=0.002s
# [Epoch 2472 timings] loss_sd=0.062s, loss_cont=0.720s, backward=1.054s, opt_step_loop=0.002s
# [Epoch 2473 timings] loss_sd=0.117s, loss_cont=0.790s, backward=0.676s, opt_step_loop=0.002s
# [Epoch 2474 timings] loss_sd=0.074s, loss_cont=0.792s, backward=0.674s, opt_step_loop=0.002s
# [Epoch 2475 timings] loss_sd=0.074s, loss_cont=0.752s, backward=0.693s, opt_step_loop=0.004s
# [Epoch 2476 timings] loss_sd=0.057s, loss_cont=0.858s, backward=0.650s, opt_step_loop=0.002s
# [Epoch 2477 timings] loss_sd=0.068s, loss_cont=0.784s, backward=0.652s, opt_step_loop=0.006s
# [Epoch 2478 timings] loss_sd=0.236s, loss_cont=0.850s, backward=0.699s, opt_step_loop=0.003s
# [Epoch 2479 timings] loss_sd=0.273s, loss_cont=0.725s, backward=0.694s, opt_step_loop=0.002s
# [Epoch 2480] W_f=1.370e+00, W_c=3.527e+05, W_a=1.170e+01, W_r=2.168e-05 | F_avg=9.1911e-01 | C_avg=7.6960e-09
# [Epoch 2480 timings] loss_sd=0.074s, loss_cont=0.724s, backward=0.644s, opt_step_loop=0.005s
# [Epoch 2481 timings] loss_sd=0.077s, loss_cont=0.853s, backward=0.626s, opt_step_loop=0.003s
# [Epoch 2482 timings] loss_sd=0.064s, loss_cont=0.839s, backward=0.635s, opt_step_loop=0.004s
# [Epoch 2483 timings] loss_sd=0.060s, loss_cont=0.841s, backward=0.738s, opt_step_loop=0.003s
# [Epoch 2484 timings] loss_sd=0.048s, loss_cont=0.765s, backward=0.631s, opt_step_loop=0.002s
# [Epoch 2485 timings] loss_sd=0.117s, loss_cont=0.815s, backward=0.675s, opt_step_loop=0.005s
# [Epoch 2486 timings] loss_sd=0.076s, loss_cont=1.632s, backward=0.662s, opt_step_loop=0.002s
# [Epoch 2487 timings] loss_sd=0.063s, loss_cont=0.756s, backward=0.631s, opt_step_loop=0.002s
# [Epoch 2488 timings] loss_sd=0.499s, loss_cont=0.803s, backward=0.630s, opt_step_loop=0.003s
# [Epoch 2489 timings] loss_sd=0.063s, loss_cont=0.728s, backward=0.749s, opt_step_loop=0.002s
# [Epoch 2490] W_f=1.374e+00, W_c=5.642e+05, W_a=1.182e+01, W_r=2.161e-05 | F_avg=9.0111e-01 | C_avg=6.8101e-09
# [Epoch 2490 timings] loss_sd=0.061s, loss_cont=0.736s, backward=1.237s, opt_step_loop=0.004s
# [Epoch 2491 timings] loss_sd=0.077s, loss_cont=0.826s, backward=0.689s, opt_step_loop=0.005s
# [Epoch 2492 timings] loss_sd=0.069s, loss_cont=0.762s, backward=0.674s, opt_step_loop=0.002s
# [Epoch 2493 timings] loss_sd=0.047s, loss_cont=0.719s, backward=0.779s, opt_step_loop=0.003s
# [Epoch 2494 timings] loss_sd=0.061s, loss_cont=0.766s, backward=0.949s, opt_step_loop=0.002s
# [Epoch 2495 timings] loss_sd=0.084s, loss_cont=0.741s, backward=1.208s, opt_step_loop=0.016s
# [Epoch 2496 timings] loss_sd=0.166s, loss_cont=0.775s, backward=0.680s, opt_step_loop=0.002s
# [Epoch 2497 timings] loss_sd=0.080s, loss_cont=0.736s, backward=0.867s, opt_step_loop=0.002s
# [Epoch 2498 timings] loss_sd=0.071s, loss_cont=0.736s, backward=0.815s, opt_step_loop=0.002s
# [Epoch 2499 timings] loss_sd=0.072s, loss_cont=0.728s, backward=1.516s, opt_step_loop=0.003s

# %%
net_norm
# Out:
# [tensor(14.9756, grad_fn=<MulBackward0>),
#  tensor(13.0626, grad_fn=<MulBackward0>),
#  tensor(284.0536, grad_fn=<MulBackward0>),
#  tensor(314.2323, grad_fn=<MulBackward0>)]

# %%
min(loss_lc_avg_arr)
# Out:
# 0.8849787712097168

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(loss_lc_avg_arr, marker="o", markersize=3)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training loss (Adam)")
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(loss_cont_avg_arr, marker="o", markersize=3)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training loss (Adam)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as mticker
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))

plt.plot(loss_lc_avg_arr, marker="o", markersize=3)

plt.yscale("log")  # log-scale y-axis
plt.ylim(bottom=1e-2)

# Format ticks as 10^{-1}, 10^{-2}, ...
ax = plt.gca()
ax.yaxis.set_major_locator(mticker.LogLocator(base=10))
ax.yaxis.set_major_formatter(mticker.LogFormatterMathtext())

plt.xlabel("Epoch")
plt.ylabel("Error")
# plt.title("Training loss (Adam)")
plt.grid(True, which="both", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()
plt.figure(figsize=(6, 4))

plt.plot(loss_cont_avg_arr, marker="o", markersize=3)

plt.yscale("log")  # log-scale y-axis
plt.ylim(bottom=1e-10)

# Format ticks as 10^{-1}, 10^{-2}, ...
ax = plt.gca()
ax.yaxis.set_major_locator(mticker.LogLocator(base=10))
ax.yaxis.set_major_formatter(mticker.LogFormatterMathtext())

plt.xlabel("Epoch")
plt.ylabel("Error")
# plt.title("Training loss (Adam)")
plt.grid(True, which="both", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %%
LCE_CG = []
LCE_rec = []
indices = []

LCE_CG_int = []
LCE_rec_int = []
indices_int = []
for local_cell_idx, cell_verts in enumerate(tqdm(local_cell_vertices)):
    # cell_verts are global vertex indices
    coords = omega_geometry[cell_verts]  # shape (3,2)
    coords_t = torch.tensor(coords, dtype=torch.float32, device=device)
    sd = cell_subdomain[local_cell_idx][0]
    net_sd = nets[sd]
    centroid = np.mean(coords, axis=0).reshape(1,-1)
    centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()

    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

    gdim = coords.shape[1]
    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))

    local_mesh = dmesh.create_mesh(
        MPI.COMM_SELF,
        loc_cells,
        coord_el,   # <-- this is the required "e" argument
        coords
    )
    cell_dofs = V.dofmap.cell_dofs(local_cell_idx)
    # -------------------------------------------------
    # 2. Local vector CG2 space for r_θ
    # -------------------------------------------------
    # Vector-valued CG2 (shape=(gdim,))
    V_loc = fem.functionspace(local_mesh, ("CG", order+1, (gdim,)))
    # r_loc = fem.Function(V_loc)

    # -------------------------------------------------
    # 3. Interpolate NN into r_loc via dof coordinates
    # -------------------------------------------------
    x_loc = V_loc.tabulate_dof_coordinates()[:,0:2]  # (Ndofs, gdim)
    x_loc_torch = torch.tensor(x_loc, dtype=torch.float32)      # NN input

    # r_vals_torch = net(x_loc_torch)                             # (Ndofs, gdim)
    # r_vals = r_vals_torch.detach().cpu().numpy().reshape(-1)

    # assign to local FEM function
    # r_loc.x.array[:] = r_vals.astype(default_scalar_type)

    # -------------------------------------------------
    # 4. Compute ∫_{∂D_j} r_θ · n ds on local mesh
    # -------------------------------------------------
    n_K = ufl.FacetNormal(local_mesh)
    # int_r_form = fem.form(ufl.dot(r_loc, n_K) * ufl.ds)

    edge_indices = [(0, 1), (1, 2), (2, 0)]
    int_r_local = torch.zeros((), device=device)

    num_sub = 3 #sub integral section

    for (i0, i1) in edge_indices:
        x0 = coords_t[i0]
        x1 = coords_t[i1]
        t = x1 - x0
        L = torch.linalg.norm(t)
        if L <= 0:
            continue

        n_edge = (torch.stack([t[1], -t[0]]) / L)
        n_edge = torch.tensor(n_edge, dtype=torch.float32)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()
        midpoint = 0.5 * (x0 + x1)
        if torch.dot(n_edge, centroid_t - midpoint) > 0:
            n_edge = -n_edge
        int_r_local += integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
    # int_r_local = fem.assemble_scalar(int_r_form)

    # -------------------------------------------------
    # 5. Combine with q_cg and f (precomputed per cell)
    # -------------------------------------------------
    P_loc = fem.functionspace(local_mesh, ("CG", order))
    p_K = fem.Function(P_loc)

    # DOFs on this cell in the global space
    global_dofs = V.dofmap.cell_dofs(local_cell_idx)

    # DOFs on the (only) cell in the local space
    local_dofs = P_loc.dofmap.cell_dofs(0)

    p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
    p_K.x.scatter_forward()

    k_m_loc = fem.Function(P_loc)
    k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]

    q_CG = -k_m_loc * ufl.grad(p_K)
    int_qcg = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ufl.ds(domain=local_mesh))
            )   # ∫_{∂D_j} q_cg · n
    
    f_m_loc = fem.Function(P_loc)
    f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]
    f_m_loc.x.scatter_forward()
    int_f   = fem.assemble_scalar(fem.form(f_m_loc * ufl.dx(domain=local_mesh)))       # ∫_{D_j} f

    residual_j = float(int_r_local) + int_qcg - int_f

    LCE_CG.append(int_qcg - int_f)
    LCE_rec.append(residual_j)
    indices.append(local_cell_idx)

    left_dofs_P = fem.locate_dofs_geometrical(
        P_loc, lambda x: np.isclose(x[0], xmin, atol=tol)
    )
    right_dofs_P = fem.locate_dofs_geometrical(
        P_loc, lambda x: np.isclose(x[0], xmax, atol=tol)
    )

    if (len(left_dofs_P) == 0) and (len(right_dofs_P) == 0):
        LCE_CG_int.append(int_qcg - int_f)
        LCE_rec_int.append(residual_j)
        indices_int.append(local_cell_idx)
# Out:
#   0%|          | 0/8192 [00:00<?, ?it/s]
# /tmp/ipykernel_167827/4043814364.py:68: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   n_edge = torch.tensor(n_edge, dtype=torch.float32)
# 100%|██████████| 8192/8192 [02:04<00:00, 65.69it/s]

# %%
indices_plot = np.array(indices_int, dtype=int)
LCE_CG_plot = np.array(LCE_CG_int, dtype=float)
LCE_rec_plot = np.array(LCE_rec_int, dtype=float)

# plot
plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")
plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
def stats(arr):
    return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
print("CG LCE stats:", stats(LCE_CG_plot))
print("Reconstructed LCE stats:", stats(LCE_rec_plot))
# Out:
# CG LCE stats: {'min': -0.0011392800727951802, 'max': 0.00025772402174570097, 'L1_mean_abs': 0.00010396642111009916, 'L2_rms': 0.0001693421679794889}
# Reconstructed LCE stats: {'min': -0.0001924418639472068, 'max': 0.0008820620956238431, 'L1_mean_abs': 4.1004008976766205e-05, 'L2_rms': 8.646145771842359e-05}

# %%
import matplotlib.ticker as mticker

indices_plot = np.array(indices_int, dtype=int)
LCE_CG_plot = np.array(LCE_CG_int, dtype=float)
LCE_rec_plot = np.array(LCE_rec_int, dtype=float)

plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")

plt.yscale("log")  # log-scale y-axis

# Format ticks as 10^{-1}, 10^{-2}, ...
plt.gca().yaxis.set_major_formatter(mticker.LogFormatterMathtext())
plt.gca().yaxis.set_major_locator(mticker.LogLocator(base=10))

plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True, which="both", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import os
# Define folder + filename
folder = "trained_nn"
filename = "cPINN_4sd_wr_0.05.pt"
path = os.path.join(folder, filename)

# Create folder if it does not exist
os.makedirs(folder, exist_ok=True)

checkpoint = {
    "epoch": epoch,
    "model_config": {
        "layers": 2,
        "width": 16,
        "activation": "tanh",
        "w_r": 0.05
    },
    "nets_state_dict": [net.state_dict() for net in nets],
    "optimizers_state_dict": [opt.state_dict() for opt in optimizers],
}

torch.save(checkpoint, path)

# %%
import matplotlib.pyplot as plt
indices_plot = np.array(indices, dtype=int)
LCE_CG_plot = np.array(LCE_CG, dtype=float)
LCE_rec_plot = np.array(LCE_rec, dtype=float)
loss_sd_plot = np.array([float(cc.detach()) for cc in loss_sd])

# plot
plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
# plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")
plt.plot(indices_plot, np.abs(loss_sd_plot), ".", label="LCE (reconstructed flux) From training")
plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
def stats(arr):
    return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
print("CG LCE stats:", stats(LCE_CG_plot))
print("Reconstructed LCE stats:", stats(LCE_rec_plot))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 5
#       3 LCE_CG_plot = np.array(LCE_CG, dtype=float)
#       4 LCE_rec_plot = np.array(LCE_rec, dtype=float)
# ----> 5 loss_sd_plot = np.array([float(cc.detach()) for cc in loss_sd])
#       7 # plot
#       8 plt.figure(figsize=(10,4))
#
# NameError: name 'loss_sd' is not defined

# %%
jump_CG = []
jump_rec = []
jump_indices = []   # cell indices

tdim = omega.topology.dim
gdim = omega.geometry.dim

# --- vertex -> cell connectivity (global) ---
cells_vtx = omega.topology.connectivity(0, tdim)
if cells_vtx is None:
    omega.topology.create_connectivity(0, tdim)
    cells_vtx = omega.topology.connectivity(0, tdim)

# --- cell -> vertex connectivity (global) ---
ctv = omega.topology.connectivity(tdim, 0)
if ctv is None:
    omega.topology.create_connectivity(tdim, 0)
    ctv = omega.topology.connectivity(tdim, 0)

num_cells = omega.topology.index_map(tdim).size_local

# Coordinate element for local 1-cell meshes
coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

local_edges = [(0, 1), (1, 2), (0, 2)]

for cell in range(num_cells):
    cell_jump_CG = 0.0
    cell_jump_rec = 0.0

    cell_verts = ctv.links(cell)
    coords_K = omega_geometry[cell_verts]

    sd = cell_subdomain[cell][0]

    # --- geometric data for this cell ---
    centroid = np.mean(coords_K, axis=0).reshape(1, -1)
    centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()

    for local_edge_idx, (la, lb) in enumerate(local_edges):
        v0 = cell_verts[la]
        v1 = cell_verts[lb]

        # ---- neighboring cell sharing this edge ----
        cells0 = cells_vtx.links(v0)
        cells1 = cells_vtx.links(v1)
        common_cells = np.intersect1d(cells0, cells1)

        if common_cells.size == 0:
            continue

        neighbor_cells = [int(c) for c in common_cells if int(c) != cell]

        # boundary edge → no contribution
        if len(neighbor_cells) == 0:
            continue

        cell_adj = neighbor_cells[0]

        facet_fluxes = []
        facet_fluxes_rec = []

        # ---------- two-sided loop (cell + neighbor) ----------
        for cell_side in (cell, cell_adj):
            cell_verts_side = ctv.links(cell_side)
            coords_side = omega_geometry[cell_verts_side]

            local_mesh = dmesh.create_mesh(
                MPI.COMM_SELF,
                loc_cells,
                coord_el,
                coords_side
            )

            tdim_loc = local_mesh.topology.dim
            fdim_loc = tdim_loc - 1
            local_mesh.topology.create_entities(fdim_loc)
            if local_mesh.topology.connectivity(fdim_loc, 0) is None:
                local_mesh.topology.create_connectivity(fdim_loc, 0)

            sd_side = cell_subdomain[cell_side][0]
            net_sd = nets[sd_side]

            P_loc = fem.functionspace(local_mesh, ("CG", order))
            p_K = fem.Function(P_loc)
            k_m_loc = fem.Function(P_loc)

            global_dofs = V.dofmap.cell_dofs(cell_side)
            local_dofs = P_loc.dofmap.cell_dofs(0)

            p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
            p_K.x.scatter_forward()

            k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
            k_m_loc.x.scatter_forward()

            q_CG = -k_m_loc * ufl.grad(p_K)
            n_K = ufl.FacetNormal(local_mesh)

            # vertex–facet connectivity
            local_mesh.topology.create_connectivity(0, fdim_loc)
            local_mesh.topology.create_connectivity(fdim_loc, 0)
            v_to_f = local_mesh.topology.connectivity(0, fdim_loc)
            f_to_v = local_mesh.topology.connectivity(fdim_loc, 0)

            lv0 = int(np.where(cell_verts_side == v0)[0][0])
            lv1 = int(np.where(cell_verts_side == v1)[0][0])

            edge_id = None
            for ff in v_to_f.links(lv0):
                if lv1 in f_to_v.links(ff):
                    edge_id = ff
                    break
            assert edge_id is not None

            mt = dmesh.meshtags(
                local_mesh,
                fdim_loc,
                np.array([edge_id], dtype=np.int32),
                np.array([1], dtype=np.int32)
            )
            ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=mt)

            flux_i = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ds(1))
            )
            facet_fluxes.append(flux_i)

            # ----- NN reconstructed flux -----
            centroid_side = np.mean(coords_side, axis=0).reshape(1, -1)
            centroid_t_side = torch.tensor(
                centroid_side, dtype=torch.float32, device=device
            ).squeeze()

            x0 = torch.tensor(omega_geometry[v0], dtype=torch.float32, device=device)
            x1 = torch.tensor(omega_geometry[v1], dtype=torch.float32, device=device)

            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t_side - midpoint) > 0:
                n_edge = -n_edge

            int_net_edge = integrate_edge_flux(
                net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3
            )
            facet_fluxes_rec.append(flux_i + float(int_net_edge))

        # ---------- sum jump on this edge ----------
        if len(facet_fluxes) == 2:
            cell_jump_CG += facet_fluxes[0] + facet_fluxes[1]
            cell_jump_rec += facet_fluxes_rec[0] + facet_fluxes_rec[1]

    # ---------- append ONCE per cell ----------
    jump_CG.append(cell_jump_CG)
    jump_rec.append(cell_jump_rec)
    jump_indices.append(cell)

# %%
jump_indices_plot = np.array(jump_indices, dtype=int)
jump_CG_plot = np.array(jump_CG, dtype=float)
jump_rec_plot = np.array(jump_rec, dtype=float)
loss_continuity_plot = np.array([cc.detach() for cc in loss_continuity_sd])

# plot
plt.figure(figsize=(10,4))
plt.plot(jump_indices_plot, jump_CG_plot, label="Jump (CG flux)")
plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
# plt.plot(jump_indices_plot, loss_continuity_plot, ".", label="Loss continuity (reconstructed flux)")
plt.xlabel("Element Index")
plt.ylabel("Jump")
plt.title("Jump per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
# def stats(arr):
#     return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
# print("CG LCE stats:", stats(LCE_CG_plot))
# print("Reconstructed LCE stats:", stats(LCE_rec_plot))

# %%
# plot
plt.figure(figsize=(10,4))
plt.plot(jump_indices_plot, abs(jump_CG_plot), label="Jump (CG flux)")
# plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
plt.plot(jump_indices_plot, abs(loss_continuity_plot), ".", label="Loss continuity (reconstructed flux)")
plt.xlabel("Element Index")
plt.ylabel("Jump")
plt.title("Jump per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 5
#       3 plt.plot(jump_indices_plot, abs(jump_CG_plot), label="Jump (CG flux)")
#       4 # plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
# ----> 5 plt.plot(jump_indices_plot, abs(loss_continuity_plot), ".", label="Loss continuity (reconstructed flux)")
#       6 plt.xlabel("Element Index")
#       7 plt.ylabel("Jump")
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (32,) and (4,)
