# %%
from mpi4py import MPI
import gmsh
import numpy as np
from scipy.spatial import cKDTree
import pyvista as pv
from dolfinx import plot

Lx, Ly = 1.0, 1.0

# %%
from dolfinx import mesh, fem
import ufl
import numpy as np
from dolfinx.io import gmsh as gmshio
from mpi4py import MPI

# ---------------------------------------------------------------------
# 1. Mesh and tags (same mesh as reference)
# ---------------------------------------------------------------------
ref = 6
filename = f"regular_mesh_{ref}.msh"
msh, cell_markers, facet_markers = gmshio.read_from_msh(filename, MPI.COMM_WORLD, 0, gdim=2)[0:3]

tdim = msh.topology.dim  # 2
fdim = tdim - 1          # 1

lc = 1.0 / (2**ref)      # mesh size
h = lc

omega = msh

# ---------------------------------------------------------------------
# 2. Function space (standard CG on the bulk only)
# ---------------------------------------------------------------------
order = 1
V = fem.functionspace(omega, ("Lagrange", order))

# ---------------------------------------------------------------------
# 3. Trial / Test / Solution function
# ---------------------------------------------------------------------
phi = ufl.TestFunction(V)
p = fem.Function(V, name="p")
dp = ufl.TrialFunction(V)

# ---------------------------------------------------------------------
# 4. Coordinates and data
# ---------------------------------------------------------------------
x = ufl.SpatialCoordinate(omega)
# f_m = fem.Constant(omega, 0.0)
# f_m = 2*(x[1] - x[1]**2 + x[0] - x[0]**2)
f_m = x[1]
def f_callable(x):
    return x[1]

f = fem.Function(V)
f_func = fem.Function(V)
f_func.interpolate(f_callable)
f.interpolate(f_callable)
# create function
k_m = fem.Function(V, name="kappa")

def k_callable(x):
    # x is array with shape (gdim, N). compute scalar per point, return shape (1,N)
    vals = 2*(x[0])
    return vals[np.newaxis, :]

k_m.interpolate(k_callable)

kappa = 1.0
# k_m = fem.Constant(omega, kappa)  # bulk permeability

dx = ufl.Measure("dx", domain=omega)

# compute domain bbox to locate sides
coords = omega.geometry.x
xx = coords[:, 0]
yy = coords[:, 1]
xmin, xmax = xx.min(), xx.max()
ymin, ymax = yy.min(), yy.max()

tol = 1e-10 * max(xmax - xmin, ymax - ymin)

# locate boundary facets for bottom (y = ymin) and top (y = ymax)
bottom_facets = mesh.locate_entities_boundary(
    omega, fdim, lambda x: np.isclose(x[1], ymin, atol=tol)
)
top_facets = mesh.locate_entities_boundary(
    omega, fdim, lambda x: np.isclose(x[1], ymax, atol=tol)
)

# create meshtags for those Neumann parts (optional — kept for clarity)
indices = np.concatenate([bottom_facets, top_facets]).astype(np.int32)
values = np.concatenate([
    np.full(bottom_facets.shape, 10, dtype=np.int32),  # bottom tag = 10
    np.full(top_facets.shape,    20, dtype=np.int32),  # top tag    = 20
])
neumann_tags = mesh.meshtags(omega, fdim, indices, values)

# boundary measure (we'll use ds over the whole boundary with conditional g_N)
dsN = ufl.Measure("ds", domain=omega)  # we integrate g_N over the boundary

# Neumann data as conditional on the y coordinate (same as reference)
# g_N = ufl.conditional(
#     ufl.lt(abs(x[1] - ymax), tol),
#     -1.0,                                # top
#     ufl.conditional(
#         ufl.lt(abs(x[1] - ymin), tol),
#         2.0,                             # bottom
#         0.0                              # elsewhere
#     ),
# )

# ---------------------------------------------------------------------
# 5. Weak form (standard Darcy / Poisson form)
# ---------------------------------------------------------------------
a = ufl.inner(k_m * ufl.grad(dp), ufl.grad(phi)) * dx
L = f_m * phi * dx
# L -= g_N * phi * dsN

# Form for assembling (bilinear/trilinear functions expect TrialFunction in a)
A_form = ufl.inner(k_m * ufl.grad(dp), ufl.grad(phi)) * dx
b_form = L

# ---------------------------------------------------------------------
# 6. Dirichlet BCs (left/right like reference)
# ---------------------------------------------------------------------
# locate dofs on each side
left_dofs   = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[0], xmin, atol=tol))
right_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[0], xmax, atol=tol))
top_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[1], ymax, atol=tol))
bottom_dofs  = fem.locate_dofs_geometrical(V, lambda x: np.isclose(x[1], ymin, atol=tol))

all_dofs = np.unique(np.concatenate([left_dofs, right_dofs]))
dof_coords = V.tabulate_dof_coordinates()

p_bc_fun = fem.Function(V)
p_bc_fun.x.array[left_dofs] = 0.0
p_bc_fun.x.array[right_dofs] = dof_coords[right_dofs, 1] / 2.0
# p_bc_fun.x.array[top_dofs] = 0.0
# p_bc_fun.x.array[bottom_dofs] = 0.0

bc = fem.dirichletbc(p_bc_fun, all_dofs)
bcs = [bc]

# ---------------------------------------------------------------------
# 7. Solve linear problem using dolfinx.fem.petsc.LinearProblem
# ---------------------------------------------------------------------
from dolfinx.fem import petsc

linear_problem = petsc.LinearProblem(
    a=A_form,
    L=b_form,
    bcs=bcs,
    petsc_options={
        "ksp_type": "preonly",
        "pc_type": "lu",
        "pc_factor_mat_solver_type": "mumps",
        "ksp_error_if_not_converged": True,
    },
    petsc_options_prefix="pmix_"
)

p_sol = linear_problem.solve()
p_sol.name = "pressure"

# optionally copy into p Function if you prefer
p.x.array[:] = p_sol.x.array[:]

# ---------------------------------------------------------------------
# 8. Diagnostics
# ---------------------------------------------------------------------
print("DOFs in V:", V.dofmap.index_map.size_global)
# Out:
# Info    : Reading 'regular_mesh_6.msh'...
# Info    : 36993 entities
# Info    : 4225 nodes
# Info    : 36993 elements
# Info    : Done reading 'regular_mesh_6.msh'
# DOFs in V: 4225

# %%
# Access mesh geometry
tdim = omega.topology.dim

# Gather coordinates and connectivity
omega_geometry = omega.geometry.x[:,0:2]  # global array of vertex coords
# Build cell->vertex mapping (fast access)
# Using dolfinx.Cell to get connectivity is more robust, but below uses mesh.topology
cells = omega.topology.connectivity(0, tdim)  # vertices -> cells
# Instead get cell->vertex mapping via mesh.topology.index_map?
# Simpler: use mesh.geometry.x with mesh.topology.connectivity(tdim, 0)
ctv = omega.topology.connectivity(tdim, 0)
if ctv is None:
    omega.topology.create_connectivity(tdim, 0)
    ctv = omega.topology.connectivity(tdim, 0)
# ctv.array() gives flattened vertex indices -> need per-cell view
# There's a helper to get cell entity indices
num_cells = omega.topology.index_map(tdim).size_local  # per-rank local count
# We'll iterate over local cells only
local_cells = np.arange(num_cells, dtype=np.int32)

# For evaluating u_h and kappa, we can use u_h.x.array if needed.
# But easier: create a point evaluation lambda to get value at a point
from dolfinx.fem import Function
u_func = p_sol
local_fluxes = {}
V_dofmap = V.dofmap.index_map.local_range  # not directly used; we'll query dofs per cell

# Get dof indices per cell
# Using dolfinx.fem.locate_dofs_topological is one option, but below we get cell_dofs
dofmap = V.dofmap
# But to avoid uncertain reshape semantics, use mesh.topology.connectivity(tdim, 0).entities
# Simpler robust approach: use dolfinx.mesh.cells() to get local cells vertex indices
try:
    from dolfinx.mesh import cells as dolfinx_cells
    local_cell_vertices = dolfinx_cells(mesh)
except Exception:
    # fallback: create by slicing connectivity
    # arr = ctv.array
    # local_cell_vertices = arr.reshape((-1, 3))
    local_cell_vertices = np.array([ctv.links(c) for c in range(ctv.num_nodes)])

# %%
tdim = omega.topology.dim
omega.topology.create_connectivity(tdim, tdim - 1)
omega.topology.create_connectivity(tdim - 1, tdim)

c2f = omega.topology.connectivity(tdim, tdim - 1)
f2c = omega.topology.connectivity(tdim - 1, tdim)

num_cells = omega.topology.index_map(tdim).size_local

local_cell_adjacent = [[] for _ in range(num_cells)]

for c in range(num_cells):
    neighbors = set()
    for ff in c2f.links(c):
        for cc in f2c.links(ff):
            if cc != c:
                neighbors.add(int(cc))
    local_cell_adjacent[c] = list(neighbors)

# %%
#facet vertices
tdim = omega.topology.dim
fdim = tdim - 1

# Make sure facet -> vertex connectivity exists
if omega.topology.connectivity(fdim, 0) is None:
    omega.topology.create_connectivity(fdim, 0)

f2v = omega.topology.connectivity(fdim, 0)

num_facets = omega.topology.index_map(fdim).size_local
local_facets = np.arange(num_facets, dtype=np.int32)

facet_vertices = []
facet_coords = []

x = omega.geometry.x  # global vertex coordinates

for ff in local_facets:
    verts = f2v.links(ff)          # vertex indices of facet f
    coords = x[verts]             # coordinates of those vertices

    facet_vertices.append(verts)
    facet_coords.append(coords)

# %%
import numpy as np
from collections import defaultdict

def compute_cell_subdomains_from_connectivity(
    local_cell_vertices,
    omega_geometry,
    n_per_dim,
    x0=0.0, x1=1.0,
    y0=0.0, y1=1.0,
):
    """
    Connectivity-based subdomain adjacency detection.
    Works for structured triangular meshes.

    Returns:
        cell_subdomain : list of lists
            [own_subdomain, adj1, adj2, ...]
    """

    m = n_per_dim
    dx = (x1 - x0) / m
    dy = (y1 - y0) / m

    n_cells = len(local_cell_vertices)

    # -------------------------------------------------
    # 1. Compute centroid-based OWNERSHIP only
    # -------------------------------------------------
    centroids = np.array([
        omega_geometry[verts].mean(axis=0)
        for verts in local_cell_vertices
    ])

    own_sub = []

    for x_c, y_c in centroids:
        ix = int((x_c - x0) / dx)
        iy = int((y_c - y0) / dy)

        ix = max(0, min(m - 1, ix))
        iy = max(0, min(m - 1, iy))

        own_sub.append(iy * m + ix)

    # -------------------------------------------------
    # 2. Build edge-to-cell map
    # -------------------------------------------------
    edge_map = defaultdict(list)

    for cell_id, verts in enumerate(local_cell_vertices):
        nv = len(verts)
        for k in range(nv):
            v0 = verts[k]
            v1 = verts[(k + 1) % nv]

            edge = tuple(sorted((v0, v1)))
            edge_map[edge].append(cell_id)

    # -------------------------------------------------
    # 3. Detect adjacency via shared edges
    # -------------------------------------------------
    cell_subdomain = []

    for cell_id in range(n_cells):

        subs = [own_sub[cell_id]]

        verts = local_cell_vertices[cell_id]
        nv = len(verts)

        for k in range(nv):
            v0 = verts[k]
            v1 = verts[(k + 1) % nv]
            edge = tuple(sorted((v0, v1)))

            neighbors = edge_map[edge]

            for nb in neighbors:
                if nb == cell_id:
                    continue

                nb_sub = own_sub[nb]
                if nb_sub != own_sub[cell_id] and nb_sub not in subs:
                    subs.append(nb_sub)

        cell_subdomain.append(subs)

    return cell_subdomain


num_subdomains = 4
cell_subdomain = compute_cell_subdomains_from_connectivity(local_cell_vertices, omega_geometry, int(np.sqrt(num_subdomains)))

# %%
import matplotlib.pyplot as plt
import numpy as np

centroids = np.array([omega_geometry[i].mean(axis=0) 
                      for i in local_cell_vertices])

fig, ax = plt.subplots()

for idx, (x, y) in enumerate(centroids):
    ax.plot(x, y, marker='o')          # plot point (not scatter)
    ax.text(x, y, str(idx),            # label with enumerate index
            fontsize=10,
            ha='center', va='center')

ax.set_aspect('equal')
plt.show()

# %%
fig, ax = plt.subplots()

for idx, (x, y) in enumerate(centroids):
    ax.plot(x, y, marker='o')          # plot point (not scatter)
    ax.text(x, y, str(cell_subdomain[idx][0]),            # label with enumerate index
            fontsize=10,
            ha='center', va='center')

ax.set_aspect('equal')
plt.show()

# %%
import numpy as np
import torch
import torch.nn as nn
import cma
from tqdm import tqdm
import basix
from dolfinx import default_scalar_type, mesh as dmesh
import math

# ---------------------------------------------------------
# 1. Define a small NN for flux (or flux correction)
# ---------------------------------------------------------
class AdaptiveTanh(nn.Module):
    def __init__(self, n=5.0):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(1.0 / n))  # scalar a^k

    def forward(self, x):
        return torch.tanh(self.a * x)
    
class AdaptiveSin(nn.Module):
    def __init__(self, n=5.0):
        super().__init__()
        self.a = nn.Parameter(torch.tensor(1.0 / n))  # scalar a^k

    def forward(self, x):
        return torch.sin(self.a * x) #+ torch.cos(self.a * x)
    
class FluxNet(nn.Module):
    def __init__(self, in_dim=1, out_dim=1, hidden_dim=32, n = 5.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, hidden_dim),
            AdaptiveTanh(n=n),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        # x: tensor of shape (N, in_dim)
        return self.net(x)
    
    def slope_recovery_term(self):
        # collect all a^k from hidden layers
        slopes = []
        for m in self.net:
            if isinstance(m, AdaptiveTanh) or isinstance(m, AdaptiveSin):
                slopes.append(m.a)

        a = torch.stack(slopes)                 # shape: (L-1,)
        return 1.0 / torch.mean(torch.exp(a))   # S(a)
    
    def zero_last_layer(self):
        last = self.net[-1]
        nn.init.constant_(last.weight, 0.0)
        if last.bias is not None:
            nn.init.constant_(last.bias, 0.0)

    def siren_init(self):
        """
        Apply SIREN initialization to all Linear layers.
        Assumes AdaptiveSin(n=n) uses frequency multiplier n.
        """
        for i, m in enumerate(self.net):
            if isinstance(m, nn.Linear):
                fan_in = m.in_features

                if i == 0:
                    # First layer
                    bound = 1.0 / fan_in
                else:
                    # Hidden layers
                    # Find preceding AdaptiveSin to get its frequency n
                    prev = self.net[i - 1]
                    if isinstance(prev, AdaptiveSin):
                        omega = float(prev.a)
                    else:
                        omega = 1.0

                    bound = (math.sqrt(6 / fan_in)) / omega

                nn.init.uniform_(m.weight, -bound, bound)

                if m.bias is not None:
                    nn.init.uniform_(m.bias, -bound, bound)


nets = [FluxNet(in_dim=2, out_dim=2, hidden_dim=8) for _ in range(num_subdomains)]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for net in nets:
    net.to(device)
    # net.siren_init()
    net.zero_last_layer()

# ---------------------------------------------------------
# 2. Utilities to flatten / unflatten parameters
# ---------------------------------------------------------

def get_flat_params_from(net: nn.Module) -> np.ndarray:
    """
    Returns a 1D numpy array containing all parameters of the network.
    """
    with torch.no_grad():
        vec = torch.nn.utils.parameters_to_vector(net.parameters())
    return vec.cpu().numpy()


def set_flat_params_to(net: nn.Module, theta: np.ndarray):
    """
    Loads a 1D numpy array `theta` back into the network parameters.
    """
    theta_torch = torch.tensor(theta, dtype=torch.float32)
    with torch.no_grad():
        torch.nn.utils.vector_to_parameters(theta_torch, net.parameters())


# ---------------------------------------------------------
# 3. Define a loss function for CMA-ES (gradient-free)
# ---------------------------------------------------------

# Precompute sample points (these play the role of quadrature points)
# x_np = np.linspace(0.0, 1.0, 128, endpoint=True)
x_np = V.tabulate_dof_coordinates()
x_torch = torch.tensor(x_np, dtype=torch.float32).view(-1, 1)
gdim = omega_geometry.shape[1]

xi = torch.tensor(
        [
            0.5 * (1.0 - 1.0 / math.sqrt(3.0)),
            0.5 * (1.0 + 1.0 / math.sqrt(3.0)),
        ],
        dtype=torch.float32,
        device=device,
    )
wi = torch.tensor([0.5, 0.5], dtype=torch.float32, device=device)

def integrate_edge_flux(net, x0, x1, n_edge, L, xi, wi, num_sub):
    """
    Compute ∫_edge (net(x)·n_edge) ds via composite quadrature.
    """
    t = x1 - x0
    h = 1.0 / num_sub

    int_edge = 0.0
    for j in range(num_sub):
        s_left = j * h
        for k in range(len(xi)):
            s = s_left + h * xi[k]
            w = h * wi[k]

            x_q = x0 + s * t
            r_q = net(x_q.unsqueeze(0))[0]  # (dim,)

            int_edge = int_edge + torch.dot(r_q, n_edge) * L * w

    return int_edge

def compute_element_continuity(nets):
    device = next(nets[0].parameters()).device
    num_vertices = omega_geometry.shape[0]
    
    # 1) Build vertex → {subdomains} map
    vertex_subdomains = [set() for _ in range(num_vertices)]

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx]  # 0,1,2,3
        for v in cell_verts:
            vertex_subdomains[v].add(sd)

    # Sort so we can index [0], [1] deterministically
    vertex_subdomains = [sorted(vv) for vv in vertex_subdomains]

    # 2) Loop over cells and edges, accumulate per-subdomain penalty
    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]

    tdim = omega.topology.dim
    cells_vtx = omega.topology.connectivity(0, tdim)

    pairs = list(enumerate(local_cell_vertices))
    random.shuffle(pairs)

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    # for local_cell_idx, cell_verts in pairs:
        sd = cell_subdomain[local_cell_idx]
        coords = omega_geometry[cell_verts]
        centroid = np.mean(coords, axis=0).reshape(1, -1)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()
        loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

        # edges in terms of *global vertex indices*
        # edge_indices = [
        #     (cell_verts[0], cell_verts[1]),
        #     (cell_verts[1], cell_verts[2]),
        #     (cell_verts[2], cell_verts[0])
        # ]
        edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

        coord_el = basix.ufl.element(
            "Lagrange", "triangle", 1, shape=(gdim,)
        )

        local_mesh = dmesh.create_mesh(
            MPI.COMM_SELF, loc_cells, coord_el, coords
        )
        tdim = local_mesh.topology.dim
        fdim = tdim - 1
        # Make sure facet entities / connectivity exist
        local_mesh.topology.create_connectivity(tdim, fdim)
        local_mesh.topology.create_connectivity(fdim, tdim)

        # Total number of facets
        num_facets = local_mesh.topology.index_map(fdim).size_local

        V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
        P_loc = fem.functionspace(local_mesh, ("CG", order))

        p_K = fem.Function(P_loc)
        k_m_loc = fem.Function(P_loc)
        f_m_loc = fem.Function(P_loc)

        x_loc = V_loc.tabulate_dof_coordinates()[:, :2]
        x_loc_torch = torch.tensor(x_loc, dtype=torch.float32, device=device)

        # ---------------- r_theta integral ----------------
        coords_t = torch.tensor(coords, dtype=torch.float32, device=device)

        # ---------------- CG flux + source ----------------
        global_dofs = V.dofmap.cell_dofs(local_cell_idx)
        local_dofs = P_loc.dofmap.cell_dofs(0)

        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
        f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()
        f_m_loc.x.scatter_forward()

        q_CG = -k_m_loc * ufl.grad(p_K)
        n_K = ufl.FacetNormal(local_mesh)

        cell_adj = local_cell_adjacent[local_cell_idx]

        for (v0, v1) in edge_indices_loc:
            i0 = cell_verts[v0]
            i1 = cell_verts[v1]
            # Only interface edges between exactly 2 subdomains, and the same pair at both endpoints
            if (len(vertex_subdomains[i0]) >= 2 and len(vertex_subdomains[i1]) >= 2):
                edge_sds = set(vertex_subdomains[i0]) & set(vertex_subdomains[i1])

                # Remove the current cell's subdomain
                sd_adj_set = edge_sds - {sd}

                if len(sd_adj_set) != 1:
                    # edge not between exactly two subdomains, skip or handle
                    continue
                sd_adj = next(iter(sd_adj_set))
                
                #find the CG flux in the edge
                local_mesh.topology.create_connectivity(0, fdim)
                local_mesh.topology.create_connectivity(fdim, 0)

                v_to_f = local_mesh.topology.connectivity(0, fdim)
                f_to_v = local_mesh.topology.connectivity(fdim, 0)

                edge_id = None
                for ff in v_to_f.links(v0):
                    verts = f_to_v.links(ff)
                    if v1 in verts:
                        edge_id = ff
                        break

                # All facet indices
                facets = np.arange(num_facets, dtype=np.int32)

                # Tag values: 0 = unmarked
                values = np.zeros(num_facets, dtype=np.int32)

                # Pick ANY positive integer as the tag
                EDGE_TAG = 1
                values[edge_id] = EDGE_TAG

                facet_tags = mesh.meshtags(local_mesh, fdim, facets, values)

                ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

                int_qcg_edge = fem.assemble_scalar(
                    fem.form(ufl.dot(q_CG, n_K) * ds(EDGE_TAG))
                )

                # LOCAL MESH ADJ
                # find neighbor cell along this edge (same as code 2)
                cells0 = cells_vtx.links(i0)
                cells1 = cells_vtx.links(i1)
                common_cells = np.intersect1d(cells0, cells1)
                neighbor_cells = [int(c) for c in common_cells if int(c) != local_cell_idx]
                if len(neighbor_cells) == 0:
                    continue  # boundary / inconsistent mesh
                local_cell_idx_adj = neighbor_cells[0]

                cell_verts_adj = local_cell_vertices[local_cell_idx_adj]
                # find local indices in the neighbor that match i0, i1
                try:
                    loc0_adj = int(np.where(cell_verts_adj == i0)[0][0])
                    loc1_adj = int(np.where(cell_verts_adj == i1)[0][0])
                except IndexError:
                    # neighbor doesn't actually share both these vertices -> skip
                    continue
                coords_adj = omega_geometry[cell_verts_adj]
                centroid_adj = np.mean(coords_adj, axis=0).reshape(1, -1)
                centroid_t_adj = torch.tensor(centroid_adj, dtype=torch.float32, device=device).squeeze()
                local_mesh_adj = dmesh.create_mesh(
                    MPI.COMM_SELF, loc_cells, coord_el, coords_adj
                )
                V_loc_adj = fem.functionspace(local_mesh_adj, ("CG", order + 1, (gdim,)))
                P_loc_adj = fem.functionspace(local_mesh_adj, ("CG", order))

                p_K_adj = fem.Function(P_loc_adj)
                k_m_loc_adj = fem.Function(P_loc_adj)

                x_loc_adj = V_loc_adj.tabulate_dof_coordinates()[:, :2]

                global_dofs_adj = V.dofmap.cell_dofs(local_cell_idx_adj)
                local_dofs_adj = P_loc_adj.dofmap.cell_dofs(0)

                p_K_adj.x.array[local_dofs_adj] = p_sol.x.array[global_dofs_adj]
                k_m_loc_adj.x.array[local_dofs_adj] = k_m.x.array[global_dofs_adj]

                p_K_adj.x.scatter_forward()
                k_m_loc_adj.x.scatter_forward()

                q_CG_adj = -k_m_loc_adj * ufl.grad(p_K_adj)
                n_K_adj = ufl.FacetNormal(local_mesh_adj)

                #find the CG flux adj in the edge
                local_mesh_adj.topology.create_connectivity(0, fdim)
                local_mesh_adj.topology.create_connectivity(fdim, 0)

                v_to_f_adj = local_mesh_adj.topology.connectivity(0, fdim)
                f_to_v_adj = local_mesh_adj.topology.connectivity(fdim, 0)

                edge_id_adj = None
                for ff in v_to_f_adj.links(loc0_adj):
                    verts = f_to_v_adj.links(ff)
                    if loc1_adj in verts:
                        edge_id_adj = ff
                        break

                # All facet indices
                facets_adj = np.arange(num_facets, dtype=np.int32)

                # Tag values: 0 = unmarked
                values_adj = np.zeros(num_facets, dtype=np.int32)

                # Pick ANY positive integer as the tag
                EDGE_TAG = 1
                values_adj[edge_id_adj] = EDGE_TAG

                facet_tags_adj = mesh.meshtags(local_mesh_adj, fdim, facets_adj, values_adj)

                ds_adj = ufl.Measure("ds", domain=local_mesh_adj, subdomain_data=facet_tags_adj)

                int_qcg_edge_adj = fem.assemble_scalar(
                    fem.form(ufl.dot(q_CG_adj, n_K_adj) * ds_adj(EDGE_TAG))
                )

                # ---- geometric data (on the right device) ----
                x0 = torch.tensor(omega_geometry[i0], dtype=torch.float32, device=device)
                x1 = torch.tensor(omega_geometry[i1], dtype=torch.float32, device=device)

                t = x1 - x0
                L = torch.linalg.norm(t)
                if L <= 0:
                    continue

                n_edge = torch.stack([t[1], -t[0]]) / L
                midpoint = 0.5 * (x0 + x1)
                if torch.dot(n_edge, centroid_t - midpoint) > 0:
                    n_edge = -n_edge

                # subdomain pair sharing this edge
                # if vertex_subdomains[i0][0] == sd:
                #     sd_adj = vertex_subdomains[i0][1]
                # elif vertex_subdomains[i0][1] == sd:
                #     sd_adj = vertex_subdomains[i0][0]
                net_sd = nets[sd]
                net_sd_adj  = nets[sd_adj]

                int_net_edge = integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
                int_net_edge_adj = integrate_edge_flux(net_sd_adj, x0, x1, -n_edge, L, xi, wi, num_sub=3)

                # add the same penalty to both subdomains
                res = int_net_edge + int_qcg_edge + int_net_edge_adj + int_qcg_edge_adj
                loss_sd[sd] += res**2
                # loss_sd[sd_adj]  += res_con
                count_sd[sd] += 1
                # count_sd[sd_adj]  += 1

    # 3) normalize by number of contributions per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd
 
def grad_norm(model):
    total_norm = 0.0
    for p in model.parameters():
        if p.grad is not None:
            param_norm = p.grad.detach().norm(2)
            total_norm += param_norm**2
    return total_norm.sqrt()

num_cells = len(local_cell_vertices)
cells_per_sd = num_cells // num_subdomains

def l2_norm_network(net, omega_geometry, dx=None, weights=None, device=None):
    """
    Approximate L2 norm of `net` over the set of points omega_geometry.

    Parameters
    ----------
    net : nn.Module
        Network with output shape (N, out_dim).
    omega_geometry : array-like, shape (N, in_dim)
        Coordinates where the network is evaluated.
    dx : float, optional
        Uniform measure per point, e.g. cell size. If given and `weights` is None:
            integral ≈ dx * sum_i ||u(x_i)||^2
    weights : array-like, optional
        Non-uniform weights w_i (e.g. quadrature weights * cell volumes).
        If given:
            integral ≈ sum_i w_i ||u(x_i)||^2
    device : torch.device, optional
        Device where computation runs. If None, inferred from `net`.

    Returns
    -------
    torch.Tensor
        Scalar tensor: approximate L2 norm.
    """
    if device is None:
        device = next(net.parameters()).device

    x = torch.as_tensor(omega_geometry, dtype=torch.float32, device=device)
    u = net(x)                           # (N, out_dim)
    norms_sq = torch.sum(u**2, dim=1)    # ||u(x_i)||^2, shape (N,)

    if weights is not None:
        w = torch.as_tensor(weights, dtype=torch.float32, device=device)
        assert w.shape == norms_sq.shape, "weights must have same shape as points"
        integral_approx = torch.sum(w * norms_sq)
    elif dx is not None:
        integral_approx = dx * torch.sum(norms_sq)
    else:
        # No geometric info: treat as average over points.
        # If |Ω| = 1 (e.g. domain [0,1]^d), this coincides with L2 norm.
        integral_approx = torch.mean(norms_sq)

    return integral_approx

def grad_norm_from_loss(loss, net):
    """
    Compute L2 norm of gradients of `loss` w.r.t. all parameters of `net`.
    Uses autograd.grad (does NOT write into param.grad).
    """
    grads = torch.autograd.grad(
        loss,
        [p for p in net.parameters() if p.requires_grad],
        retain_graph=True,
        create_graph=False,
        allow_unused=True,
    )
    sq_sum = 0.0
    for g in grads:
        if g is not None:
            sq_sum = sq_sum + g.pow(2).sum()
    return sq_sum.sqrt()

# ---------------------------------------------------------
# 4. Train the network with Adam (gradient-based)
# ---------------------------------------------------------
# import torch

# Put network on desired device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# net.to(device)

# Adam optimizer
learning_rate = 1e-3
# all_params = []
# for net in nets:
#     all_params += list(net.parameters())

# optimizer = torch.optim.Adam(all_params, lr=1e-3)
optimizers = [
    torch.optim.Adam(nets[k].parameters(), lr=1e-3)
    for k in range(num_subdomains)
]

max_epochs = 800    # or whatever you like
mse_it = []

best_loss = float("inf")
best_state = None
W_f = 1.0e3   # flux term
W_c = 1.0e2     # continuity
W_a = 1.0    # slope regularizer (between 0.007 and 0.07 is reasonable)
# W_r = 1.0e1
# ckpt = torch.load("checkpoint.pt")
# net.load_state_dict(ckpt["model_state_dict"])
# optimizer.load_state_dict(ckpt["optimizer_state_dict"])
# start_epoch = ckpt["epoch"] + 1

loss_sd_arr = [[] for _ in range(num_subdomains)]
loss_cont_arr = [[] for _ in range(num_subdomains)]
loss_total_arr = [[] for _ in range(num_subdomains)]

loss_lc_avg_arr = []
loss_cont_avg_arr = []

subdomain_cell = [[] for _ in range(num_subdomains)]

for cell_idx, subs in enumerate(cell_subdomain):
    own_sub = subs[0]        # index 0 = own subdomain
    subdomain_cell[own_sub].append(cell_idx)

# use sets to avoid duplicates
subdomain_vertices = [set() for _ in range(num_subdomains)]

for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    own_sub = cell_subdomain[local_cell_idx][0]
    subdomain_vertices[own_sub].update(cell_verts)

# convert sets to lists (optional: sorted for consistency)
subdomain_vertices = [sorted(list(vset)) for vset in subdomain_vertices]

# %%
subdomain_vertices_coord = [[omega_geometry[j] for j in subdomain_vertices[i]] for i in range(num_subdomains)]

# %%
def precompute_cell_flux_and_source():
    """
    Precompute, for each cell K:
        int_qcg[K] = ∫_{∂K} q_CG · n ds
        int_f[K]   = ∫_K f dx
    where q_CG = -k_m * grad(p_sol).

    Returns:
        cell_flux: dict mapping cell_idx -> (int_qcg, int_f)
    """
    cell_flux = {}

    gdim = omega_geometry.shape[1]

    # 1-cell template mesh
    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
    dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

    local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)

    tdim = local_mesh.topology.dim

    V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
    P_loc = fem.functionspace(local_mesh, ("CG", order))

    p_K = fem.Function(P_loc)
    k_m_loc = fem.Function(P_loc)
    f_m_loc = fem.Function(P_loc)

    # Local DOFs for the single template cell
    local_dofs = P_loc.dofmap.cell_dofs(0)

    n_K = ufl.FacetNormal(local_mesh)
    q_CG = -k_m_loc * ufl.grad(p_K)

    ds = ufl.ds(domain=local_mesh)
    dx = ufl.dx(domain=local_mesh)

    for cell_idx, cell_verts in enumerate(local_cell_vertices):
        coords = omega_geometry[cell_verts]
        # update geometry
        local_mesh.geometry.x[:, :gdim] = coords

        # copy global DOFs into local functions
        global_dofs = V.dofmap.cell_dofs(cell_idx)
        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
        f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()
        f_m_loc.x.scatter_forward()

        # assemble cell-level quantities
        int_qcg = fem.assemble_scalar(fem.form(ufl.dot(q_CG, n_K) * ds))
        int_f   = fem.assemble_scalar(fem.form(f_m_loc * dx))

        cell_flux[cell_idx] = (float(int_qcg), float(int_f))

    return cell_flux

cell_flux = precompute_cell_flux_and_source()

# %%
def precompute_interface_cg_fluxes():
    """
    Precompute ∫_e q_CG · n_K ds for every cell edge.
    Returns:
        cg_flux[(cell_idx, local_edge_id)] = float
    """

    cg_flux = {}

    gdim = omega_geometry.shape[1]

    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
    dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

    local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)

    tdim = local_mesh.topology.dim
    fdim = tdim - 1

    local_mesh.topology.create_connectivity(tdim, fdim)
    local_mesh.topology.create_connectivity(fdim, tdim)
    local_mesh.topology.create_connectivity(0, fdim)
    local_mesh.topology.create_connectivity(fdim, 0)

    num_facets = local_mesh.topology.index_map(fdim).size_local

    facets = np.arange(num_facets, dtype=np.int32)
    facet_values = np.arange(num_facets, dtype=np.int32)
    facet_tags = mesh.meshtags(local_mesh, fdim, facets, facet_values)

    ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

    V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
    P_loc = fem.functionspace(local_mesh, ("CG", order))

    p_K = fem.Function(P_loc)
    k_m_loc = fem.Function(P_loc)

    local_dofs = P_loc.dofmap.cell_dofs(0)

    n_K = ufl.FacetNormal(local_mesh)
    q_CG = -k_m_loc * ufl.grad(p_K)

    # Build edge mapping
    v_to_f = local_mesh.topology.connectivity(0, fdim)
    f_to_v = local_mesh.topology.connectivity(fdim, 0)

    edge_to_facet = {}
    for v0 in range(3):
        for fct in v_to_f.links(v0):
            verts = f_to_v.links(fct)
            for v1 in verts:
                if v1 != v0:
                    edge_to_facet[(v0, v1)] = fct

    edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

    for cell_idx, cell_verts in enumerate(local_cell_vertices):

        coords = omega_geometry[cell_verts]
        local_mesh.geometry.x[:, :gdim] = coords

        global_dofs = V.dofmap.cell_dofs(cell_idx)

        p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
        k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]

        p_K.x.scatter_forward()
        k_m_loc.x.scatter_forward()

        for edge_loc, (v0, v1) in enumerate(edge_indices_loc):
            facet_id = edge_to_facet[(v0, v1)]

            value = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ds(facet_id))
            )

            cg_flux[(cell_idx, edge_loc)] = value

    return cg_flux

cg_flux = precompute_interface_cg_fluxes()

# %%
num_vertices = omega_geometry.shape[0]

# 1) Build vertex → {subdomains} map  (unchanged)
vertex_subdomains = [set() for _ in range(num_vertices)]
for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
    sd = cell_subdomain[local_cell_idx][0]  # 0,1,2,3
    for v in cell_verts:
        vertex_subdomains[v].add(sd)
vertex_subdomains = [sorted(vv) for vv in vertex_subdomains]


# --- connectivity on the global mesh (used for neighbor search) ---
tdim = omega.topology.dim
omega.topology.create_connectivity(0, tdim)
cells_vtx = omega.topology.connectivity(0, tdim)

# randomize cell order (unchanged logic)
# pairs = list(enumerate(local_cell_vertices))
# random.shuffle(pairs)

# ------------------------------------------------------------
# NEW: Precompute a single 1-cell local mesh + spaces + facet tags
# ------------------------------------------------------------
gdim = omega_geometry.shape[1]

coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
loc_cells = np.array([[0, 1, 2]], dtype=np.int64)
dummy_coords = np.zeros((3, gdim), dtype=omega_geometry.dtype)

local_mesh = dmesh.create_mesh(MPI.COMM_SELF, loc_cells, coord_el, dummy_coords)
tdim_loc = local_mesh.topology.dim
fdim = tdim_loc - 1

local_mesh.topology.create_connectivity(tdim_loc, fdim)
local_mesh.topology.create_connectivity(fdim, tdim_loc)
local_mesh.topology.create_connectivity(0, fdim)
local_mesh.topology.create_connectivity(fdim, 0)

num_facets = local_mesh.topology.index_map(fdim).size_local

# Tag each facet with its own index: 0,1,2
facets = np.arange(num_facets, dtype=np.int32)
facet_values = np.arange(num_facets, dtype=np.int32)
facet_tags = mesh.meshtags(local_mesh, fdim, facets, facet_values)

ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=facet_tags)

V_loc = fem.functionspace(local_mesh, ("CG", order + 1, (gdim,)))
P_loc = fem.functionspace(local_mesh, ("CG", order))

p_K = fem.Function(P_loc)
k_m_loc = fem.Function(P_loc)
f_m_loc = fem.Function(P_loc)

# Local DOFs for the single cell of the template mesh
local_dofs = P_loc.dofmap.cell_dofs(0)

n_K = ufl.FacetNormal(local_mesh)
q_CG = -k_m_loc * ufl.grad(p_K)

# Build a robust edge (v0,v1) -> facet_id map once
v_to_f = local_mesh.topology.connectivity(0, fdim)
f_to_v = local_mesh.topology.connectivity(fdim, 0)
edge_to_facet = {}
for v0 in range(3):
    for fct in v_to_f.links(v0):
        verts = f_to_v.links(fct)
        for v1 in verts:
            if v1 != v0:
                edge_to_facet[(v0, v1)] = fct

# Local edge list (same as before)
edge_indices_loc = [(0, 1), (1, 2), (2, 0)]

# Precompute geometry tensor (no grad; acts as constant input to nets)
omega_geometry_t = torch.tensor(omega_geometry, dtype=torch.float32, device=device)
edge_pair_to_id = {
    (0, 1): 0,
    (1, 2): 1,
    (2, 0): 2,
    (1, 0): 0,
    (2, 1): 1,
    (0, 2): 2,
}
def compute_subdomain_continuity(nets):
    device = next(nets[0].parameters()).device
    # 2) Per-subdomain loss accumulators  (unchanged)
    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]
    # ------------------------------------------------------------
    # 3) Loop over cells and edges
    # ------------------------------------------------------------
    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx][0]

        cell_verts_np = np.asarray(cell_verts, dtype=np.int64)
        coords = omega_geometry[cell_verts_np]
        centroid = coords.mean(axis=0)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device)

        for edge_loc, (v0_loc, v1_loc) in enumerate(edge_indices_loc):
            i0 = int(cell_verts_np[v0_loc])
            i1 = int(cell_verts_np[v1_loc])

            # Only interface edges between exactly 2 subdomains
            if (len(vertex_subdomains[i0]) < 2 or len(vertex_subdomains[i1]) < 2):
                continue

            edge_sds = set(vertex_subdomains[i0]) & set(vertex_subdomains[i1])
            sd_adj_set = edge_sds - {sd}
            if len(sd_adj_set) != 1:
                continue
            sd_adj = next(iter(sd_adj_set))

            # ---- CG flux integral on this edge for current cell (precomputed) ----
            # If missing (e.g. boundary), treat as zero
            int_qcg_edge = cg_flux.get((local_cell_idx, edge_loc), 0.0)

            # ---- find neighbor cell sharing (i0, i1) ----
            cells0 = cells_vtx.links(i0)
            cells1 = cells_vtx.links(i1)
            common_cells = np.intersect1d(cells0, cells1)
            neighbor_cells = [int(c) for c in common_cells if int(c) != local_cell_idx]
            if not neighbor_cells:
                continue
            local_cell_idx_adj = neighbor_cells[0]

            # local indices of i0, i1 in neighbor cell
            cell_verts_adj = local_cell_vertices[local_cell_idx_adj]
            try:
                loc0_adj = int(np.where(cell_verts_adj == i0)[0][0])
                loc1_adj = int(np.where(cell_verts_adj == i1)[0][0])
            except IndexError:
                # neighbor doesn't actually share both these vertices
                continue

            # local edge id for neighbor cell
            edge_loc_adj = edge_pair_to_id[(loc0_adj, loc1_adj)]

            # CG flux integral for neighbor cell on same geometric edge
            int_qcg_edge_adj = cg_flux.get((local_cell_idx_adj, edge_loc_adj), 0.0)

            # ---- geometric data for NN fluxes ----
            x0 = omega_geometry_t[i0]
            x1 = omega_geometry_t[i1]

            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            # outward normal (in plane) w.r.t. current cell
            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t - midpoint) > 0:
                n_edge = -n_edge

            net_sd = nets[sd]
            net_sd_adj = nets[sd_adj]

            # Keep gradients: these calls must NOT be in no_grad
            int_net_edge = integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
            int_net_edge_adj = integrate_edge_flux(net_sd_adj, x0, x1, -n_edge, L, xi, wi, num_sub=3)

            # q_CG integrals are plain floats (constants); nets carry grad
            res = int_net_edge + int_qcg_edge + int_net_edge_adj + int_qcg_edge_adj

            loss_sd[sd] += res**2
            count_sd[sd] += 1

    # 3) normalize by number of contributions per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd

# %%
def compute_flux_loss(nets, it=None):
    """
    nets      : list of PyTorch models, one per subdomain
    cell_flux : dict mapping cell_idx -> (int_qcg, int_f)
                where
                  int_qcg = ∫_{∂K} q_CG · n ds  (float)
                  int_f   = ∫_K f dx           (float)
    """
    device = next(nets[0].parameters()).device

    loss_sd = [torch.zeros((), device=device) for _ in range(num_subdomains)]
    count_sd = [0 for _ in range(num_subdomains)]

    # geometry as torch constant (no grad wrt nets)
    omega_geometry_t = torch.tensor(omega_geometry, dtype=torch.float32, device=device)

    edge_indices = [(0, 1), (1, 2), (2, 0)]
    num_sub = 3  # sub-intervals per edge

    for local_cell_idx, cell_verts in enumerate(local_cell_vertices):
        sd = cell_subdomain[local_cell_idx][0]
        net = nets[sd]
        count_sd[sd] += 1

        # --- geometry (torch) ---
        cell_verts_np = np.asarray(cell_verts, dtype=np.int64)
        coords_t = omega_geometry_t[cell_verts_np]  # shape (3, gdim)
        centroid_t = coords_t.mean(dim=0)

        # ---------------- r_theta integral (NN flux over boundary) ----------------
        int_r_local = torch.zeros((), device=device)

        for (i0, i1) in edge_indices:
            x0 = coords_t[i0]
            x1 = coords_t[i1]
            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t - midpoint) > 0:
                n_edge = -n_edge

            h = 1.0 / num_sub

            for j in range(num_sub):
                s_left = j * h
                for k in range(len(xi)):
                    s = s_left + h * xi[k]
                    w = h * wi[k]

                    x_q = x0 + s * t  # point on edge, torch
                    r_q = net(x_q.unsqueeze(0))[0]  # NN flux at quadrature point

                    int_r_local = int_r_local + torch.dot(r_q, n_edge) * L * w

        # ---------------- CG flux + source (precomputed) ----------------
        int_qcg, int_f = cell_flux.get(local_cell_idx, (0.0, 0.0))

        int_qcg_t = torch.tensor(int_qcg, dtype=torch.float32, device=device)
        int_f_t   = torch.tensor(int_f, dtype=torch.float32, device=device)

        residual = int_r_local + int_qcg_t - int_f_t

        loss_sd[sd] += residual**2

    # normalize by number of cells per subdomain
    for k in range(num_subdomains):
        if count_sd[k] > 0:
            loss_sd[k] /= count_sd[k]

    return loss_sd

# %%
from dolfinx import geometry
local_cell_centroid = []
for local_cell_idx, cell_verts in enumerate(tqdm(local_cell_vertices)):
    # cell_verts are global vertex indices
    coords = omega_geometry[cell_verts]  # shape (3,2)
    centroid = np.mean(coords, axis=0).reshape(1,-1)
    local_cell_centroid.append(centroid)

# Reference-cell centroid (barycenter) for common cell types
if tdim == 1:
    # interval [0, 1]
    X_ref = np.array([[0.5]], dtype=np.float64)
elif tdim == 2:
    # triangle: vertices (0,0), (1,0), (0,1)
    X_ref = np.array([[1/3, 1/3]], dtype=np.float64)
elif tdim == 3:
    # tetrahedron: vertices (0,0,0), (1,0,0), (0,1,0), (0,0,1)
    X_ref = np.array([[1/3, 1/3, 1/3]], dtype=np.float64)
else:
    raise RuntimeError("Unsupported topological dimension for centroid eval")

# UFL expression for the flux
q_ufl = -k_m * ufl.grad(p)

# Expression: evaluate q at the reference centroid in each cell
expr_q = fem.Expression(ufl.div(q_ufl), X_ref)
expr_f = fem.Expression(f_func, X_ref)

# --- your existing point / cell-location code, with centroids as X3 ---
cells = np.arange(len(local_cell_centroid), dtype=np.int32)
q_vals_local = expr_q.eval(omega, cells)
f_local = expr_f.eval(omega, cells)
# q_vals_local = expr_q.eval(omega, cells_on_proc)
div_q_local = q_vals_local[:, 0]  # drop the "num_points" axis

def compute_strong_form(nets):
    """
    Strong-form loss:
        L(theta) ≈ mean_i ( div(q + r_theta)(x_i) )^2
    evaluated at cell centroids, grouped per subdomain.
    """

    # ---- 1️⃣ Pre-assemble centroid arrays per subdomain ----
    # Convert centroids to clean (num_cells, gdim) numpy array
    X_all = np.vstack(local_cell_centroid)   # shape (num_cells, gdim)
    sd_all = np.array([cell_subdomain[i][0] for i in range(len(X_all))])

    loss_sd = []

    for sd in range(num_subdomains):

        # Mask cells belonging to this subdomain
        mask = (sd_all == sd)
        if not np.any(mask):
            loss_sd.append(torch.zeros((), device=device))
            continue

        # ---- 2️⃣ Batch points ----
        X_sd = torch.tensor(
            X_all[mask],
            dtype=torch.float32,
            device=device,
            requires_grad=True
        )  # shape (Ns, gdim)

        div_q_sd = torch.tensor(
            div_q_local[mask],
            dtype=torch.float32,
            device=device
        )  # shape (Ns,)

        f_sd = torch.tensor(
            f_local[mask],
            dtype=torch.float32,
            device=device
        )

        net = nets[sd]

        # ---- 3️⃣ Forward pass ----
        r = net(X_sd)  # shape (Ns, gdim)

        # ---- 4️⃣ Compute divergence in batch ----
        gdim = r.shape[1]
        div_r = 0.0

        for j in range(gdim):
            grad_rj = torch.autograd.grad(
                r[:, j].sum(),     # sum to get scalar
                X_sd,
                create_graph=True
            )[0]                  # shape (Ns, gdim)

            div_r = div_r + grad_rj[:, j]

        # ---- 5️⃣ Residual and loss ----
        residual = div_q_sd + div_r - f_sd  # shape (Ns,)
        loss = torch.mean(residual**2)

        loss_sd.append(loss)

    return loss_sd
# Out:
# 100%|██████████| 8192/8192 [00:00<00:00, 115478.62it/s]

# %%
eps = 1e-6
W_f = 1.0e3   # flux term
W_c = 1.0e2     # continuity
W_r = 1.0e3
W_a = 1.0
# initialize once
lambdas = [torch.zeros(1, device=device) for _ in range(num_subdomains)]
rho = 10.0   # penalty parameter (tunable)
is_update_rho = False


max_epochs = 2500
import time

for epoch in range(max_epochs):

    # zero all grads
    for opt in optimizers:
        opt.zero_grad()

    # ----- forward: loss_sd -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    # loss_lce = compute_flux_loss(nets)
    loss_strong = compute_strong_form(nets)                       # 10s
    time_loss_sd = time.perf_counter() - t0

    # ----- forward: loss_continuity_sd -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    loss_continuity_sd = compute_subdomain_continuity(nets) # 30s
    time_loss_cont = time.perf_counter() - t0

    S_a = [net_i.slope_recovery_term() for net_i in nets]   # list of num_subdomains scalars
    net_norm = [l2_norm_network(nets[i], subdomain_vertices_coord[i], dx=lc) for i in range(num_subdomains)]

    # ----- gradient-based weight update every 10 epochs -----
    if epoch % 10 == 0:
        grad_f_list, grad_c_list, grad_a_list, grad_r_list = [], [], [], []

        for k in range(num_subdomains):
            net_k = nets[k]

            g_f = grad_norm_from_loss(loss_strong[k], net_k)
            g_c = grad_norm_from_loss(loss_continuity_sd[k], net_k)
            g_a = grad_norm_from_loss(S_a[k], net_k)
            g_r = grad_norm_from_loss(net_norm[k], net_k)

            grad_f_list.append(g_f)
            grad_c_list.append(g_c)
            grad_a_list.append(g_a)
            grad_r_list.append(g_r)

        # average gradient norms over subdomains
        g_f = torch.stack(grad_f_list).mean()
        g_c = torch.stack(grad_c_list).mean()
        g_a = torch.stack(grad_a_list).mean()
        g_r = torch.stack(grad_r_list).mean()

        # choose W_f as the anchor (scale is arbitrary)
        with torch.no_grad():
            W_f = (1.0 / (g_f + eps)).item()
            W_c = (1.0 / (g_c + eps)).item()
            W_a = (1.0 / (g_a + eps)).item()
            W_r = 0.01*(1.0 / (g_r + eps)).item()

    # ----- combined loss with current weights -----
    loss = [
        W_f * loss_strong[k] +
        W_c * loss_continuity_sd[k]
        # + lambdas[k] * loss_continuity_sd[k]
        + W_a * S_a[k]
        + W_r * net_norm[k]
        for k in range(num_subdomains)
    ]
    total_loss = torch.sum(torch.stack(loss))

    # ----- backward: total_loss.backward() -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    total_loss.backward()
    time_backward = time.perf_counter() - t0

    # ----- optimizer.step() loop (per subdomain) -----
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.perf_counter()
    for k in range(num_subdomains):
        optimizers[k].step()
    time_opt_step = time.perf_counter() - t0

    avg_F = sum(loss_strong) / len(loss_strong)
    avg_C = sum(loss_continuity_sd) / len(loss_continuity_sd)

    loss_lc_avg_arr.append(float(avg_F))
    loss_cont_avg_arr.append(float(avg_C))
    if epoch == 1:
        Lc0 = avg_C.item()

    if epoch % 10 == 0:
        print(
            f"[Epoch {epoch:4d}] "
            f"W_f={W_f:.3e}, W_c={W_c:.3e}, W_a={W_a:.3e}, W_r={W_r:.3e} | "
            f"F_avg={avg_F.item():.4e} | "
            f"C_avg={avg_C.item():.4e}"
        )

    # timings printed every epoch
    print(
        f"[Epoch {epoch:4d} timings] "
        f"loss_sd={time_loss_sd:.3f}s, "
        f"loss_cont={time_loss_cont:.3f}s, "
        f"backward={time_backward:.3f}s, "
        f"opt_step_loop={time_opt_step:.3f}s"
    )
# Out:
# [Epoch    0] W_f=1.528e+03, W_c=3.434e+05, W_a=2.443e+00, W_r=1.000e+04 | F_avg=9.0545e+00 | C_avg=1.1245e-08
# [Epoch    0 timings] loss_sd=0.153s, loss_cont=1.800s, backward=1.310s, opt_step_loop=0.008s
# [Epoch    1 timings] loss_sd=0.118s, loss_cont=1.420s, backward=1.459s, opt_step_loop=0.005s
# [Epoch    2 timings] loss_sd=0.105s, loss_cont=1.048s, backward=1.367s, opt_step_loop=0.006s
# [Epoch    3 timings] loss_sd=0.107s, loss_cont=1.144s, backward=1.395s, opt_step_loop=0.004s
# [Epoch    4 timings] loss_sd=0.085s, loss_cont=1.029s, backward=1.555s, opt_step_loop=0.003s
# [Epoch    5 timings] loss_sd=0.108s, loss_cont=1.107s, backward=1.455s, opt_step_loop=0.004s
# [Epoch    6 timings] loss_sd=0.099s, loss_cont=1.064s, backward=1.546s, opt_step_loop=0.005s
# [Epoch    7 timings] loss_sd=0.118s, loss_cont=1.127s, backward=1.619s, opt_step_loop=0.003s
# [Epoch    8 timings] loss_sd=0.104s, loss_cont=1.104s, backward=1.492s, opt_step_loop=0.004s
# [Epoch    9 timings] loss_sd=0.114s, loss_cont=1.021s, backward=1.538s, opt_step_loop=0.005s
# [Epoch   10] W_f=9.943e+02, W_c=3.596e+05, W_a=2.464e+00, W_r=6.852e-01 | F_avg=9.0545e+00 | C_avg=9.9753e-09
# [Epoch   10 timings] loss_sd=0.131s, loss_cont=1.097s, backward=1.409s, opt_step_loop=0.004s
# [Epoch   11 timings] loss_sd=0.105s, loss_cont=1.049s, backward=1.378s, opt_step_loop=0.004s
# [Epoch   12 timings] loss_sd=0.084s, loss_cont=1.089s, backward=1.411s, opt_step_loop=0.004s
# [Epoch   13 timings] loss_sd=0.123s, loss_cont=1.067s, backward=1.697s, opt_step_loop=0.003s
# [Epoch   14 timings] loss_sd=0.126s, loss_cont=1.140s, backward=1.485s, opt_step_loop=0.004s
# [Epoch   15 timings] loss_sd=0.147s, loss_cont=1.094s, backward=1.576s, opt_step_loop=0.004s
# [Epoch   16 timings] loss_sd=0.105s, loss_cont=1.114s, backward=1.514s, opt_step_loop=0.006s
# [Epoch   17 timings] loss_sd=0.147s, loss_cont=1.069s, backward=1.517s, opt_step_loop=0.003s
# [Epoch   18 timings] loss_sd=0.106s, loss_cont=1.092s, backward=1.416s, opt_step_loop=0.006s
# [Epoch   19 timings] loss_sd=0.111s, loss_cont=1.102s, backward=1.490s, opt_step_loop=0.005s
# [Epoch   20] W_f=6.049e+02, W_c=2.721e+05, W_a=2.488e+00, W_r=1.528e-01 | F_avg=9.0544e+00 | C_avg=1.7489e-08
# [Epoch   20 timings] loss_sd=0.106s, loss_cont=1.825s, backward=1.519s, opt_step_loop=0.004s
# [Epoch   21 timings] loss_sd=0.139s, loss_cont=1.000s, backward=1.471s, opt_step_loop=0.006s
# [Epoch   22 timings] loss_sd=0.128s, loss_cont=1.202s, backward=1.438s, opt_step_loop=0.004s
# [Epoch   23 timings] loss_sd=0.106s, loss_cont=1.067s, backward=1.778s, opt_step_loop=0.005s
# [Epoch   24 timings] loss_sd=0.139s, loss_cont=1.117s, backward=1.458s, opt_step_loop=0.005s
# [Epoch   25 timings] loss_sd=0.112s, loss_cont=1.010s, backward=1.377s, opt_step_loop=0.005s
# [Epoch   26 timings] loss_sd=0.116s, loss_cont=1.054s, backward=1.489s, opt_step_loop=0.003s
# [Epoch   27 timings] loss_sd=0.258s, loss_cont=1.125s, backward=1.366s, opt_step_loop=0.004s
# [Epoch   28 timings] loss_sd=0.119s, loss_cont=1.018s, backward=1.517s, opt_step_loop=0.003s
# [Epoch   29 timings] loss_sd=0.165s, loss_cont=1.136s, backward=1.449s, opt_step_loop=0.005s
# [Epoch   30] W_f=3.711e+02, W_c=2.491e+05, W_a=2.513e+00, W_r=1.096e-01 | F_avg=9.0544e+00 | C_avg=2.1139e-08
# [Epoch   30 timings] loss_sd=0.089s, loss_cont=1.051s, backward=1.411s, opt_step_loop=0.004s
# [Epoch   31 timings] loss_sd=0.104s, loss_cont=1.059s, backward=1.512s, opt_step_loop=0.006s
# [Epoch   32 timings] loss_sd=0.108s, loss_cont=0.965s, backward=1.379s, opt_step_loop=0.005s
# [Epoch   33 timings] loss_sd=0.121s, loss_cont=1.102s, backward=1.432s, opt_step_loop=0.005s
# [Epoch   34 timings] loss_sd=0.123s, loss_cont=1.136s, backward=1.502s, opt_step_loop=0.006s
# [Epoch   35 timings] loss_sd=0.125s, loss_cont=1.150s, backward=1.472s, opt_step_loop=0.003s
# [Epoch   36 timings] loss_sd=0.140s, loss_cont=1.127s, backward=1.591s, opt_step_loop=0.003s
# [Epoch   37 timings] loss_sd=0.128s, loss_cont=1.906s, backward=1.535s, opt_step_loop=0.004s
# [Epoch   38 timings] loss_sd=0.129s, loss_cont=1.113s, backward=1.522s, opt_step_loop=0.005s
# [Epoch   39 timings] loss_sd=0.114s, loss_cont=1.178s, backward=1.518s, opt_step_loop=0.005s
# [Epoch   40] W_f=2.290e+02, W_c=2.427e+05, W_a=2.539e+00, W_r=9.987e-02 | F_avg=9.0544e+00 | C_avg=2.2308e-08
# [Epoch   40 timings] loss_sd=0.113s, loss_cont=1.168s, backward=1.452s, opt_step_loop=0.005s
# [Epoch   41 timings] loss_sd=0.123s, loss_cont=1.057s, backward=1.444s, opt_step_loop=0.006s
# [Epoch   42 timings] loss_sd=0.116s, loss_cont=1.026s, backward=1.461s, opt_step_loop=0.005s
# [Epoch   43 timings] loss_sd=0.139s, loss_cont=1.079s, backward=1.612s, opt_step_loop=0.005s
# [Epoch   44 timings] loss_sd=0.127s, loss_cont=1.058s, backward=1.449s, opt_step_loop=0.004s
# [Epoch   45 timings] loss_sd=0.145s, loss_cont=1.038s, backward=1.567s, opt_step_loop=0.005s
# [Epoch   46 timings] loss_sd=0.113s, loss_cont=1.036s, backward=1.461s, opt_step_loop=0.004s
# [Epoch   47 timings] loss_sd=0.120s, loss_cont=1.081s, backward=1.527s, opt_step_loop=0.005s
# [Epoch   48 timings] loss_sd=0.120s, loss_cont=1.018s, backward=1.435s, opt_step_loop=0.005s
# [Epoch   49 timings] loss_sd=0.124s, loss_cont=1.097s, backward=1.420s, opt_step_loop=0.005s
# [Epoch   50] W_f=1.422e+02, W_c=2.426e+05, W_a=2.566e+00, W_r=9.821e-02 | F_avg=9.0542e+00 | C_avg=2.2243e-08
# [Epoch   50 timings] loss_sd=0.121s, loss_cont=1.026s, backward=1.484s, opt_step_loop=0.005s
# [Epoch   51 timings] loss_sd=0.130s, loss_cont=1.102s, backward=1.476s, opt_step_loop=0.004s
# [Epoch   52 timings] loss_sd=0.121s, loss_cont=1.031s, backward=1.428s, opt_step_loop=0.005s
# [Epoch   53 timings] loss_sd=0.116s, loss_cont=1.060s, backward=1.457s, opt_step_loop=0.005s
# [Epoch   54 timings] loss_sd=0.105s, loss_cont=1.001s, backward=1.499s, opt_step_loop=0.005s
# [Epoch   55 timings] loss_sd=0.127s, loss_cont=1.964s, backward=1.475s, opt_step_loop=0.005s
# [Epoch   56 timings] loss_sd=0.115s, loss_cont=1.189s, backward=1.474s, opt_step_loop=0.004s
# [Epoch   57 timings] loss_sd=0.129s, loss_cont=1.155s, backward=1.444s, opt_step_loop=0.004s
# [Epoch   58 timings] loss_sd=0.089s, loss_cont=1.051s, backward=1.464s, opt_step_loop=0.005s
# [Epoch   59 timings] loss_sd=0.128s, loss_cont=1.221s, backward=1.622s, opt_step_loop=0.005s
# [Epoch   60] W_f=8.901e+01, W_c=2.458e+05, W_a=2.593e+00, W_r=1.000e-01 | F_avg=9.0540e+00 | C_avg=2.1494e-08
# [Epoch   60 timings] loss_sd=0.101s, loss_cont=1.089s, backward=1.465s, opt_step_loop=0.005s
# [Epoch   61 timings] loss_sd=0.111s, loss_cont=1.184s, backward=1.611s, opt_step_loop=0.004s
# [Epoch   62 timings] loss_sd=0.152s, loss_cont=1.107s, backward=1.519s, opt_step_loop=0.004s
# [Epoch   63 timings] loss_sd=0.102s, loss_cont=1.146s, backward=1.528s, opt_step_loop=0.006s
# [Epoch   64 timings] loss_sd=0.123s, loss_cont=1.065s, backward=1.638s, opt_step_loop=0.005s
# [Epoch   65 timings] loss_sd=0.119s, loss_cont=1.082s, backward=1.574s, opt_step_loop=0.005s
# [Epoch   66 timings] loss_sd=0.122s, loss_cont=1.119s, backward=1.453s, opt_step_loop=0.006s
# [Epoch   67 timings] loss_sd=0.136s, loss_cont=1.107s, backward=1.580s, opt_step_loop=0.006s
# [Epoch   68 timings] loss_sd=0.121s, loss_cont=1.125s, backward=1.528s, opt_step_loop=0.004s
# [Epoch   69 timings] loss_sd=0.103s, loss_cont=1.105s, backward=1.492s, opt_step_loop=0.004s
# [Epoch   70] W_f=5.629e+01, W_c=2.523e+05, W_a=2.622e+00, W_r=1.049e-01 | F_avg=9.0536e+00 | C_avg=2.0202e-08
# [Epoch   70 timings] loss_sd=0.150s, loss_cont=1.072s, backward=1.552s, opt_step_loop=0.004s
# [Epoch   71 timings] loss_sd=0.098s, loss_cont=1.025s, backward=1.447s, opt_step_loop=0.003s
# [Epoch   72 timings] loss_sd=0.124s, loss_cont=1.000s, backward=1.572s, opt_step_loop=0.004s
# [Epoch   73 timings] loss_sd=0.097s, loss_cont=1.803s, backward=1.465s, opt_step_loop=0.004s
# [Epoch   74 timings] loss_sd=0.088s, loss_cont=1.052s, backward=1.461s, opt_step_loop=0.004s
# [Epoch   75 timings] loss_sd=0.113s, loss_cont=1.024s, backward=1.456s, opt_step_loop=0.005s
# [Epoch   76 timings] loss_sd=0.092s, loss_cont=1.280s, backward=1.489s, opt_step_loop=0.003s
# [Epoch   77 timings] loss_sd=0.108s, loss_cont=1.013s, backward=1.466s, opt_step_loop=0.005s
# [Epoch   78 timings] loss_sd=0.105s, loss_cont=1.071s, backward=1.355s, opt_step_loop=0.005s
# [Epoch   79 timings] loss_sd=0.096s, loss_cont=1.056s, backward=1.556s, opt_step_loop=0.005s
# [Epoch   80] W_f=3.599e+01, W_c=2.632e+05, W_a=2.651e+00, W_r=1.148e-01 | F_avg=9.0529e+00 | C_avg=1.8315e-08
# [Epoch   80 timings] loss_sd=0.100s, loss_cont=0.983s, backward=1.334s, opt_step_loop=0.004s
# [Epoch   81 timings] loss_sd=0.128s, loss_cont=0.986s, backward=1.359s, opt_step_loop=0.003s
# [Epoch   82 timings] loss_sd=0.289s, loss_cont=0.988s, backward=1.345s, opt_step_loop=0.004s
# [Epoch   83 timings] loss_sd=0.122s, loss_cont=1.003s, backward=1.403s, opt_step_loop=0.004s
# [Epoch   84 timings] loss_sd=0.106s, loss_cont=0.996s, backward=1.339s, opt_step_loop=0.004s
# [Epoch   85 timings] loss_sd=0.097s, loss_cont=1.013s, backward=1.350s, opt_step_loop=0.004s
# [Epoch   86 timings] loss_sd=0.104s, loss_cont=0.977s, backward=1.437s, opt_step_loop=0.003s
# [Epoch   87 timings] loss_sd=0.093s, loss_cont=0.983s, backward=1.403s, opt_step_loop=0.005s
# [Epoch   88 timings] loss_sd=0.127s, loss_cont=0.963s, backward=1.361s, opt_step_loop=0.005s
# [Epoch   89 timings] loss_sd=0.098s, loss_cont=0.967s, backward=1.376s, opt_step_loop=0.003s
# [Epoch   90] W_f=2.330e+01, W_c=2.815e+05, W_a=2.680e+00, W_r=1.367e-01 | F_avg=9.0517e+00 | C_avg=1.5744e-08
# [Epoch   90 timings] loss_sd=0.104s, loss_cont=0.997s, backward=1.328s, opt_step_loop=0.004s
# [Epoch   91 timings] loss_sd=0.094s, loss_cont=1.751s, backward=1.383s, opt_step_loop=0.004s
# [Epoch   92 timings] loss_sd=0.094s, loss_cont=0.964s, backward=1.332s, opt_step_loop=0.003s
# [Epoch   93 timings] loss_sd=0.103s, loss_cont=0.985s, backward=1.376s, opt_step_loop=0.005s
# [Epoch   94 timings] loss_sd=0.194s, loss_cont=1.004s, backward=1.279s, opt_step_loop=0.004s
# [Epoch   95 timings] loss_sd=0.086s, loss_cont=1.161s, backward=1.460s, opt_step_loop=0.004s
# [Epoch   96 timings] loss_sd=0.137s, loss_cont=0.962s, backward=1.499s, opt_step_loop=0.007s
# [Epoch   97 timings] loss_sd=0.098s, loss_cont=1.062s, backward=1.388s, opt_step_loop=0.005s
# [Epoch   98 timings] loss_sd=0.106s, loss_cont=1.077s, backward=1.623s, opt_step_loop=0.014s
# [Epoch   99 timings] loss_sd=0.105s, loss_cont=1.006s, backward=1.571s, opt_step_loop=0.007s
# [Epoch  100] W_f=1.530e+01, W_c=3.127e+05, W_a=2.710e+00, W_r=1.396e-01 | F_avg=9.0496e+00 | C_avg=1.2556e-08
# [Epoch  100 timings] loss_sd=0.105s, loss_cont=1.026s, backward=1.382s, opt_step_loop=0.006s
# [Epoch  101 timings] loss_sd=0.441s, loss_cont=1.066s, backward=1.415s, opt_step_loop=0.004s
# [Epoch  102 timings] loss_sd=0.105s, loss_cont=1.107s, backward=1.334s, opt_step_loop=0.006s
# [Epoch  103 timings] loss_sd=0.094s, loss_cont=1.040s, backward=1.391s, opt_step_loop=0.004s
# [Epoch  104 timings] loss_sd=0.099s, loss_cont=1.114s, backward=1.411s, opt_step_loop=0.004s
# [Epoch  105 timings] loss_sd=0.099s, loss_cont=1.103s, backward=1.576s, opt_step_loop=0.005s
# [Epoch  106 timings] loss_sd=0.096s, loss_cont=0.986s, backward=1.325s, opt_step_loop=0.005s
# [Epoch  107 timings] loss_sd=0.111s, loss_cont=1.038s, backward=1.607s, opt_step_loop=0.006s
# [Epoch  108 timings] loss_sd=0.110s, loss_cont=0.984s, backward=1.546s, opt_step_loop=0.003s
# [Epoch  109 timings] loss_sd=0.108s, loss_cont=1.909s, backward=1.456s, opt_step_loop=0.005s
# [Epoch  110] W_f=1.019e+01, W_c=3.651e+05, W_a=2.741e+00, W_r=1.224e-01 | F_avg=9.0464e+00 | C_avg=9.2165e-09
# [Epoch  110 timings] loss_sd=0.086s, loss_cont=1.063s, backward=1.379s, opt_step_loop=0.008s
# [Epoch  111 timings] loss_sd=0.106s, loss_cont=1.020s, backward=1.662s, opt_step_loop=0.003s
# [Epoch  112 timings] loss_sd=0.110s, loss_cont=1.046s, backward=1.807s, opt_step_loop=0.004s
# [Epoch  113 timings] loss_sd=0.091s, loss_cont=0.990s, backward=1.812s, opt_step_loop=0.007s
# [Epoch  114 timings] loss_sd=0.104s, loss_cont=0.993s, backward=1.750s, opt_step_loop=0.006s
# [Epoch  115 timings] loss_sd=0.107s, loss_cont=1.014s, backward=1.454s, opt_step_loop=0.004s
# [Epoch  116 timings] loss_sd=0.110s, loss_cont=1.077s, backward=1.339s, opt_step_loop=0.004s
# [Epoch  117 timings] loss_sd=0.093s, loss_cont=1.129s, backward=1.438s, opt_step_loop=0.004s
# [Epoch  118 timings] loss_sd=0.119s, loss_cont=1.051s, backward=1.345s, opt_step_loop=0.004s
# [Epoch  119 timings] loss_sd=0.104s, loss_cont=1.094s, backward=1.443s, opt_step_loop=0.004s
# [Epoch  120] W_f=6.900e+00, W_c=4.121e+05, W_a=2.772e+00, W_r=1.106e-01 | F_avg=9.0414e+00 | C_avg=6.5180e-09
# [Epoch  120 timings] loss_sd=0.097s, loss_cont=1.092s, backward=1.941s, opt_step_loop=0.003s
# [Epoch  121 timings] loss_sd=0.114s, loss_cont=0.989s, backward=1.435s, opt_step_loop=0.005s
# [Epoch  122 timings] loss_sd=0.101s, loss_cont=1.022s, backward=1.567s, opt_step_loop=0.004s
# [Epoch  123 timings] loss_sd=0.105s, loss_cont=1.011s, backward=1.487s, opt_step_loop=0.004s
# [Epoch  124 timings] loss_sd=0.092s, loss_cont=1.007s, backward=2.016s, opt_step_loop=0.004s
# [Epoch  125 timings] loss_sd=0.690s, loss_cont=1.020s, backward=1.474s, opt_step_loop=0.005s
# [Epoch  126 timings] loss_sd=0.106s, loss_cont=1.077s, backward=1.379s, opt_step_loop=0.004s
# [Epoch  127 timings] loss_sd=0.100s, loss_cont=1.846s, backward=2.216s, opt_step_loop=0.004s
# [Epoch  128 timings] loss_sd=0.090s, loss_cont=1.015s, backward=1.972s, opt_step_loop=0.008s
# [Epoch  129 timings] loss_sd=0.191s, loss_cont=1.008s, backward=1.512s, opt_step_loop=0.005s
# [Epoch  130] W_f=4.745e+00, W_c=4.509e+05, W_a=2.803e+00, W_r=8.027e-02 | F_avg=9.0338e+00 | C_avg=4.7787e-09
# [Epoch  130 timings] loss_sd=0.110s, loss_cont=0.998s, backward=1.455s, opt_step_loop=0.004s
# [Epoch  131 timings] loss_sd=0.217s, loss_cont=0.978s, backward=1.414s, opt_step_loop=0.003s
# [Epoch  132 timings] loss_sd=0.127s, loss_cont=1.004s, backward=1.540s, opt_step_loop=0.003s
# [Epoch  133 timings] loss_sd=0.091s, loss_cont=1.015s, backward=1.455s, opt_step_loop=0.003s
# [Epoch  134 timings] loss_sd=0.106s, loss_cont=1.044s, backward=1.483s, opt_step_loop=0.006s
# [Epoch  135 timings] loss_sd=0.107s, loss_cont=1.141s, backward=1.693s, opt_step_loop=0.004s
# [Epoch  136 timings] loss_sd=0.108s, loss_cont=0.999s, backward=1.427s, opt_step_loop=0.004s
# [Epoch  137 timings] loss_sd=0.109s, loss_cont=1.023s, backward=1.335s, opt_step_loop=0.004s
# [Epoch  138 timings] loss_sd=0.114s, loss_cont=1.034s, backward=1.788s, opt_step_loop=0.004s
# [Epoch  139 timings] loss_sd=0.090s, loss_cont=1.002s, backward=1.727s, opt_step_loop=0.004s
# [Epoch  140] W_f=3.315e+00, W_c=5.142e+05, W_a=2.834e+00, W_r=6.606e-02 | F_avg=9.0225e+00 | C_avg=3.3771e-09
# [Epoch  140 timings] loss_sd=0.092s, loss_cont=0.989s, backward=1.489s, opt_step_loop=0.003s
# [Epoch  141 timings] loss_sd=0.096s, loss_cont=1.015s, backward=1.483s, opt_step_loop=0.005s
# [Epoch  142 timings] loss_sd=0.107s, loss_cont=1.041s, backward=1.534s, opt_step_loop=0.004s
# [Epoch  143 timings] loss_sd=0.135s, loss_cont=1.102s, backward=1.525s, opt_step_loop=0.004s
# [Epoch  144 timings] loss_sd=0.095s, loss_cont=1.190s, backward=1.520s, opt_step_loop=0.005s
# [Epoch  145 timings] loss_sd=0.637s, loss_cont=1.305s, backward=1.579s, opt_step_loop=0.004s
# [Epoch  146 timings] loss_sd=0.110s, loss_cont=2.016s, backward=1.878s, opt_step_loop=0.005s
# [Epoch  147 timings] loss_sd=0.122s, loss_cont=0.998s, backward=1.535s, opt_step_loop=0.004s
# [Epoch  148 timings] loss_sd=0.101s, loss_cont=1.090s, backward=1.501s, opt_step_loop=0.004s
# [Epoch  149 timings] loss_sd=0.109s, loss_cont=1.113s, backward=1.525s, opt_step_loop=0.005s
# [Epoch  150] W_f=2.353e+00, W_c=5.540e+05, W_a=2.866e+00, W_r=6.186e-02 | F_avg=9.0061e+00 | C_avg=2.6105e-09
# [Epoch  150 timings] loss_sd=0.352s, loss_cont=1.016s, backward=1.361s, opt_step_loop=0.004s
# [Epoch  151 timings] loss_sd=0.126s, loss_cont=1.174s, backward=1.435s, opt_step_loop=0.004s
# [Epoch  152 timings] loss_sd=0.093s, loss_cont=1.148s, backward=1.362s, opt_step_loop=0.004s
# [Epoch  153 timings] loss_sd=0.096s, loss_cont=1.100s, backward=1.455s, opt_step_loop=0.004s
# [Epoch  154 timings] loss_sd=0.130s, loss_cont=1.199s, backward=1.481s, opt_step_loop=0.003s
# [Epoch  155 timings] loss_sd=0.122s, loss_cont=1.121s, backward=1.506s, opt_step_loop=0.004s
# [Epoch  156 timings] loss_sd=0.093s, loss_cont=1.045s, backward=1.619s, opt_step_loop=0.004s
# [Epoch  157 timings] loss_sd=0.113s, loss_cont=1.109s, backward=1.560s, opt_step_loop=0.005s
# [Epoch  158 timings] loss_sd=0.130s, loss_cont=1.051s, backward=1.498s, opt_step_loop=0.004s
# [Epoch  159 timings] loss_sd=0.096s, loss_cont=1.021s, backward=1.685s, opt_step_loop=0.005s
# [Epoch  160] W_f=1.700e+00, W_c=5.292e+05, W_a=2.898e+00, W_r=5.239e-02 | F_avg=8.9829e+00 | C_avg=2.8374e-09
# [Epoch  160 timings] loss_sd=0.172s, loss_cont=1.000s, backward=1.523s, opt_step_loop=0.004s
# [Epoch  161 timings] loss_sd=0.109s, loss_cont=1.330s, backward=1.537s, opt_step_loop=0.005s
# [Epoch  162 timings] loss_sd=0.139s, loss_cont=1.107s, backward=1.590s, opt_step_loop=0.003s
# [Epoch  163 timings] loss_sd=0.107s, loss_cont=1.111s, backward=1.451s, opt_step_loop=0.003s
# [Epoch  164 timings] loss_sd=0.157s, loss_cont=1.056s, backward=1.559s, opt_step_loop=0.005s
# [Epoch  165 timings] loss_sd=0.106s, loss_cont=1.980s, backward=1.445s, opt_step_loop=0.004s
# [Epoch  166 timings] loss_sd=0.111s, loss_cont=1.089s, backward=1.539s, opt_step_loop=0.005s
# [Epoch  167 timings] loss_sd=0.129s, loss_cont=1.108s, backward=1.460s, opt_step_loop=0.003s
# [Epoch  168 timings] loss_sd=0.115s, loss_cont=1.084s, backward=1.469s, opt_step_loop=0.004s
# [Epoch  169 timings] loss_sd=0.114s, loss_cont=1.171s, backward=1.430s, opt_step_loop=0.006s
# [Epoch  170] W_f=1.254e+00, W_c=5.041e+05, W_a=2.930e+00, W_r=3.761e-02 | F_avg=8.9507e+00 | C_avg=3.4794e-09
# [Epoch  170 timings] loss_sd=0.860s, loss_cont=1.040s, backward=1.457s, opt_step_loop=0.004s
# [Epoch  171 timings] loss_sd=0.125s, loss_cont=1.102s, backward=1.535s, opt_step_loop=0.005s
# [Epoch  172 timings] loss_sd=0.121s, loss_cont=1.042s, backward=1.559s, opt_step_loop=0.006s
# [Epoch  173 timings] loss_sd=0.098s, loss_cont=1.057s, backward=1.490s, opt_step_loop=0.004s
# [Epoch  174 timings] loss_sd=0.127s, loss_cont=1.123s, backward=1.380s, opt_step_loop=0.004s
# [Epoch  175 timings] loss_sd=0.980s, loss_cont=1.121s, backward=1.456s, opt_step_loop=0.005s
# [Epoch  176 timings] loss_sd=0.135s, loss_cont=1.063s, backward=1.546s, opt_step_loop=0.010s
# [Epoch  177 timings] loss_sd=0.103s, loss_cont=1.084s, backward=1.464s, opt_step_loop=0.005s
# [Epoch  178 timings] loss_sd=0.143s, loss_cont=1.074s, backward=1.433s, opt_step_loop=0.004s
# [Epoch  179 timings] loss_sd=0.399s, loss_cont=1.050s, backward=1.408s, opt_step_loop=0.004s
# [Epoch  180] W_f=9.435e-01, W_c=4.584e+05, W_a=2.962e+00, W_r=2.660e-02 | F_avg=8.9075e+00 | C_avg=5.3878e-09
# [Epoch  180 timings] loss_sd=0.815s, loss_cont=1.093s, backward=1.465s, opt_step_loop=0.004s
# [Epoch  181 timings] loss_sd=0.129s, loss_cont=1.043s, backward=1.481s, opt_step_loop=0.004s
# [Epoch  182 timings] loss_sd=0.098s, loss_cont=1.104s, backward=1.479s, opt_step_loop=0.005s
# [Epoch  183 timings] loss_sd=0.106s, loss_cont=1.048s, backward=1.630s, opt_step_loop=0.004s
# [Epoch  184 timings] loss_sd=0.101s, loss_cont=1.206s, backward=1.527s, opt_step_loop=0.006s
# [Epoch  185 timings] loss_sd=0.123s, loss_cont=1.772s, backward=1.482s, opt_step_loop=0.005s
# [Epoch  186 timings] loss_sd=0.132s, loss_cont=1.048s, backward=1.544s, opt_step_loop=0.004s
# [Epoch  187 timings] loss_sd=0.110s, loss_cont=1.146s, backward=1.574s, opt_step_loop=0.007s
# [Epoch  188 timings] loss_sd=0.091s, loss_cont=1.039s, backward=1.527s, opt_step_loop=0.007s
# [Epoch  189 timings] loss_sd=0.108s, loss_cont=0.998s, backward=1.483s, opt_step_loop=0.003s
# [Epoch  190] W_f=7.273e-01, W_c=4.061e+05, W_a=2.995e+00, W_r=1.930e-02 | F_avg=8.8511e+00 | C_avg=9.1861e-09
# [Epoch  190 timings] loss_sd=0.113s, loss_cont=0.976s, backward=1.471s, opt_step_loop=0.006s
# [Epoch  191 timings] loss_sd=0.128s, loss_cont=1.060s, backward=1.499s, opt_step_loop=0.004s
# [Epoch  192 timings] loss_sd=0.110s, loss_cont=1.134s, backward=1.412s, opt_step_loop=0.003s
# [Epoch  193 timings] loss_sd=0.111s, loss_cont=1.085s, backward=1.845s, opt_step_loop=0.005s
# [Epoch  194 timings] loss_sd=0.111s, loss_cont=1.080s, backward=1.601s, opt_step_loop=0.004s
# [Epoch  195 timings] loss_sd=0.157s, loss_cont=1.109s, backward=1.476s, opt_step_loop=0.004s
# [Epoch  196 timings] loss_sd=0.108s, loss_cont=1.003s, backward=1.464s, opt_step_loop=0.004s
# [Epoch  197 timings] loss_sd=0.219s, loss_cont=1.097s, backward=1.492s, opt_step_loop=0.007s
# [Epoch  198 timings] loss_sd=0.095s, loss_cont=1.025s, backward=1.573s, opt_step_loop=0.003s
# [Epoch  199 timings] loss_sd=0.489s, loss_cont=1.037s, backward=1.590s, opt_step_loop=0.004s
# [Epoch  200] W_f=5.773e-01, W_c=3.648e+05, W_a=3.027e+00, W_r=1.370e-02 | F_avg=8.7805e+00 | C_avg=1.5688e-08
# [Epoch  200 timings] loss_sd=0.109s, loss_cont=1.021s, backward=1.449s, opt_step_loop=0.004s
# [Epoch  201 timings] loss_sd=0.095s, loss_cont=1.166s, backward=1.578s, opt_step_loop=0.005s
# [Epoch  202 timings] loss_sd=0.107s, loss_cont=2.006s, backward=1.528s, opt_step_loop=0.004s
# [Epoch  203 timings] loss_sd=0.102s, loss_cont=1.064s, backward=1.627s, opt_step_loop=0.003s
# [Epoch  204 timings] loss_sd=0.106s, loss_cont=1.180s, backward=1.524s, opt_step_loop=0.005s
# [Epoch  205 timings] loss_sd=0.098s, loss_cont=1.146s, backward=1.493s, opt_step_loop=0.004s
# [Epoch  206 timings] loss_sd=0.093s, loss_cont=1.188s, backward=1.442s, opt_step_loop=0.004s
# [Epoch  207 timings] loss_sd=0.100s, loss_cont=1.123s, backward=1.444s, opt_step_loop=0.005s
# [Epoch  208 timings] loss_sd=0.258s, loss_cont=1.094s, backward=1.512s, opt_step_loop=0.005s
# [Epoch  209 timings] loss_sd=0.104s, loss_cont=1.112s, backward=1.461s, opt_step_loop=0.004s
# [Epoch  210] W_f=4.733e-01, W_c=3.265e+05, W_a=3.059e+00, W_r=9.885e-03 | F_avg=8.6960e+00 | C_avg=2.6764e-08
# [Epoch  210 timings] loss_sd=0.098s, loss_cont=1.133s, backward=1.481s, opt_step_loop=0.005s
# [Epoch  211 timings] loss_sd=0.129s, loss_cont=1.045s, backward=2.104s, opt_step_loop=0.003s
# [Epoch  212 timings] loss_sd=0.098s, loss_cont=1.008s, backward=1.750s, opt_step_loop=0.007s
# [Epoch  213 timings] loss_sd=0.076s, loss_cont=0.998s, backward=1.498s, opt_step_loop=0.006s
# [Epoch  214 timings] loss_sd=0.109s, loss_cont=1.093s, backward=1.437s, opt_step_loop=0.006s
# [Epoch  215 timings] loss_sd=0.110s, loss_cont=1.107s, backward=1.385s, opt_step_loop=0.005s
# [Epoch  216 timings] loss_sd=0.101s, loss_cont=1.119s, backward=1.369s, opt_step_loop=0.005s
# [Epoch  217 timings] loss_sd=0.129s, loss_cont=1.102s, backward=1.394s, opt_step_loop=0.004s
# [Epoch  218 timings] loss_sd=0.116s, loss_cont=1.086s, backward=1.402s, opt_step_loop=0.004s
# [Epoch  219 timings] loss_sd=0.100s, loss_cont=1.126s, backward=1.424s, opt_step_loop=0.005s
# [Epoch  220] W_f=4.027e-01, W_c=2.997e+05, W_a=3.091e+00, W_r=7.168e-03 | F_avg=8.6005e+00 | C_avg=4.3596e-08
# [Epoch  220 timings] loss_sd=0.099s, loss_cont=1.811s, backward=1.465s, opt_step_loop=0.004s
# [Epoch  221 timings] loss_sd=0.466s, loss_cont=1.010s, backward=1.498s, opt_step_loop=0.005s
# [Epoch  222 timings] loss_sd=0.102s, loss_cont=1.131s, backward=2.198s, opt_step_loop=0.006s
# [Epoch  223 timings] loss_sd=0.226s, loss_cont=1.128s, backward=1.512s, opt_step_loop=0.004s
# [Epoch  224 timings] loss_sd=0.099s, loss_cont=0.999s, backward=2.259s, opt_step_loop=0.005s
# [Epoch  225 timings] loss_sd=0.802s, loss_cont=1.131s, backward=3.099s, opt_step_loop=0.004s
# [Epoch  226 timings] loss_sd=0.107s, loss_cont=1.043s, backward=2.053s, opt_step_loop=0.006s
# [Epoch  227 timings] loss_sd=0.130s, loss_cont=1.076s, backward=2.399s, opt_step_loop=0.005s
# [Epoch  228 timings] loss_sd=0.100s, loss_cont=1.120s, backward=2.891s, opt_step_loop=0.007s
# [Epoch  229 timings] loss_sd=0.093s, loss_cont=1.024s, backward=1.864s, opt_step_loop=0.005s
# [Epoch  230] W_f=3.568e-01, W_c=2.846e+05, W_a=3.122e+00, W_r=5.286e-03 | F_avg=8.4993e+00 | C_avg=6.7372e-08
# [Epoch  230 timings] loss_sd=0.106s, loss_cont=1.007s, backward=1.495s, opt_step_loop=0.003s
# [Epoch  231 timings] loss_sd=0.282s, loss_cont=1.251s, backward=1.589s, opt_step_loop=0.004s
# [Epoch  232 timings] loss_sd=0.115s, loss_cont=1.027s, backward=1.464s, opt_step_loop=0.004s
# [Epoch  233 timings] loss_sd=0.108s, loss_cont=1.139s, backward=1.698s, opt_step_loop=0.004s
# [Epoch  234 timings] loss_sd=0.127s, loss_cont=1.142s, backward=2.215s, opt_step_loop=0.005s
# [Epoch  235 timings] loss_sd=0.437s, loss_cont=1.076s, backward=2.312s, opt_step_loop=0.004s
# [Epoch  236 timings] loss_sd=0.390s, loss_cont=1.038s, backward=2.102s, opt_step_loop=0.005s
# [Epoch  237 timings] loss_sd=0.365s, loss_cont=1.048s, backward=1.714s, opt_step_loop=0.005s
# [Epoch  238 timings] loss_sd=0.113s, loss_cont=1.843s, backward=1.534s, opt_step_loop=0.004s
# [Epoch  239 timings] loss_sd=0.097s, loss_cont=1.042s, backward=1.498s, opt_step_loop=0.005s
# [Epoch  240] W_f=3.296e-01, W_c=2.820e+05, W_a=3.153e+00, W_r=3.988e-03 | F_avg=8.4006e+00 | C_avg=9.7782e-08
# [Epoch  240 timings] loss_sd=0.098s, loss_cont=1.107s, backward=1.407s, opt_step_loop=0.004s
# [Epoch  241 timings] loss_sd=0.098s, loss_cont=1.131s, backward=1.484s, opt_step_loop=0.003s
# [Epoch  242 timings] loss_sd=0.111s, loss_cont=1.112s, backward=1.528s, opt_step_loop=0.005s
# [Epoch  243 timings] loss_sd=0.103s, loss_cont=1.053s, backward=1.556s, opt_step_loop=0.006s
# [Epoch  244 timings] loss_sd=0.089s, loss_cont=1.091s, backward=1.442s, opt_step_loop=0.004s
# [Epoch  245 timings] loss_sd=0.109s, loss_cont=1.082s, backward=1.514s, opt_step_loop=0.004s
# [Epoch  246 timings] loss_sd=0.108s, loss_cont=0.994s, backward=1.498s, opt_step_loop=0.004s
# [Epoch  247 timings] loss_sd=0.105s, loss_cont=1.088s, backward=1.595s, opt_step_loop=0.004s
# [Epoch  248 timings] loss_sd=0.094s, loss_cont=1.075s, backward=1.428s, opt_step_loop=0.004s
# [Epoch  249 timings] loss_sd=0.096s, loss_cont=0.997s, backward=1.398s, opt_step_loop=0.004s
# [Epoch  250] W_f=3.163e-01, W_c=2.862e+05, W_a=3.182e+00, W_r=3.113e-03 | F_avg=8.3137e+00 | C_avg=1.3130e-07
# [Epoch  250 timings] loss_sd=0.108s, loss_cont=1.032s, backward=1.487s, opt_step_loop=0.004s
# [Epoch  251 timings] loss_sd=0.110s, loss_cont=1.035s, backward=1.483s, opt_step_loop=0.005s
# [Epoch  252 timings] loss_sd=0.102s, loss_cont=1.024s, backward=1.739s, opt_step_loop=0.004s
# [Epoch  253 timings] loss_sd=0.109s, loss_cont=1.110s, backward=1.574s, opt_step_loop=0.004s
# [Epoch  254 timings] loss_sd=0.104s, loss_cont=1.211s, backward=1.613s, opt_step_loop=0.006s
# [Epoch  255 timings] loss_sd=0.117s, loss_cont=1.067s, backward=1.744s, opt_step_loop=0.007s
# [Epoch  256 timings] loss_sd=0.179s, loss_cont=1.868s, backward=1.720s, opt_step_loop=0.003s
# [Epoch  257 timings] loss_sd=0.123s, loss_cont=1.216s, backward=1.644s, opt_step_loop=0.005s
# [Epoch  258 timings] loss_sd=0.100s, loss_cont=1.107s, backward=1.848s, opt_step_loop=0.004s
# [Epoch  259 timings] loss_sd=0.101s, loss_cont=1.125s, backward=1.723s, opt_step_loop=0.006s
# [Epoch  260] W_f=3.121e-01, W_c=2.818e+05, W_a=3.211e+00, W_r=2.544e-03 | F_avg=8.2449e+00 | C_avg=1.5906e-07
# [Epoch  260 timings] loss_sd=0.095s, loss_cont=1.108s, backward=1.416s, opt_step_loop=0.003s
# [Epoch  261 timings] loss_sd=0.597s, loss_cont=1.101s, backward=1.411s, opt_step_loop=0.004s
# [Epoch  262 timings] loss_sd=0.720s, loss_cont=1.049s, backward=1.495s, opt_step_loop=0.004s
# [Epoch  263 timings] loss_sd=0.115s, loss_cont=0.960s, backward=1.698s, opt_step_loop=0.004s
# [Epoch  264 timings] loss_sd=0.117s, loss_cont=1.071s, backward=1.408s, opt_step_loop=0.004s
# [Epoch  265 timings] loss_sd=0.110s, loss_cont=1.087s, backward=1.731s, opt_step_loop=0.005s
# [Epoch  266 timings] loss_sd=0.101s, loss_cont=1.076s, backward=1.482s, opt_step_loop=0.009s
# [Epoch  267 timings] loss_sd=0.100s, loss_cont=1.058s, backward=1.497s, opt_step_loop=0.009s
# [Epoch  268 timings] loss_sd=0.090s, loss_cont=1.110s, backward=1.540s, opt_step_loop=0.003s
# [Epoch  269 timings] loss_sd=0.104s, loss_cont=1.068s, backward=1.461s, opt_step_loop=0.009s
# [Epoch  270] W_f=3.119e-01, W_c=2.628e+05, W_a=3.238e+00, W_r=2.188e-03 | F_avg=8.1923e+00 | C_avg=1.7314e-07
# [Epoch  270 timings] loss_sd=0.091s, loss_cont=1.119s, backward=1.560s, opt_step_loop=0.007s
# [Epoch  271 timings] loss_sd=0.226s, loss_cont=1.107s, backward=1.415s, opt_step_loop=0.004s
# [Epoch  272 timings] loss_sd=0.095s, loss_cont=1.149s, backward=1.616s, opt_step_loop=0.004s
# [Epoch  273 timings] loss_sd=0.111s, loss_cont=1.120s, backward=1.644s, opt_step_loop=0.003s
# [Epoch  274 timings] loss_sd=0.103s, loss_cont=1.894s, backward=1.446s, opt_step_loop=0.003s
# [Epoch  275 timings] loss_sd=0.113s, loss_cont=1.133s, backward=1.436s, opt_step_loop=0.005s
# [Epoch  276 timings] loss_sd=0.106s, loss_cont=1.112s, backward=1.426s, opt_step_loop=0.003s
# [Epoch  277 timings] loss_sd=0.362s, loss_cont=1.647s, backward=1.457s, opt_step_loop=0.005s
# [Epoch  278 timings] loss_sd=0.105s, loss_cont=1.077s, backward=1.507s, opt_step_loop=0.006s
# [Epoch  279 timings] loss_sd=0.093s, loss_cont=1.175s, backward=1.425s, opt_step_loop=0.004s
# [Epoch  280] W_f=3.112e-01, W_c=2.448e+05, W_a=3.265e+00, W_r=1.964e-03 | F_avg=8.1464e+00 | C_avg=1.7648e-07
# [Epoch  280 timings] loss_sd=0.119s, loss_cont=1.176s, backward=2.166s, opt_step_loop=0.003s
# [Epoch  281 timings] loss_sd=0.105s, loss_cont=1.042s, backward=1.689s, opt_step_loop=0.004s
# [Epoch  282 timings] loss_sd=0.107s, loss_cont=1.003s, backward=1.455s, opt_step_loop=0.004s
# [Epoch  283 timings] loss_sd=0.122s, loss_cont=1.175s, backward=1.367s, opt_step_loop=0.004s
# [Epoch  284 timings] loss_sd=0.116s, loss_cont=1.259s, backward=1.477s, opt_step_loop=0.004s
# [Epoch  285 timings] loss_sd=0.099s, loss_cont=1.151s, backward=1.380s, opt_step_loop=0.004s
# [Epoch  286 timings] loss_sd=0.091s, loss_cont=1.150s, backward=1.424s, opt_step_loop=0.004s
# [Epoch  287 timings] loss_sd=0.095s, loss_cont=1.122s, backward=1.503s, opt_step_loop=0.006s
# [Epoch  288 timings] loss_sd=0.095s, loss_cont=1.161s, backward=1.523s, opt_step_loop=0.003s
# [Epoch  289 timings] loss_sd=0.100s, loss_cont=1.144s, backward=1.504s, opt_step_loop=0.004s
# [Epoch  290] W_f=3.071e-01, W_c=2.275e+05, W_a=3.292e+00, W_r=1.821e-03 | F_avg=8.0975e+00 | C_avg=1.7510e-07
# [Epoch  290 timings] loss_sd=0.099s, loss_cont=1.166s, backward=2.150s, opt_step_loop=0.007s
# [Epoch  291 timings] loss_sd=0.101s, loss_cont=1.015s, backward=1.478s, opt_step_loop=0.004s
# [Epoch  292 timings] loss_sd=0.095s, loss_cont=1.889s, backward=1.381s, opt_step_loop=0.004s
# [Epoch  293 timings] loss_sd=0.118s, loss_cont=1.038s, backward=1.840s, opt_step_loop=0.003s
# [Epoch  294 timings] loss_sd=0.082s, loss_cont=1.212s, backward=2.305s, opt_step_loop=0.004s
# [Epoch  295 timings] loss_sd=0.618s, loss_cont=1.143s, backward=1.882s, opt_step_loop=0.005s
# [Epoch  296 timings] loss_sd=0.117s, loss_cont=1.066s, backward=2.452s, opt_step_loop=0.005s
# [Epoch  297 timings] loss_sd=0.185s, loss_cont=0.942s, backward=1.873s, opt_step_loop=0.006s
# [Epoch  298 timings] loss_sd=0.314s, loss_cont=1.039s, backward=2.590s, opt_step_loop=0.005s
# [Epoch  299 timings] loss_sd=0.122s, loss_cont=1.149s, backward=2.642s, opt_step_loop=0.003s
# [Epoch  300] W_f=2.979e-01, W_c=2.075e+05, W_a=3.319e+00, W_r=1.735e-03 | F_avg=8.0377e+00 | C_avg=1.7231e-07
# [Epoch  300 timings] loss_sd=0.650s, loss_cont=1.155s, backward=1.506s, opt_step_loop=0.003s
# [Epoch  301 timings] loss_sd=0.105s, loss_cont=1.157s, backward=1.519s, opt_step_loop=0.006s
# [Epoch  302 timings] loss_sd=0.093s, loss_cont=1.143s, backward=1.441s, opt_step_loop=0.004s
# [Epoch  303 timings] loss_sd=0.975s, loss_cont=1.135s, backward=1.414s, opt_step_loop=0.004s
# [Epoch  304 timings] loss_sd=0.830s, loss_cont=1.028s, backward=1.412s, opt_step_loop=0.005s
# [Epoch  305 timings] loss_sd=0.110s, loss_cont=1.108s, backward=1.413s, opt_step_loop=0.005s
# [Epoch  306 timings] loss_sd=0.437s, loss_cont=1.132s, backward=1.432s, opt_step_loop=0.004s
# [Epoch  307 timings] loss_sd=0.804s, loss_cont=1.121s, backward=1.440s, opt_step_loop=0.004s
# [Epoch  308 timings] loss_sd=0.727s, loss_cont=1.036s, backward=1.499s, opt_step_loop=0.003s
# [Epoch  309 timings] loss_sd=0.485s, loss_cont=1.076s, backward=1.447s, opt_step_loop=0.004s
# [Epoch  310] W_f=2.838e-01, W_c=1.857e+05, W_a=3.346e+00, W_r=1.676e-03 | F_avg=7.9608e+00 | C_avg=1.6847e-07
# [Epoch  310 timings] loss_sd=0.094s, loss_cont=1.133s, backward=1.455s, opt_step_loop=0.003s
# [Epoch  311 timings] loss_sd=0.117s, loss_cont=1.799s, backward=1.695s, opt_step_loop=0.005s
# [Epoch  312 timings] loss_sd=0.138s, loss_cont=1.014s, backward=1.493s, opt_step_loop=0.004s
# [Epoch  313 timings] loss_sd=0.130s, loss_cont=0.981s, backward=1.482s, opt_step_loop=0.005s
# [Epoch  314 timings] loss_sd=0.082s, loss_cont=0.988s, backward=1.412s, opt_step_loop=0.003s
# [Epoch  315 timings] loss_sd=0.112s, loss_cont=0.928s, backward=1.414s, opt_step_loop=0.003s
# [Epoch  316 timings] loss_sd=0.117s, loss_cont=0.978s, backward=1.453s, opt_step_loop=0.004s
# [Epoch  317 timings] loss_sd=0.100s, loss_cont=0.979s, backward=1.377s, opt_step_loop=0.004s
# [Epoch  318 timings] loss_sd=0.096s, loss_cont=0.981s, backward=1.654s, opt_step_loop=0.006s
# [Epoch  319 timings] loss_sd=0.100s, loss_cont=0.997s, backward=1.925s, opt_step_loop=0.004s
# [Epoch  320] W_f=2.667e-01, W_c=1.728e+05, W_a=3.375e+00, W_r=1.539e-03 | F_avg=7.8647e+00 | C_avg=1.5995e-07
# [Epoch  320 timings] loss_sd=0.100s, loss_cont=1.026s, backward=1.435s, opt_step_loop=0.004s
# [Epoch  321 timings] loss_sd=0.270s, loss_cont=0.913s, backward=1.952s, opt_step_loop=0.004s
# [Epoch  322 timings] loss_sd=0.266s, loss_cont=1.103s, backward=1.511s, opt_step_loop=0.007s
# [Epoch  323 timings] loss_sd=0.110s, loss_cont=1.122s, backward=1.517s, opt_step_loop=0.003s
# [Epoch  324 timings] loss_sd=0.099s, loss_cont=1.053s, backward=1.519s, opt_step_loop=0.004s
# [Epoch  325 timings] loss_sd=0.115s, loss_cont=1.083s, backward=1.932s, opt_step_loop=0.004s
# [Epoch  326 timings] loss_sd=0.107s, loss_cont=1.034s, backward=1.490s, opt_step_loop=0.003s
# [Epoch  327 timings] loss_sd=0.099s, loss_cont=1.162s, backward=1.592s, opt_step_loop=0.003s
# [Epoch  328 timings] loss_sd=0.108s, loss_cont=1.010s, backward=1.805s, opt_step_loop=0.004s
# [Epoch  329 timings] loss_sd=0.128s, loss_cont=1.054s, backward=1.505s, opt_step_loop=0.003s
# [Epoch  330] W_f=2.494e-01, W_c=1.709e+05, W_a=3.406e+00, W_r=1.280e-03 | F_avg=7.7509e+00 | C_avg=1.4424e-07
# [Epoch  330 timings] loss_sd=0.125s, loss_cont=1.799s, backward=1.344s, opt_step_loop=0.004s
# [Epoch  331 timings] loss_sd=0.115s, loss_cont=1.247s, backward=1.697s, opt_step_loop=0.003s
# [Epoch  332 timings] loss_sd=0.099s, loss_cont=1.218s, backward=1.528s, opt_step_loop=0.003s
# [Epoch  333 timings] loss_sd=0.537s, loss_cont=1.064s, backward=1.515s, opt_step_loop=0.003s
# [Epoch  334 timings] loss_sd=0.436s, loss_cont=1.001s, backward=1.534s, opt_step_loop=0.005s
# [Epoch  335 timings] loss_sd=0.112s, loss_cont=1.059s, backward=1.719s, opt_step_loop=0.004s
# [Epoch  336 timings] loss_sd=0.097s, loss_cont=1.078s, backward=1.900s, opt_step_loop=0.004s
# [Epoch  337 timings] loss_sd=0.118s, loss_cont=0.964s, backward=1.619s, opt_step_loop=0.004s
# [Epoch  338 timings] loss_sd=0.117s, loss_cont=1.064s, backward=1.787s, opt_step_loop=0.004s
# [Epoch  339 timings] loss_sd=0.102s, loss_cont=1.034s, backward=1.718s, opt_step_loop=0.005s
# [Epoch  340] W_f=2.349e-01, W_c=1.794e+05, W_a=3.438e+00, W_r=1.014e-03 | F_avg=7.6261e+00 | C_avg=1.1996e-07
# [Epoch  340 timings] loss_sd=0.109s, loss_cont=1.171s, backward=1.409s, opt_step_loop=0.005s
# [Epoch  341 timings] loss_sd=0.104s, loss_cont=1.157s, backward=1.754s, opt_step_loop=0.004s
# [Epoch  342 timings] loss_sd=0.111s, loss_cont=1.103s, backward=1.851s, opt_step_loop=0.007s
# [Epoch  343 timings] loss_sd=0.101s, loss_cont=1.153s, backward=1.633s, opt_step_loop=0.003s
# [Epoch  344 timings] loss_sd=0.126s, loss_cont=1.126s, backward=1.436s, opt_step_loop=0.004s
# [Epoch  345 timings] loss_sd=0.116s, loss_cont=1.124s, backward=1.527s, opt_step_loop=0.005s
# [Epoch  346 timings] loss_sd=0.097s, loss_cont=1.128s, backward=1.412s, opt_step_loop=0.007s
# [Epoch  347 timings] loss_sd=0.105s, loss_cont=1.111s, backward=1.510s, opt_step_loop=0.005s
# [Epoch  348 timings] loss_sd=0.093s, loss_cont=1.015s, backward=1.453s, opt_step_loop=0.004s
# [Epoch  349 timings] loss_sd=0.107s, loss_cont=1.060s, backward=1.643s, opt_step_loop=0.004s
# [Epoch  350] W_f=2.253e-01, W_c=2.062e+05, W_a=3.471e+00, W_r=8.093e-04 | F_avg=7.4990e+00 | C_avg=8.7926e-08
# [Epoch  350 timings] loss_sd=0.155s, loss_cont=1.846s, backward=1.932s, opt_step_loop=0.005s
# [Epoch  351 timings] loss_sd=0.092s, loss_cont=1.090s, backward=1.405s, opt_step_loop=0.004s
# [Epoch  352 timings] loss_sd=0.109s, loss_cont=1.077s, backward=1.379s, opt_step_loop=0.003s
# [Epoch  353 timings] loss_sd=0.103s, loss_cont=1.148s, backward=1.431s, opt_step_loop=0.007s
# [Epoch  354 timings] loss_sd=0.106s, loss_cont=1.128s, backward=1.396s, opt_step_loop=0.005s
# [Epoch  355 timings] loss_sd=0.108s, loss_cont=1.139s, backward=1.336s, opt_step_loop=0.003s
# [Epoch  356 timings] loss_sd=0.109s, loss_cont=1.059s, backward=1.435s, opt_step_loop=0.004s
# [Epoch  357 timings] loss_sd=0.123s, loss_cont=1.197s, backward=1.384s, opt_step_loop=0.005s
# [Epoch  358 timings] loss_sd=0.101s, loss_cont=1.127s, backward=1.418s, opt_step_loop=0.006s
# [Epoch  359 timings] loss_sd=0.112s, loss_cont=1.223s, backward=1.527s, opt_step_loop=0.003s
# [Epoch  360] W_f=2.197e-01, W_c=2.436e+05, W_a=3.505e+00, W_r=6.627e-04 | F_avg=7.3708e+00 | C_avg=5.9937e-08
# [Epoch  360 timings] loss_sd=0.103s, loss_cont=1.153s, backward=1.772s, opt_step_loop=0.007s
# [Epoch  361 timings] loss_sd=0.109s, loss_cont=0.955s, backward=1.438s, opt_step_loop=0.005s
# [Epoch  362 timings] loss_sd=0.130s, loss_cont=0.987s, backward=1.300s, opt_step_loop=0.007s
# [Epoch  363 timings] loss_sd=0.132s, loss_cont=1.087s, backward=1.446s, opt_step_loop=0.003s
# [Epoch  364 timings] loss_sd=0.087s, loss_cont=1.026s, backward=1.357s, opt_step_loop=0.004s
# [Epoch  365 timings] loss_sd=0.130s, loss_cont=0.977s, backward=1.301s, opt_step_loop=0.004s
# [Epoch  366 timings] loss_sd=0.119s, loss_cont=1.035s, backward=1.285s, opt_step_loop=0.004s
# [Epoch  367 timings] loss_sd=0.108s, loss_cont=1.846s, backward=1.303s, opt_step_loop=0.003s
# [Epoch  368 timings] loss_sd=0.757s, loss_cont=0.931s, backward=1.300s, opt_step_loop=0.004s
# [Epoch  369 timings] loss_sd=0.554s, loss_cont=0.924s, backward=1.313s, opt_step_loop=0.004s
# [Epoch  370] W_f=2.180e-01, W_c=2.850e+05, W_a=3.540e+00, W_r=5.553e-04 | F_avg=7.2434e+00 | C_avg=4.9370e-08
# [Epoch  370 timings] loss_sd=0.882s, loss_cont=0.965s, backward=1.441s, opt_step_loop=0.004s
# [Epoch  371 timings] loss_sd=0.118s, loss_cont=1.071s, backward=1.363s, opt_step_loop=0.005s
# [Epoch  372 timings] loss_sd=0.844s, loss_cont=1.029s, backward=1.324s, opt_step_loop=0.005s
# [Epoch  373 timings] loss_sd=0.128s, loss_cont=0.956s, backward=1.285s, opt_step_loop=0.006s
# [Epoch  374 timings] loss_sd=0.621s, loss_cont=1.003s, backward=1.391s, opt_step_loop=0.005s
# [Epoch  375 timings] loss_sd=0.656s, loss_cont=1.028s, backward=1.650s, opt_step_loop=0.004s
# [Epoch  376 timings] loss_sd=0.104s, loss_cont=1.018s, backward=1.897s, opt_step_loop=0.004s
# [Epoch  377 timings] loss_sd=0.131s, loss_cont=1.046s, backward=2.047s, opt_step_loop=0.005s
# [Epoch  378 timings] loss_sd=0.642s, loss_cont=0.986s, backward=1.615s, opt_step_loop=0.004s
# [Epoch  379 timings] loss_sd=0.143s, loss_cont=0.982s, backward=1.571s, opt_step_loop=0.005s
# [Epoch  380] W_f=2.181e-01, W_c=3.186e+05, W_a=3.574e+00, W_r=4.759e-04 | F_avg=7.1265e+00 | C_avg=6.2147e-08
# [Epoch  380 timings] loss_sd=0.085s, loss_cont=1.075s, backward=1.398s, opt_step_loop=0.004s
# [Epoch  381 timings] loss_sd=0.122s, loss_cont=1.107s, backward=1.375s, opt_step_loop=0.005s
# [Epoch  382 timings] loss_sd=0.884s, loss_cont=1.004s, backward=1.386s, opt_step_loop=0.005s
# [Epoch  383 timings] loss_sd=1.020s, loss_cont=1.081s, backward=1.414s, opt_step_loop=0.004s
# [Epoch  384 timings] loss_sd=0.650s, loss_cont=1.033s, backward=1.419s, opt_step_loop=0.003s
# [Epoch  385 timings] loss_sd=0.489s, loss_cont=1.857s, backward=1.448s, opt_step_loop=0.004s
# [Epoch  386 timings] loss_sd=0.131s, loss_cont=1.023s, backward=1.556s, opt_step_loop=0.006s
# [Epoch  387 timings] loss_sd=0.125s, loss_cont=1.012s, backward=1.727s, opt_step_loop=0.004s
# [Epoch  388 timings] loss_sd=0.106s, loss_cont=1.057s, backward=1.729s, opt_step_loop=0.004s
# [Epoch  389 timings] loss_sd=0.089s, loss_cont=1.047s, backward=1.436s, opt_step_loop=0.004s
# [Epoch  390] W_f=2.147e-01, W_c=3.215e+05, W_a=3.607e+00, W_r=4.203e-04 | F_avg=7.0208e+00 | C_avg=8.6155e-08
# [Epoch  390 timings] loss_sd=0.104s, loss_cont=1.081s, backward=1.518s, opt_step_loop=0.005s
# [Epoch  391 timings] loss_sd=0.362s, loss_cont=1.073s, backward=1.450s, opt_step_loop=0.004s
# [Epoch  392 timings] loss_sd=0.113s, loss_cont=1.013s, backward=1.568s, opt_step_loop=0.004s
# [Epoch  393 timings] loss_sd=0.084s, loss_cont=1.046s, backward=1.397s, opt_step_loop=0.004s
# [Epoch  394 timings] loss_sd=0.088s, loss_cont=1.004s, backward=1.426s, opt_step_loop=0.006s
# [Epoch  395 timings] loss_sd=0.243s, loss_cont=0.938s, backward=1.838s, opt_step_loop=0.004s
# [Epoch  396 timings] loss_sd=0.193s, loss_cont=0.948s, backward=2.210s, opt_step_loop=0.004s
# [Epoch  397 timings] loss_sd=0.910s, loss_cont=0.963s, backward=2.057s, opt_step_loop=0.004s
# [Epoch  398 timings] loss_sd=0.488s, loss_cont=0.971s, backward=2.052s, opt_step_loop=0.004s
# [Epoch  399 timings] loss_sd=0.747s, loss_cont=0.953s, backward=2.021s, opt_step_loop=0.005s
# [Epoch  400] W_f=2.084e-01, W_c=3.247e+05, W_a=3.637e+00, W_r=3.822e-04 | F_avg=6.9252e+00 | C_avg=1.0659e-07
# [Epoch  400 timings] loss_sd=0.550s, loss_cont=0.900s, backward=1.438s, opt_step_loop=0.003s
# [Epoch  401 timings] loss_sd=0.107s, loss_cont=1.097s, backward=1.922s, opt_step_loop=0.004s
# [Epoch  402 timings] loss_sd=0.501s, loss_cont=0.978s, backward=1.327s, opt_step_loop=0.005s
# [Epoch  403 timings] loss_sd=0.616s, loss_cont=1.859s, backward=1.460s, opt_step_loop=0.008s
# [Epoch  404 timings] loss_sd=0.121s, loss_cont=1.083s, backward=1.470s, opt_step_loop=0.003s
# [Epoch  405 timings] loss_sd=0.095s, loss_cont=1.032s, backward=1.447s, opt_step_loop=0.005s
# [Epoch  406 timings] loss_sd=0.113s, loss_cont=0.967s, backward=1.555s, opt_step_loop=0.003s
# [Epoch  407 timings] loss_sd=0.117s, loss_cont=0.993s, backward=1.465s, opt_step_loop=0.004s
# [Epoch  408 timings] loss_sd=0.102s, loss_cont=1.031s, backward=1.475s, opt_step_loop=0.004s
# [Epoch  409 timings] loss_sd=0.114s, loss_cont=0.981s, backward=1.532s, opt_step_loop=0.005s
# [Epoch  410] W_f=2.009e-01, W_c=3.312e+05, W_a=3.666e+00, W_r=3.539e-04 | F_avg=6.8363e+00 | C_avg=1.2190e-07
# [Epoch  410 timings] loss_sd=0.115s, loss_cont=1.002s, backward=1.531s, opt_step_loop=0.004s
# [Epoch  411 timings] loss_sd=0.547s, loss_cont=1.048s, backward=1.471s, opt_step_loop=0.004s
# [Epoch  412 timings] loss_sd=0.097s, loss_cont=1.003s, backward=1.481s, opt_step_loop=0.003s
# [Epoch  413 timings] loss_sd=0.099s, loss_cont=1.037s, backward=1.531s, opt_step_loop=0.003s
# [Epoch  414 timings] loss_sd=0.301s, loss_cont=1.034s, backward=1.495s, opt_step_loop=0.004s
# [Epoch  415 timings] loss_sd=0.121s, loss_cont=1.070s, backward=1.569s, opt_step_loop=0.007s
# [Epoch  416 timings] loss_sd=0.127s, loss_cont=1.028s, backward=1.565s, opt_step_loop=0.004s
# [Epoch  417 timings] loss_sd=0.418s, loss_cont=1.160s, backward=1.465s, opt_step_loop=0.006s
# [Epoch  418 timings] loss_sd=0.111s, loss_cont=1.017s, backward=1.416s, opt_step_loop=0.004s
# [Epoch  419 timings] loss_sd=0.134s, loss_cont=0.943s, backward=1.501s, opt_step_loop=0.004s
# [Epoch  420] W_f=1.915e-01, W_c=3.412e+05, W_a=3.695e+00, W_r=3.302e-04 | F_avg=6.7509e+00 | C_avg=1.3254e-07
# [Epoch  420 timings] loss_sd=0.122s, loss_cont=0.964s, backward=1.570s, opt_step_loop=0.007s
# [Epoch  421 timings] loss_sd=0.102s, loss_cont=1.830s, backward=1.345s, opt_step_loop=0.004s
# [Epoch  422 timings] loss_sd=0.102s, loss_cont=1.076s, backward=1.354s, opt_step_loop=0.004s
# [Epoch  423 timings] loss_sd=0.091s, loss_cont=1.099s, backward=1.344s, opt_step_loop=0.004s
# [Epoch  424 timings] loss_sd=0.097s, loss_cont=1.045s, backward=1.418s, opt_step_loop=0.003s
# [Epoch  425 timings] loss_sd=0.106s, loss_cont=1.071s, backward=1.389s, opt_step_loop=0.005s
# [Epoch  426 timings] loss_sd=0.103s, loss_cont=1.048s, backward=1.356s, opt_step_loop=0.004s
# [Epoch  427 timings] loss_sd=0.084s, loss_cont=1.094s, backward=1.414s, opt_step_loop=0.005s
# [Epoch  428 timings] loss_sd=0.106s, loss_cont=1.107s, backward=1.436s, opt_step_loop=0.003s
# [Epoch  429 timings] loss_sd=0.099s, loss_cont=1.183s, backward=1.368s, opt_step_loop=0.004s
# [Epoch  430] W_f=1.825e-01, W_c=3.464e+05, W_a=3.724e+00, W_r=3.096e-04 | F_avg=6.6635e+00 | C_avg=1.4062e-07
# [Epoch  430 timings] loss_sd=0.100s, loss_cont=1.072s, backward=1.389s, opt_step_loop=0.003s
# [Epoch  431 timings] loss_sd=0.540s, loss_cont=1.002s, backward=1.508s, opt_step_loop=0.003s
# [Epoch  432 timings] loss_sd=0.698s, loss_cont=1.017s, backward=1.395s, opt_step_loop=0.004s
# [Epoch  433 timings] loss_sd=0.103s, loss_cont=1.060s, backward=1.374s, opt_step_loop=0.004s
# [Epoch  434 timings] loss_sd=0.104s, loss_cont=1.106s, backward=1.345s, opt_step_loop=0.004s
# [Epoch  435 timings] loss_sd=0.111s, loss_cont=1.147s, backward=1.416s, opt_step_loop=0.005s
# [Epoch  436 timings] loss_sd=0.087s, loss_cont=1.081s, backward=1.382s, opt_step_loop=0.004s
# [Epoch  437 timings] loss_sd=0.104s, loss_cont=1.078s, backward=1.379s, opt_step_loop=0.004s
# [Epoch  438 timings] loss_sd=0.127s, loss_cont=1.081s, backward=1.335s, opt_step_loop=0.004s
# [Epoch  439 timings] loss_sd=0.107s, loss_cont=1.971s, backward=1.586s, opt_step_loop=0.004s
# [Epoch  440] W_f=1.744e-01, W_c=3.480e+05, W_a=3.754e+00, W_r=2.914e-04 | F_avg=6.5698e+00 | C_avg=1.4695e-07
# [Epoch  440 timings] loss_sd=0.109s, loss_cont=0.947s, backward=1.778s, opt_step_loop=0.004s
# [Epoch  441 timings] loss_sd=0.177s, loss_cont=1.024s, backward=2.186s, opt_step_loop=0.004s
# [Epoch  442 timings] loss_sd=0.159s, loss_cont=1.153s, backward=1.605s, opt_step_loop=0.004s
# [Epoch  443 timings] loss_sd=0.085s, loss_cont=1.015s, backward=1.384s, opt_step_loop=0.005s
# [Epoch  444 timings] loss_sd=0.100s, loss_cont=1.028s, backward=1.969s, opt_step_loop=0.004s
# [Epoch  445 timings] loss_sd=0.201s, loss_cont=0.968s, backward=1.403s, opt_step_loop=0.004s
# [Epoch  446 timings] loss_sd=0.116s, loss_cont=1.042s, backward=1.785s, opt_step_loop=0.005s
# [Epoch  447 timings] loss_sd=0.437s, loss_cont=1.097s, backward=2.393s, opt_step_loop=0.004s
# [Epoch  448 timings] loss_sd=0.751s, loss_cont=1.071s, backward=1.426s, opt_step_loop=0.003s
# [Epoch  449 timings] loss_sd=0.945s, loss_cont=1.037s, backward=1.440s, opt_step_loop=0.003s
# [Epoch  450] W_f=1.666e-01, W_c=3.499e+05, W_a=3.784e+00, W_r=2.749e-04 | F_avg=6.4665e+00 | C_avg=1.5180e-07
# [Epoch  450 timings] loss_sd=0.114s, loss_cont=1.052s, backward=2.126s, opt_step_loop=0.005s
# [Epoch  451 timings] loss_sd=0.136s, loss_cont=1.025s, backward=2.836s, opt_step_loop=0.003s
# [Epoch  452 timings] loss_sd=0.404s, loss_cont=1.070s, backward=1.499s, opt_step_loop=0.005s
# [Epoch  453 timings] loss_sd=0.125s, loss_cont=1.116s, backward=1.573s, opt_step_loop=0.004s
# [Epoch  454 timings] loss_sd=0.112s, loss_cont=1.119s, backward=1.952s, opt_step_loop=0.003s
# [Epoch  455 timings] loss_sd=0.109s, loss_cont=1.097s, backward=1.530s, opt_step_loop=0.003s
# [Epoch  456 timings] loss_sd=0.107s, loss_cont=1.199s, backward=1.652s, opt_step_loop=0.006s
# [Epoch  457 timings] loss_sd=0.147s, loss_cont=1.776s, backward=1.497s, opt_step_loop=0.004s
# [Epoch  458 timings] loss_sd=0.277s, loss_cont=0.927s, backward=1.452s, opt_step_loop=0.005s
# [Epoch  459 timings] loss_sd=0.132s, loss_cont=0.978s, backward=1.509s, opt_step_loop=0.005s
# [Epoch  460] W_f=1.589e-01, W_c=3.550e+05, W_a=3.815e+00, W_r=2.597e-04 | F_avg=6.3498e+00 | C_avg=1.5528e-07
# ...
# [Epoch 2346 timings] loss_sd=1.143s, loss_cont=3.015s, backward=6.053s, opt_step_loop=0.006s
# [Epoch 2347 timings] loss_sd=0.786s, loss_cont=2.568s, backward=4.379s, opt_step_loop=0.045s
# [Epoch 2348 timings] loss_sd=0.944s, loss_cont=1.669s, backward=4.782s, opt_step_loop=0.006s
# [Epoch 2349 timings] loss_sd=0.784s, loss_cont=1.814s, backward=5.162s, opt_step_loop=0.005s
# [Epoch 2350] W_f=1.353e-01, W_c=8.345e+05, W_a=1.692e+01, W_r=1.346e-04 | F_avg=1.9568e-01 | C_avg=2.3372e-09
# [Epoch 2350 timings] loss_sd=0.982s, loss_cont=1.478s, backward=3.882s, opt_step_loop=0.005s
# [Epoch 2351 timings] loss_sd=1.516s, loss_cont=2.030s, backward=5.913s, opt_step_loop=0.004s
# [Epoch 2352 timings] loss_sd=1.529s, loss_cont=2.100s, backward=3.623s, opt_step_loop=0.011s
# [Epoch 2353 timings] loss_sd=1.039s, loss_cont=2.354s, backward=4.039s, opt_step_loop=0.014s
# [Epoch 2354 timings] loss_sd=0.904s, loss_cont=2.041s, backward=3.376s, opt_step_loop=0.004s
# [Epoch 2355 timings] loss_sd=0.688s, loss_cont=1.545s, backward=3.882s, opt_step_loop=0.006s
# [Epoch 2356 timings] loss_sd=1.840s, loss_cont=2.424s, backward=5.286s, opt_step_loop=0.025s
# [Epoch 2357 timings] loss_sd=1.163s, loss_cont=2.627s, backward=5.489s, opt_step_loop=0.004s
# [Epoch 2358 timings] loss_sd=0.886s, loss_cont=1.550s, backward=3.329s, opt_step_loop=0.004s
# [Epoch 2359 timings] loss_sd=0.823s, loss_cont=3.275s, backward=5.000s, opt_step_loop=0.008s
# [Epoch 2360] W_f=1.667e-01, W_c=8.415e+05, W_a=1.705e+01, W_r=1.344e-04 | F_avg=1.6366e-01 | C_avg=2.2005e-09
# [Epoch 2360 timings] loss_sd=1.542s, loss_cont=1.453s, backward=5.498s, opt_step_loop=0.006s
# [Epoch 2361 timings] loss_sd=0.705s, loss_cont=1.443s, backward=4.278s, opt_step_loop=0.008s
# [Epoch 2362 timings] loss_sd=1.637s, loss_cont=2.633s, backward=4.980s, opt_step_loop=0.005s
# [Epoch 2363 timings] loss_sd=1.300s, loss_cont=1.662s, backward=4.313s, opt_step_loop=0.004s
# [Epoch 2364 timings] loss_sd=1.344s, loss_cont=1.635s, backward=4.772s, opt_step_loop=0.007s
# [Epoch 2365 timings] loss_sd=0.967s, loss_cont=3.011s, backward=5.353s, opt_step_loop=0.004s
# [Epoch 2366 timings] loss_sd=0.928s, loss_cont=1.520s, backward=3.750s, opt_step_loop=0.011s
# [Epoch 2367 timings] loss_sd=1.738s, loss_cont=2.343s, backward=3.555s, opt_step_loop=0.004s
# [Epoch 2368 timings] loss_sd=0.791s, loss_cont=2.827s, backward=3.409s, opt_step_loop=0.005s
# [Epoch 2369 timings] loss_sd=0.747s, loss_cont=3.363s, backward=3.622s, opt_step_loop=0.012s
# [Epoch 2370] W_f=2.948e-01, W_c=8.644e+05, W_a=1.718e+01, W_r=1.344e-04 | F_avg=1.3767e-01 | C_avg=2.0029e-09
# [Epoch 2370 timings] loss_sd=0.818s, loss_cont=1.593s, backward=5.856s, opt_step_loop=0.008s
# [Epoch 2371 timings] loss_sd=1.275s, loss_cont=1.514s, backward=3.975s, opt_step_loop=0.019s
# [Epoch 2372 timings] loss_sd=1.003s, loss_cont=2.347s, backward=5.220s, opt_step_loop=0.011s
# [Epoch 2373 timings] loss_sd=1.659s, loss_cont=1.573s, backward=3.912s, opt_step_loop=0.006s
# [Epoch 2374 timings] loss_sd=1.013s, loss_cont=2.308s, backward=4.545s, opt_step_loop=0.013s
# [Epoch 2375 timings] loss_sd=1.734s, loss_cont=2.447s, backward=5.165s, opt_step_loop=0.010s
# [Epoch 2376 timings] loss_sd=0.968s, loss_cont=2.496s, backward=5.058s, opt_step_loop=0.008s
# [Epoch 2377 timings] loss_sd=0.984s, loss_cont=2.378s, backward=5.563s, opt_step_loop=0.006s
# [Epoch 2378 timings] loss_sd=0.944s, loss_cont=2.232s, backward=5.176s, opt_step_loop=0.006s
# [Epoch 2379 timings] loss_sd=0.640s, loss_cont=1.912s, backward=4.974s, opt_step_loop=0.006s
# [Epoch 2380] W_f=6.104e-01, W_c=8.454e+05, W_a=1.731e+01, W_r=1.347e-04 | F_avg=1.1594e-01 | C_avg=1.8991e-09
# [Epoch 2380 timings] loss_sd=1.669s, loss_cont=2.468s, backward=4.560s, opt_step_loop=0.021s
# [Epoch 2381 timings] loss_sd=1.671s, loss_cont=2.133s, backward=5.451s, opt_step_loop=0.013s
# [Epoch 2382 timings] loss_sd=1.002s, loss_cont=1.994s, backward=3.050s, opt_step_loop=0.007s
# [Epoch 2383 timings] loss_sd=0.545s, loss_cont=1.911s, backward=2.455s, opt_step_loop=0.004s
# [Epoch 2384 timings] loss_sd=0.232s, loss_cont=0.918s, backward=2.370s, opt_step_loop=0.003s
# [Epoch 2385 timings] loss_sd=0.383s, loss_cont=0.983s, backward=2.058s, opt_step_loop=0.002s
# [Epoch 2386 timings] loss_sd=0.267s, loss_cont=0.845s, backward=2.098s, opt_step_loop=0.003s
# [Epoch 2387 timings] loss_sd=0.257s, loss_cont=0.995s, backward=1.855s, opt_step_loop=0.003s
# [Epoch 2388 timings] loss_sd=0.421s, loss_cont=0.915s, backward=1.822s, opt_step_loop=0.003s
# [Epoch 2389 timings] loss_sd=0.602s, loss_cont=1.239s, backward=2.394s, opt_step_loop=0.003s
# [Epoch 2390] W_f=8.161e-01, W_c=7.265e+05, W_a=1.744e+01, W_r=1.348e-04 | F_avg=1.0267e-01 | C_avg=1.9295e-09
# [Epoch 2390 timings] loss_sd=0.373s, loss_cont=1.350s, backward=2.277s, opt_step_loop=0.003s
# [Epoch 2391 timings] loss_sd=0.750s, loss_cont=1.072s, backward=1.778s, opt_step_loop=0.004s
# [Epoch 2392 timings] loss_sd=0.466s, loss_cont=1.107s, backward=2.153s, opt_step_loop=0.003s
# [Epoch 2393 timings] loss_sd=0.653s, loss_cont=1.356s, backward=2.507s, opt_step_loop=0.006s
# [Epoch 2394 timings] loss_sd=0.166s, loss_cont=1.302s, backward=2.941s, opt_step_loop=0.012s
# [Epoch 2395 timings] loss_sd=0.869s, loss_cont=1.360s, backward=2.015s, opt_step_loop=0.008s
# [Epoch 2396 timings] loss_sd=0.192s, loss_cont=1.068s, backward=2.556s, opt_step_loop=0.012s
# [Epoch 2397 timings] loss_sd=1.082s, loss_cont=1.273s, backward=2.607s, opt_step_loop=0.002s
# [Epoch 2398 timings] loss_sd=0.904s, loss_cont=1.121s, backward=2.581s, opt_step_loop=0.011s
# [Epoch 2399 timings] loss_sd=0.864s, loss_cont=1.503s, backward=2.942s, opt_step_loop=0.004s
# [Epoch 2400] W_f=6.466e-01, W_c=5.303e+05, W_a=1.757e+01, W_r=1.351e-04 | F_avg=9.3416e-02 | C_avg=2.1394e-09
# [Epoch 2400 timings] loss_sd=0.239s, loss_cont=1.420s, backward=2.838s, opt_step_loop=0.005s
# [Epoch 2401 timings] loss_sd=0.326s, loss_cont=2.148s, backward=2.284s, opt_step_loop=0.003s
# [Epoch 2402 timings] loss_sd=0.210s, loss_cont=1.090s, backward=2.117s, opt_step_loop=0.003s
# [Epoch 2403 timings] loss_sd=0.624s, loss_cont=1.152s, backward=2.129s, opt_step_loop=0.004s
# [Epoch 2404 timings] loss_sd=0.369s, loss_cont=1.155s, backward=2.195s, opt_step_loop=0.003s
# [Epoch 2405 timings] loss_sd=0.216s, loss_cont=0.983s, backward=2.242s, opt_step_loop=0.005s
# [Epoch 2406 timings] loss_sd=0.195s, loss_cont=1.200s, backward=3.020s, opt_step_loop=0.007s
# [Epoch 2407 timings] loss_sd=0.090s, loss_cont=1.153s, backward=2.459s, opt_step_loop=0.003s
# [Epoch 2408 timings] loss_sd=0.806s, loss_cont=1.021s, backward=2.365s, opt_step_loop=0.003s
# [Epoch 2409 timings] loss_sd=0.218s, loss_cont=1.191s, backward=2.075s, opt_step_loop=0.003s
# [Epoch 2410] W_f=6.852e-01, W_c=5.388e+05, W_a=1.770e+01, W_r=1.353e-04 | F_avg=8.6837e-02 | C_avg=2.3585e-09
# [Epoch 2410 timings] loss_sd=0.649s, loss_cont=1.333s, backward=2.727s, opt_step_loop=0.003s
# [Epoch 2411 timings] loss_sd=0.654s, loss_cont=1.222s, backward=2.511s, opt_step_loop=0.004s
# [Epoch 2412 timings] loss_sd=0.700s, loss_cont=0.990s, backward=1.986s, opt_step_loop=0.005s
# [Epoch 2413 timings] loss_sd=0.778s, loss_cont=1.185s, backward=2.326s, opt_step_loop=0.007s
# [Epoch 2414 timings] loss_sd=0.424s, loss_cont=1.451s, backward=2.640s, opt_step_loop=0.003s
# [Epoch 2415 timings] loss_sd=0.473s, loss_cont=1.074s, backward=2.645s, opt_step_loop=0.004s
# [Epoch 2416 timings] loss_sd=0.936s, loss_cont=1.095s, backward=2.655s, opt_step_loop=0.005s
# [Epoch 2417 timings] loss_sd=0.748s, loss_cont=1.545s, backward=2.384s, opt_step_loop=0.006s
# [Epoch 2418 timings] loss_sd=0.307s, loss_cont=1.362s, backward=2.372s, opt_step_loop=0.003s
# [Epoch 2419 timings] loss_sd=0.780s, loss_cont=2.245s, backward=2.371s, opt_step_loop=0.003s
# [Epoch 2420] W_f=7.731e-01, W_c=5.542e+05, W_a=1.784e+01, W_r=1.353e-04 | F_avg=8.2942e-02 | C_avg=2.5055e-09
# [Epoch 2420 timings] loss_sd=0.609s, loss_cont=1.052s, backward=2.438s, opt_step_loop=0.004s
# [Epoch 2421 timings] loss_sd=0.414s, loss_cont=1.215s, backward=2.732s, opt_step_loop=0.003s
# [Epoch 2422 timings] loss_sd=0.405s, loss_cont=1.380s, backward=2.444s, opt_step_loop=0.007s
# [Epoch 2423 timings] loss_sd=0.345s, loss_cont=1.000s, backward=1.811s, opt_step_loop=0.003s
# [Epoch 2424 timings] loss_sd=0.405s, loss_cont=1.290s, backward=1.895s, opt_step_loop=0.005s
# [Epoch 2425 timings] loss_sd=0.487s, loss_cont=1.215s, backward=2.429s, opt_step_loop=0.003s
# [Epoch 2426 timings] loss_sd=0.411s, loss_cont=1.278s, backward=2.465s, opt_step_loop=0.003s
# [Epoch 2427 timings] loss_sd=0.609s, loss_cont=1.383s, backward=2.083s, opt_step_loop=0.003s
# [Epoch 2428 timings] loss_sd=0.459s, loss_cont=0.957s, backward=1.878s, opt_step_loop=0.004s
# [Epoch 2429 timings] loss_sd=0.711s, loss_cont=1.075s, backward=1.753s, opt_step_loop=0.003s
# [Epoch 2430] W_f=1.016e+00, W_c=5.929e+05, W_a=1.797e+01, W_r=1.355e-04 | F_avg=8.0418e-02 | C_avg=2.5606e-09
# [Epoch 2430 timings] loss_sd=0.428s, loss_cont=1.440s, backward=2.286s, opt_step_loop=0.006s
# [Epoch 2431 timings] loss_sd=0.585s, loss_cont=1.632s, backward=2.297s, opt_step_loop=0.006s
# [Epoch 2432 timings] loss_sd=0.453s, loss_cont=1.161s, backward=2.102s, opt_step_loop=0.004s
# [Epoch 2433 timings] loss_sd=0.545s, loss_cont=1.167s, backward=2.101s, opt_step_loop=0.003s
# [Epoch 2434 timings] loss_sd=0.285s, loss_cont=1.128s, backward=2.361s, opt_step_loop=0.003s
# [Epoch 2435 timings] loss_sd=0.378s, loss_cont=1.105s, backward=2.230s, opt_step_loop=0.014s
# [Epoch 2436 timings] loss_sd=0.355s, loss_cont=1.518s, backward=2.724s, opt_step_loop=0.003s
# [Epoch 2437 timings] loss_sd=0.275s, loss_cont=1.999s, backward=2.077s, opt_step_loop=0.003s
# [Epoch 2438 timings] loss_sd=0.187s, loss_cont=1.107s, backward=2.339s, opt_step_loop=0.004s
# [Epoch 2439 timings] loss_sd=0.294s, loss_cont=1.480s, backward=2.380s, opt_step_loop=0.004s
# [Epoch 2440] W_f=1.275e+00, W_c=5.958e+05, W_a=1.811e+01, W_r=1.360e-04 | F_avg=7.8429e-02 | C_avg=2.6123e-09
# [Epoch 2440 timings] loss_sd=0.845s, loss_cont=0.985s, backward=2.749s, opt_step_loop=0.005s
# [Epoch 2441 timings] loss_sd=0.567s, loss_cont=1.476s, backward=3.119s, opt_step_loop=0.004s
# [Epoch 2442 timings] loss_sd=0.481s, loss_cont=1.578s, backward=3.520s, opt_step_loop=0.005s
# [Epoch 2443 timings] loss_sd=0.801s, loss_cont=1.539s, backward=3.027s, opt_step_loop=0.007s
# [Epoch 2444 timings] loss_sd=0.422s, loss_cont=2.168s, backward=2.776s, opt_step_loop=0.003s
# [Epoch 2445 timings] loss_sd=1.145s, loss_cont=1.681s, backward=3.547s, opt_step_loop=0.005s
# [Epoch 2446 timings] loss_sd=1.073s, loss_cont=1.439s, backward=3.071s, opt_step_loop=0.004s
# [Epoch 2447 timings] loss_sd=0.401s, loss_cont=1.275s, backward=2.805s, opt_step_loop=0.004s
# [Epoch 2448 timings] loss_sd=0.645s, loss_cont=1.244s, backward=2.739s, opt_step_loop=0.003s
# [Epoch 2449 timings] loss_sd=0.590s, loss_cont=1.170s, backward=2.327s, opt_step_loop=0.004s
# [Epoch 2450] W_f=1.740e+00, W_c=5.955e+05, W_a=1.825e+01, W_r=1.364e-04 | F_avg=7.6739e-02 | C_avg=2.6927e-09
# [Epoch 2450 timings] loss_sd=0.554s, loss_cont=1.216s, backward=2.897s, opt_step_loop=0.003s
# [Epoch 2451 timings] loss_sd=0.818s, loss_cont=1.201s, backward=2.648s, opt_step_loop=0.012s
# [Epoch 2452 timings] loss_sd=0.892s, loss_cont=1.166s, backward=2.419s, opt_step_loop=0.018s
# [Epoch 2453 timings] loss_sd=0.159s, loss_cont=1.222s, backward=2.653s, opt_step_loop=0.008s
# [Epoch 2454 timings] loss_sd=0.559s, loss_cont=1.417s, backward=2.872s, opt_step_loop=0.005s
# [Epoch 2455 timings] loss_sd=0.603s, loss_cont=1.230s, backward=2.411s, opt_step_loop=0.003s
# [Epoch 2456 timings] loss_sd=0.374s, loss_cont=1.921s, backward=2.612s, opt_step_loop=0.004s
# [Epoch 2457 timings] loss_sd=0.327s, loss_cont=1.296s, backward=2.766s, opt_step_loop=0.004s
# [Epoch 2458 timings] loss_sd=1.070s, loss_cont=1.094s, backward=3.652s, opt_step_loop=0.003s
# [Epoch 2459 timings] loss_sd=0.501s, loss_cont=1.618s, backward=3.085s, opt_step_loop=0.005s
# [Epoch 2460] W_f=2.189e+00, W_c=5.858e+05, W_a=1.840e+01, W_r=1.364e-04 | F_avg=7.5227e-02 | C_avg=2.8302e-09
# [Epoch 2460 timings] loss_sd=0.191s, loss_cont=1.278s, backward=2.635s, opt_step_loop=0.005s
# [Epoch 2461 timings] loss_sd=0.545s, loss_cont=1.904s, backward=3.975s, opt_step_loop=0.004s
# [Epoch 2462 timings] loss_sd=0.518s, loss_cont=1.769s, backward=2.985s, opt_step_loop=0.017s
# [Epoch 2463 timings] loss_sd=1.518s, loss_cont=1.397s, backward=3.766s, opt_step_loop=0.004s
# [Epoch 2464 timings] loss_sd=1.457s, loss_cont=1.310s, backward=2.615s, opt_step_loop=0.004s
# [Epoch 2465 timings] loss_sd=0.146s, loss_cont=1.252s, backward=3.271s, opt_step_loop=0.003s
# [Epoch 2466 timings] loss_sd=0.761s, loss_cont=1.251s, backward=3.060s, opt_step_loop=0.003s
# [Epoch 2467 timings] loss_sd=0.842s, loss_cont=1.079s, backward=2.206s, opt_step_loop=0.004s
# [Epoch 2468 timings] loss_sd=0.678s, loss_cont=1.139s, backward=2.379s, opt_step_loop=0.006s
# [Epoch 2469 timings] loss_sd=0.949s, loss_cont=1.838s, backward=2.435s, opt_step_loop=0.005s
# [Epoch 2470] W_f=2.911e+00, W_c=6.130e+05, W_a=1.854e+01, W_r=1.361e-04 | F_avg=7.3945e-02 | C_avg=2.9177e-09
# [Epoch 2470 timings] loss_sd=0.380s, loss_cont=1.772s, backward=2.885s, opt_step_loop=0.003s
# [Epoch 2471 timings] loss_sd=0.310s, loss_cont=1.320s, backward=2.804s, opt_step_loop=0.006s
# [Epoch 2472 timings] loss_sd=0.819s, loss_cont=1.122s, backward=2.160s, opt_step_loop=0.007s
# [Epoch 2473 timings] loss_sd=1.018s, loss_cont=1.348s, backward=2.206s, opt_step_loop=0.003s
# [Epoch 2474 timings] loss_sd=0.805s, loss_cont=1.129s, backward=2.128s, opt_step_loop=0.003s
# [Epoch 2475 timings] loss_sd=1.349s, loss_cont=1.926s, backward=2.189s, opt_step_loop=0.003s
# [Epoch 2476 timings] loss_sd=0.667s, loss_cont=1.258s, backward=2.192s, opt_step_loop=0.005s
# [Epoch 2477 timings] loss_sd=0.616s, loss_cont=1.073s, backward=2.213s, opt_step_loop=0.003s
# [Epoch 2478 timings] loss_sd=0.918s, loss_cont=1.214s, backward=2.496s, opt_step_loop=0.003s
# [Epoch 2479 timings] loss_sd=0.765s, loss_cont=1.221s, backward=2.242s, opt_step_loop=0.003s
# [Epoch 2480] W_f=4.087e+00, W_c=6.633e+05, W_a=1.868e+01, W_r=1.354e-04 | F_avg=7.2864e-02 | C_avg=2.9412e-09
# [Epoch 2480 timings] loss_sd=0.756s, loss_cont=1.228s, backward=2.264s, opt_step_loop=0.003s
# [Epoch 2481 timings] loss_sd=0.327s, loss_cont=1.053s, backward=1.925s, opt_step_loop=0.003s
# [Epoch 2482 timings] loss_sd=0.614s, loss_cont=1.218s, backward=2.332s, opt_step_loop=0.004s
# [Epoch 2483 timings] loss_sd=0.354s, loss_cont=1.324s, backward=3.619s, opt_step_loop=0.003s
# [Epoch 2484 timings] loss_sd=0.278s, loss_cont=1.214s, backward=2.288s, opt_step_loop=0.005s
# [Epoch 2485 timings] loss_sd=0.427s, loss_cont=1.862s, backward=2.685s, opt_step_loop=0.003s
# [Epoch 2486 timings] loss_sd=0.377s, loss_cont=1.310s, backward=2.366s, opt_step_loop=0.003s
# [Epoch 2487 timings] loss_sd=0.361s, loss_cont=1.177s, backward=2.301s, opt_step_loop=0.004s
# [Epoch 2488 timings] loss_sd=0.372s, loss_cont=1.140s, backward=2.386s, opt_step_loop=0.004s
# [Epoch 2489 timings] loss_sd=0.687s, loss_cont=1.236s, backward=2.487s, opt_step_loop=0.005s
# [Epoch 2490] W_f=5.660e+00, W_c=7.002e+05, W_a=1.883e+01, W_r=1.344e-04 | F_avg=7.1900e-02 | C_avg=2.9293e-09
# [Epoch 2490 timings] loss_sd=0.318s, loss_cont=1.435s, backward=2.087s, opt_step_loop=0.005s
# [Epoch 2491 timings] loss_sd=0.541s, loss_cont=1.151s, backward=2.115s, opt_step_loop=0.003s
# [Epoch 2492 timings] loss_sd=0.322s, loss_cont=1.117s, backward=2.689s, opt_step_loop=0.003s
# [Epoch 2493 timings] loss_sd=0.431s, loss_cont=1.155s, backward=2.560s, opt_step_loop=0.004s
# [Epoch 2494 timings] loss_sd=0.214s, loss_cont=1.599s, backward=3.044s, opt_step_loop=0.004s
# [Epoch 2495 timings] loss_sd=0.413s, loss_cont=2.113s, backward=2.806s, opt_step_loop=0.003s
# [Epoch 2496 timings] loss_sd=0.371s, loss_cont=1.721s, backward=2.298s, opt_step_loop=0.003s
# [Epoch 2497 timings] loss_sd=0.429s, loss_cont=1.171s, backward=2.253s, opt_step_loop=0.005s
# [Epoch 2498 timings] loss_sd=0.344s, loss_cont=1.594s, backward=2.307s, opt_step_loop=0.005s
# [Epoch 2499 timings] loss_sd=0.274s, loss_cont=1.613s, backward=2.933s, opt_step_loop=0.003s

# %%
net_norm
# Out:
# [tensor(9.4512, grad_fn=<MulBackward0>),
#  tensor(3.6223, grad_fn=<MulBackward0>),
#  tensor(6.5244, grad_fn=<MulBackward0>),
#  tensor(2.6454, grad_fn=<MulBackward0>)]

# %%
min(loss_lc_avg_arr)
# Out:
# 0.07110973447561264

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(loss_lc_avg_arr, marker="o", markersize=3)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training loss (Adam)")
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(loss_cont_avg_arr, marker="o", markersize=3)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training loss (Adam)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as mticker
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))

plt.plot(loss_lc_avg_arr, marker="o", markersize=3)

plt.yscale("log")  # log-scale y-axis
plt.ylim(bottom=1e-2)

# Format ticks as 10^{-1}, 10^{-2}, ...
ax = plt.gca()
ax.yaxis.set_major_locator(mticker.LogLocator(base=10))
ax.yaxis.set_major_formatter(mticker.LogFormatterMathtext())

plt.xlabel("Epoch")
plt.ylabel("Error")
# plt.title("Training loss (Adam)")
plt.grid(True, which="both", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()
plt.figure(figsize=(6, 4))

plt.plot(loss_cont_avg_arr, marker="o", markersize=3)

plt.yscale("log")  # log-scale y-axis
plt.ylim(bottom=1e-10)

# Format ticks as 10^{-1}, 10^{-2}, ...
ax = plt.gca()
ax.yaxis.set_major_locator(mticker.LogLocator(base=10))
ax.yaxis.set_major_formatter(mticker.LogFormatterMathtext())

plt.xlabel("Epoch")
plt.ylabel("Error")
# plt.title("Training loss (Adam)")
plt.grid(True, which="both", linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %%
LCE_CG = []
LCE_rec = []
indices = []

LCE_CG_int = []
LCE_rec_int = []
indices_int = []
for local_cell_idx, cell_verts in enumerate(tqdm(local_cell_vertices)):
    # cell_verts are global vertex indices
    coords = omega_geometry[cell_verts]  # shape (3,2)
    coords_t = torch.tensor(coords, dtype=torch.float32, device=device)
    sd = cell_subdomain[local_cell_idx][0]
    net_sd = nets[sd]
    centroid = np.mean(coords, axis=0).reshape(1,-1)
    centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()

    loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

    gdim = coords.shape[1]
    coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))

    local_mesh = dmesh.create_mesh(
        MPI.COMM_SELF,
        loc_cells,
        coord_el,   # <-- this is the required "e" argument
        coords
    )
    cell_dofs = V.dofmap.cell_dofs(local_cell_idx)
    # -------------------------------------------------
    # 2. Local vector CG2 space for r_θ
    # -------------------------------------------------
    # Vector-valued CG2 (shape=(gdim,))
    V_loc = fem.functionspace(local_mesh, ("CG", order+1, (gdim,)))
    # r_loc = fem.Function(V_loc)

    # -------------------------------------------------
    # 3. Interpolate NN into r_loc via dof coordinates
    # -------------------------------------------------
    x_loc = V_loc.tabulate_dof_coordinates()[:,0:2]  # (Ndofs, gdim)
    x_loc_torch = torch.tensor(x_loc, dtype=torch.float32)      # NN input

    # r_vals_torch = net(x_loc_torch)                             # (Ndofs, gdim)
    # r_vals = r_vals_torch.detach().cpu().numpy().reshape(-1)

    # assign to local FEM function
    # r_loc.x.array[:] = r_vals.astype(default_scalar_type)

    # -------------------------------------------------
    # 4. Compute ∫_{∂D_j} r_θ · n ds on local mesh
    # -------------------------------------------------
    n_K = ufl.FacetNormal(local_mesh)
    # int_r_form = fem.form(ufl.dot(r_loc, n_K) * ufl.ds)

    edge_indices = [(0, 1), (1, 2), (2, 0)]
    int_r_local = torch.zeros((), device=device)

    num_sub = 3 #sub integral section

    for (i0, i1) in edge_indices:
        x0 = coords_t[i0]
        x1 = coords_t[i1]
        t = x1 - x0
        L = torch.linalg.norm(t)
        if L <= 0:
            continue

        n_edge = (torch.stack([t[1], -t[0]]) / L)
        n_edge = torch.tensor(n_edge, dtype=torch.float32)
        centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()
        midpoint = 0.5 * (x0 + x1)
        if torch.dot(n_edge, centroid_t - midpoint) > 0:
            n_edge = -n_edge
        int_r_local += integrate_edge_flux(net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3)
    # int_r_local = fem.assemble_scalar(int_r_form)

    # -------------------------------------------------
    # 5. Combine with q_cg and f (precomputed per cell)
    # -------------------------------------------------
    P_loc = fem.functionspace(local_mesh, ("CG", order))
    p_K = fem.Function(P_loc)

    # DOFs on this cell in the global space
    global_dofs = V.dofmap.cell_dofs(local_cell_idx)

    # DOFs on the (only) cell in the local space
    local_dofs = P_loc.dofmap.cell_dofs(0)

    p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
    p_K.x.scatter_forward()

    k_m_loc = fem.Function(P_loc)
    k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]

    q_CG = -k_m_loc * ufl.grad(p_K)
    int_qcg = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ufl.ds(domain=local_mesh))
            )   # ∫_{∂D_j} q_cg · n
    
    f_m_loc = fem.Function(P_loc)
    f_m_loc.x.array[local_dofs] = f.x.array[global_dofs]
    f_m_loc.x.scatter_forward()
    int_f   = fem.assemble_scalar(fem.form(f_m_loc * ufl.dx(domain=local_mesh)))       # ∫_{D_j} f

    residual_j = float(int_r_local) + int_qcg - int_f

    LCE_CG.append(int_qcg - int_f)
    LCE_rec.append(residual_j)
    indices.append(local_cell_idx)

    left_dofs_P = fem.locate_dofs_geometrical(
        P_loc, lambda x: np.isclose(x[0], xmin, atol=tol)
    )
    right_dofs_P = fem.locate_dofs_geometrical(
        P_loc, lambda x: np.isclose(x[0], xmax, atol=tol)
    )

    if (len(left_dofs_P) == 0) and (len(right_dofs_P) == 0):
        LCE_CG_int.append(int_qcg - int_f)
        LCE_rec_int.append(residual_j)
        indices_int.append(local_cell_idx)
# Out:
#   0%|          | 0/8192 [00:00<?, ?it/s]/tmp/ipykernel_167827/4043814364.py:68: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   n_edge = torch.tensor(n_edge, dtype=torch.float32)
# 100%|██████████| 8192/8192 [02:09<00:00, 63.44it/s]

# %%
indices_plot = np.array(indices_int, dtype=int)
LCE_CG_plot = np.array(LCE_CG_int, dtype=float)
LCE_rec_plot = np.array(LCE_rec_int, dtype=float)

# plot
plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")
plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
def stats(arr):
    return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
print("CG LCE stats:", stats(LCE_CG_plot))
print("Reconstructed LCE stats:", stats(LCE_rec_plot))
# Out:
# CG LCE stats: {'min': -0.0011392800727951802, 'max': 0.00025772402174570097, 'L1_mean_abs': 0.00010396642111009916, 'L2_rms': 0.00016934216797948889}
# Reconstructed LCE stats: {'min': -0.0005636068228124243, 'max': 0.0002577249530682756, 'L1_mean_abs': 2.4106467578104035e-05, 'L2_rms': 4.69249557892925e-05}

# %%
import matplotlib.ticker as mticker

indices_plot = np.array(indices_int, dtype=int)
LCE_CG_plot = np.array(LCE_CG_int, dtype=float)
LCE_rec_plot = np.array(LCE_rec_int, dtype=float)

plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")

plt.yscale("log")  # log-scale y-axis

# Format ticks as 10^{-1}, 10^{-2}, ...
plt.gca().yaxis.set_major_formatter(mticker.LogFormatterMathtext())
plt.gca().yaxis.set_major_locator(mticker.LogLocator(base=10))

plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True, which="both", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import os
# Define folder + filename
folder = "trained_nn"
filename = "cPINN_4sd_wr_0.05.pt"
path = os.path.join(folder, filename)

# Create folder if it does not exist
os.makedirs(folder, exist_ok=True)

checkpoint = {
    "epoch": epoch,
    "model_config": {
        "layers": 2,
        "width": 16,
        "activation": "tanh",
        "w_r": 0.05
    },
    "nets_state_dict": [net.state_dict() for net in nets],
    "optimizers_state_dict": [opt.state_dict() for opt in optimizers],
}

torch.save(checkpoint, path)

# %%
import matplotlib.pyplot as plt
indices_plot = np.array(indices, dtype=int)
LCE_CG_plot = np.array(LCE_CG, dtype=float)
LCE_rec_plot = np.array(LCE_rec, dtype=float)
loss_sd_plot = np.array([float(cc.detach()) for cc in loss_sd])

# plot
plt.figure(figsize=(10,4))
plt.plot(indices_plot, np.abs(LCE_CG_plot), label="LCE (CG flux)")
# plt.plot(indices_plot, np.abs(LCE_rec_plot), ".", label="LCE (reconstructed flux)")
plt.plot(indices_plot, np.abs(loss_sd_plot), ".", label="LCE (reconstructed flux) From training")
plt.xlabel("Element index")
plt.ylabel("Local Conservation Error (LCE)")
plt.title("LCE per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
def stats(arr):
    return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
print("CG LCE stats:", stats(LCE_CG_plot))
print("Reconstructed LCE stats:", stats(LCE_rec_plot))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 5
#       3 LCE_CG_plot = np.array(LCE_CG, dtype=float)
#       4 LCE_rec_plot = np.array(LCE_rec, dtype=float)
# ----> 5 loss_sd_plot = np.array([float(cc.detach()) for cc in loss_sd])
#       7 # plot
#       8 plt.figure(figsize=(10,4))
#
# NameError: name 'loss_sd' is not defined

# %%
jump_CG = []
jump_rec = []
jump_indices = []   # cell indices

tdim = omega.topology.dim
gdim = omega.geometry.dim

# --- vertex -> cell connectivity (global) ---
cells_vtx = omega.topology.connectivity(0, tdim)
if cells_vtx is None:
    omega.topology.create_connectivity(0, tdim)
    cells_vtx = omega.topology.connectivity(0, tdim)

# --- cell -> vertex connectivity (global) ---
ctv = omega.topology.connectivity(tdim, 0)
if ctv is None:
    omega.topology.create_connectivity(tdim, 0)
    ctv = omega.topology.connectivity(tdim, 0)

num_cells = omega.topology.index_map(tdim).size_local

# Coordinate element for local 1-cell meshes
coord_el = basix.ufl.element("Lagrange", "triangle", 1, shape=(gdim,))
loc_cells = np.array([[0, 1, 2]], dtype=np.int64)

local_edges = [(0, 1), (1, 2), (0, 2)]

for cell in range(num_cells):
    cell_jump_CG = 0.0
    cell_jump_rec = 0.0

    cell_verts = ctv.links(cell)
    coords_K = omega_geometry[cell_verts]

    sd = cell_subdomain[cell][0]

    # --- geometric data for this cell ---
    centroid = np.mean(coords_K, axis=0).reshape(1, -1)
    centroid_t = torch.tensor(centroid, dtype=torch.float32, device=device).squeeze()

    for local_edge_idx, (la, lb) in enumerate(local_edges):
        v0 = cell_verts[la]
        v1 = cell_verts[lb]

        # ---- neighboring cell sharing this edge ----
        cells0 = cells_vtx.links(v0)
        cells1 = cells_vtx.links(v1)
        common_cells = np.intersect1d(cells0, cells1)

        if common_cells.size == 0:
            continue

        neighbor_cells = [int(c) for c in common_cells if int(c) != cell]

        # boundary edge → no contribution
        if len(neighbor_cells) == 0:
            continue

        cell_adj = neighbor_cells[0]

        facet_fluxes = []
        facet_fluxes_rec = []

        # ---------- two-sided loop (cell + neighbor) ----------
        for cell_side in (cell, cell_adj):
            cell_verts_side = ctv.links(cell_side)
            coords_side = omega_geometry[cell_verts_side]

            local_mesh = dmesh.create_mesh(
                MPI.COMM_SELF,
                loc_cells,
                coord_el,
                coords_side
            )

            tdim_loc = local_mesh.topology.dim
            fdim_loc = tdim_loc - 1
            local_mesh.topology.create_entities(fdim_loc)
            if local_mesh.topology.connectivity(fdim_loc, 0) is None:
                local_mesh.topology.create_connectivity(fdim_loc, 0)

            sd_side = cell_subdomain[cell_side][0]
            net_sd = nets[sd_side]

            P_loc = fem.functionspace(local_mesh, ("CG", order))
            p_K = fem.Function(P_loc)
            k_m_loc = fem.Function(P_loc)

            global_dofs = V.dofmap.cell_dofs(cell_side)
            local_dofs = P_loc.dofmap.cell_dofs(0)

            p_K.x.array[local_dofs] = p_sol.x.array[global_dofs]
            p_K.x.scatter_forward()

            k_m_loc.x.array[local_dofs] = k_m.x.array[global_dofs]
            k_m_loc.x.scatter_forward()

            q_CG = -k_m_loc * ufl.grad(p_K)
            n_K = ufl.FacetNormal(local_mesh)

            # vertex–facet connectivity
            local_mesh.topology.create_connectivity(0, fdim_loc)
            local_mesh.topology.create_connectivity(fdim_loc, 0)
            v_to_f = local_mesh.topology.connectivity(0, fdim_loc)
            f_to_v = local_mesh.topology.connectivity(fdim_loc, 0)

            lv0 = int(np.where(cell_verts_side == v0)[0][0])
            lv1 = int(np.where(cell_verts_side == v1)[0][0])

            edge_id = None
            for ff in v_to_f.links(lv0):
                if lv1 in f_to_v.links(ff):
                    edge_id = ff
                    break
            assert edge_id is not None

            mt = dmesh.meshtags(
                local_mesh,
                fdim_loc,
                np.array([edge_id], dtype=np.int32),
                np.array([1], dtype=np.int32)
            )
            ds = ufl.Measure("ds", domain=local_mesh, subdomain_data=mt)

            flux_i = fem.assemble_scalar(
                fem.form(ufl.dot(q_CG, n_K) * ds(1))
            )
            facet_fluxes.append(flux_i)

            # ----- NN reconstructed flux -----
            centroid_side = np.mean(coords_side, axis=0).reshape(1, -1)
            centroid_t_side = torch.tensor(
                centroid_side, dtype=torch.float32, device=device
            ).squeeze()

            x0 = torch.tensor(omega_geometry[v0], dtype=torch.float32, device=device)
            x1 = torch.tensor(omega_geometry[v1], dtype=torch.float32, device=device)

            t = x1 - x0
            L = torch.linalg.norm(t)
            if L <= 0:
                continue

            n_edge = torch.stack([t[1], -t[0]]) / L
            midpoint = 0.5 * (x0 + x1)
            if torch.dot(n_edge, centroid_t_side - midpoint) > 0:
                n_edge = -n_edge

            int_net_edge = integrate_edge_flux(
                net_sd, x0, x1, n_edge, L, xi, wi, num_sub=3
            )
            facet_fluxes_rec.append(flux_i + float(int_net_edge))

        # ---------- sum jump on this edge ----------
        if len(facet_fluxes) == 2:
            cell_jump_CG += facet_fluxes[0] + facet_fluxes[1]
            cell_jump_rec += facet_fluxes_rec[0] + facet_fluxes_rec[1]

    # ---------- append ONCE per cell ----------
    jump_CG.append(cell_jump_CG)
    jump_rec.append(cell_jump_rec)
    jump_indices.append(cell)

# %%
jump_indices_plot = np.array(jump_indices, dtype=int)
jump_CG_plot = np.array(jump_CG, dtype=float)
jump_rec_plot = np.array(jump_rec, dtype=float)
loss_continuity_plot = np.array([cc.detach() for cc in loss_continuity_sd])

# plot
plt.figure(figsize=(10,4))
plt.plot(jump_indices_plot, jump_CG_plot, label="Jump (CG flux)")
plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
# plt.plot(jump_indices_plot, loss_continuity_plot, ".", label="Loss continuity (reconstructed flux)")
plt.xlabel("Element Index")
plt.ylabel("Jump")
plt.title("Jump per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()

# print stats & produce dataframe
# def stats(arr):
#     return {"min": float(arr.min()), "max": float(arr.max()), "L1_mean_abs": float(np.mean(np.abs(arr))), "L2_rms": float(np.sqrt(np.mean(arr**2)))}
# print("CG LCE stats:", stats(LCE_CG_plot))
# print("Reconstructed LCE stats:", stats(LCE_rec_plot))

# %%
# plot
plt.figure(figsize=(10,4))
plt.plot(jump_indices_plot, abs(jump_CG_plot), label="Jump (CG flux)")
# plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
plt.plot(jump_indices_plot, abs(loss_continuity_plot), ".", label="Loss continuity (reconstructed flux)")
plt.xlabel("Element Index")
plt.ylabel("Jump")
plt.title("Jump per element: CG vs Reconstructed flux")
plt.legend()
plt.grid(True)
plt.tight_layout()
# out_path = "/mnt/data/lce_plot.png"
# plt.savefig(out_path)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 5
#       3 plt.plot(jump_indices_plot, abs(jump_CG_plot), label="Jump (CG flux)")
#       4 # plt.plot(jump_indices_plot, jump_rec_plot, ".", label="Jump (reconstructed flux)")
# ----> 5 plt.plot(jump_indices_plot, abs(loss_continuity_plot), ".", label="Loss continuity (reconstructed flux)")
#       6 plt.xlabel("Element Index")
#       7 plt.ylabel("Jump")
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/PhD/fenicsx/lib/python3.13/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (32,) and (4,)
